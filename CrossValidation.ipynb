# %%
import pandas as pd
import numpy as np
import scipy
import random
import csv
from sklearn.svm import SVC, LinearSVC
from sklearn.model_selection import train_test_split, GridSearchCV,RandomizedSearchCV
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing


fileLocation = "Model-nofilter-nonorm.csv"
df = pd.read_csv(fileLocation)

data = df.drop('Class', axis=1)  
classes = df['Class']

# X_train = []
# X_test = []
# X_validation = []
# y_train = []
# y_test = []
# y_validation = []
# for index in range(0, len(data)):
#     if index % 5 == 0:
#         X_test.append(data.loc[index].values)
#         y_test.append(classes.loc[index])
#     elif index % 5 == 1:
#         X_validation.append(data.loc[index].values)
#         y_validation.append(classes.loc[index])
#     else:
#         X_train.append(data.loc[index].values)
#         y_train.append(classes.loc[index])
        
# X_test = pd.DataFrame(X_test, columns = data.columns.values)
# y_test = pd.DataFrame(y_test, columns = ['Class'])
# X_train = pd.DataFrame(X_train, columns = data.columns.values)
# y_train = pd.DataFrame(y_train, columns = ['Class']) 
# X_validation = pd.DataFrame(X_validation, columns = data.columns.values)
# y_validation = pd.DataFrame(y_validation, columns = ['Class']) 

X_train, X_test, y_train, y_test = train_test_split(data, classes, test_size=0.20, random_state=0)
    
#X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# %%
scaler = preprocessing.StandardScaler().fit(X_train)
X_train_transformed = scaler.transform(X_train)

# %%
Cs = [0.001, 0.01, 0.1, 1, 10]
gammas = ["auto", 0.001, 0.01, 0.1, 1]
degrees = [1, 2, 3, 4, 5]

param_grid = {'C': Cs, 'gamma' : gammas, 'degree' : degrees}

svclassifier = SVC(kernel='rbf')  

clf = RandomizedSearchCV(svclassifier, param_grid)

scores = cross_val_score(clf, X_train_transformed, y_train, cv=10)

# %%
print(scores)

print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

print(clf.return_train_score)

# %%
clf = SVC(kernel='rbf', C=10, gamma = 'auto', degree = 3).fit(X_train_transformed, y_train)

# %%
X_validation_transformed = scaler.transform(X_validation)

# %%
Cs = [0.001, 0.01, 0.1, 1, 10]
gammas = ["auto", 0.001, 0.01, 0.1, 1]
degrees = [1, 2, 3, 4, 5]

param_grid = {'C': Cs, 'gamma' : gammas, 'degree' : degrees}


svclassifier = SVC(kernel='rbf')  

clf = RandomizedSearchCV(svclassifier, param_grid)
clf.fit(X_train, y_train)  

print(clf.best_params_)
y_pred = clf.predict(X_validation)
print(confusion_matrix(y_validation,y_pred))  
print(classification_report(y_validation,y_pred))  
print(accuracy_score(y_validation, y_pred))

# %% [markdown]
# # random serach {'gamma': 'auto', 'degree': 3, 'C': 10}

# %%
X_test_transformed = scaler.transform(X_test)

# %%
clf = SVC(kernel='rbf', C=10, gamma = 'auto', degree = 3)  

clf.fit(X_train_transformed, y_train)  
  

# print(tclf.best_params_)
y_pred = clf.predict(X_test_transformed)
print(confusion_matrix(y_test,y_pred))  
print(classification_report(y_test,y_pred))  
print(accuracy_score(y_test, y_pred))

# %%
cf = confusion_matrix(y_test,y_pred)

df = pd.DataFrame(cf)
df.to_csv('crossval.csv', encoding='utf-8', index=False)

# %%
print(len(X_train))

# %% [markdown]
# # Parameter estimation

# %%
from __future__ import print_function

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.svm import SVC

print(__doc__)


Cs = [0.001, 0.01, 0.1, 1, 10]
gammas = ["auto", 0.001, 0.01, 0.1, 1]
degrees = [1, 2, 3, 4, 5]
param_grid = {'C': Cs, 'gamma' : gammas, 'degree' : degrees}
scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()
    svclassifier = SVC(kernel='rbf')  

    clf = RandomizedSearchCV(svclassifier, param_grid, cv=10)
    clf.fit(X_train_transformed, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test_transformed)
    print(classification_report(y_true, y_pred))

# Note the problem is too easy: the hyperparameter plateau is too flat and the
# output model is the same for precision and recall with ties in quality.
# Out:
# Automatically created module for IPython interactive environment
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'gamma': 'auto', 'degree': 1, 'C': 10}
#
# Grid scores on development set:
#
# 0.411 (+/-0.040) for {'gamma': 0.1, 'degree': 4, 'C': 1}
# 0.165 (+/-0.011) for {'gamma': 0.001, 'degree': 3, 'C': 0.1}
# 0.456 (+/-0.041) for {'gamma': 0.1, 'degree': 2, 'C': 10}
# 0.019 (+/-0.001) for {'gamma': 0.001, 'degree': 4, 'C': 0.001}
# 0.257 (+/-0.018) for {'gamma': 0.01, 'degree': 4, 'C': 0.1}
# 0.924 (+/-0.034) for {'gamma': 'auto', 'degree': 1, 'C': 10}
# 0.165 (+/-0.011) for {'gamma': 0.001, 'degree': 2, 'C': 0.1}
# 0.019 (+/-0.001) for {'gamma': 0.1, 'degree': 1, 'C': 0.01}
# 0.165 (+/-0.011) for {'gamma': 0.001, 'degree': 1, 'C': 0.1}
# 0.019 (+/-0.001) for {'gamma': 'auto', 'degree': 4, 'C': 0.01}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#                  precision    recall  f1-score   support
#
#             ano       0.90      1.00      0.95        19
#            asul       0.95      0.95      0.95        20
#             ate       0.94      0.83      0.88        18
#           baboy       1.00      0.95      0.97        20
#       binebenta       0.90      0.90      0.90        21
#          dalawa       0.76      0.81      0.79        27
#            dito       0.88      0.88      0.88        16
#           extra       0.93      1.00      0.97        14
#           gulay       1.00      1.00      1.00        23
#           gusto       0.78      0.90      0.84        20
#           hello       0.81      1.00      0.89        17
#             isa       0.79      0.79      0.79        19
#            isda       1.00      0.90      0.95        10
#            itim       1.00      0.95      0.98        22
#           itlog       0.86      1.00      0.92        18
#             ito       0.96      0.92      0.94        24
#           juice       0.81      0.89      0.85        19
#           kanin       0.90      1.00      0.95        19
#            kape       0.88      0.79      0.83        19
#            kayo       0.95      0.95      0.95        20
#            kilo       1.00      1.00      1.00        17
#              ko       0.93      0.93      0.93        14
#           kulay       0.95      0.86      0.90        21
#            kuya       0.83      0.94      0.88        16
#   large (shirt)       1.00      0.88      0.93        16
#         magkano       1.00      1.00      1.00        20
#           mahal       1.00      0.95      0.98        22
#          malaki       0.85      0.71      0.77        24
#          maliit       0.76      0.92      0.83        24
#           manok       0.96      0.96      0.96        25
#         mantika       0.88      0.92      0.90        24
#         mayroon       0.89      1.00      0.94        24
#  medium (shirt)       0.69      0.85      0.76        13
#      nagbubukas       0.91      0.88      0.89        24
#       nagsasara       0.87      0.76      0.81        17
#            nito       0.90      0.95      0.92        19
#            niyo       1.00      1.00      1.00        16
#            oras       1.00      1.00      1.00        23
#          pabili       1.00      1.00      1.00        17
#         pagkain       0.94      1.00      0.97        17
#       poloshirt       1.00      1.00      1.00        23
#            pula       0.96      0.96      0.96        24
#          puwede       1.00      1.00      1.00        18
#          saging       1.00      0.88      0.93        32
#         salamat       0.96      1.00      0.98        23
# sari-sari store       0.93      1.00      0.97        14
#          shorts       0.97      1.00      0.98        30
#            size       0.95      1.00      0.98        21
#   small (shirt)       0.92      0.79      0.85        14
#      softdrinks       1.00      0.76      0.86        21
#           sorry       1.00      0.96      0.98        23
#       spaghetti       1.00      1.00      1.00        18
#           supot       0.96      1.00      0.98        23
#         t-shirt       1.00      0.85      0.92        13
#           tatlo       0.88      0.71      0.79        21
#           tawad       1.00      0.93      0.97        15
#         tinapay       0.96      1.00      0.98        25
#           tubig       1.00      0.90      0.95        21
#           utang       0.95      1.00      0.98        21
#            wala       1.00      0.95      0.98        22
#
#     avg / total       0.93      0.93      0.93      1200
#
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# {'gamma': 0.001, 'degree': 3, 'C': 10}
#
# Grid scores on development set:
#
# 0.019 (+/-0.001) for {'gamma': 0.1, 'degree': 1, 'C': 0.01}
# 0.869 (+/-0.034) for {'gamma': 0.001, 'degree': 3, 'C': 10}
# 0.369 (+/-0.032) for {'gamma': 'auto', 'degree': 4, 'C': 0.1}
# 0.019 (+/-0.001) for {'gamma': 0.01, 'degree': 1, 'C': 0.01}
# 0.019 (+/-0.001) for {'gamma': 'auto', 'degree': 3, 'C': 0.01}
# 0.257 (+/-0.018) for {'gamma': 0.01, 'degree': 3, 'C': 0.1}
# 0.165 (+/-0.011) for {'gamma': 0.001, 'degree': 5, 'C': 0.1}
# 0.019 (+/-0.001) for {'gamma': 1, 'degree': 4, 'C': 0.1}
# 0.019 (+/-0.001) for {'gamma': 0.1, 'degree': 5, 'C': 0.001}
# 0.019 (+/-0.001) for {'gamma': 0.1, 'degree': 2, 'C': 0.01}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#                  precision    recall  f1-score   support
#
#             ano       0.75      0.95      0.84        19
#            asul       0.94      0.85      0.89        20
#             ate       0.65      0.61      0.63        18
#           baboy       1.00      0.85      0.92        20
#       binebenta       1.00      0.86      0.92        21
#          dalawa       0.71      0.74      0.73        27
#            dito       0.87      0.81      0.84        16
#           extra       0.92      0.86      0.89        14
#           gulay       1.00      1.00      1.00        23
#           gusto       0.94      0.80      0.86        20
#           hello       0.69      0.65      0.67        17
#             isa       0.72      0.68      0.70        19
#            isda       1.00      1.00      1.00        10
#            itim       0.92      1.00      0.96        22
#           itlog       0.94      0.94      0.94        18
#             ito       0.91      0.83      0.87        24
#           juice       0.77      0.89      0.83        19
#           kanin       0.73      0.84      0.78        19
#            kape       0.80      0.84      0.82        19
#            kayo       1.00      1.00      1.00        20
#            kilo       1.00      1.00      1.00        17
#              ko       0.92      0.79      0.85        14
#           kulay       0.73      0.76      0.74        21
#            kuya       0.82      0.88      0.85        16
#   large (shirt)       0.93      0.88      0.90        16
#         magkano       0.95      1.00      0.98        20
#           mahal       0.96      1.00      0.98        22
#          malaki       0.58      0.75      0.65        24
#          maliit       0.74      0.71      0.72        24
#           manok       0.92      0.92      0.92        25
#         mantika       0.81      0.92      0.86        24
#         mayroon       0.96      1.00      0.98        24
#  medium (shirt)       0.50      0.69      0.58        13
#      nagbubukas       0.86      0.75      0.80        24
#       nagsasara       0.59      0.76      0.67        17
#            nito       0.90      0.95      0.92        19
#            niyo       1.00      1.00      1.00        16
#            oras       1.00      0.91      0.95        23
#          pabili       1.00      0.94      0.97        17
#         pagkain       0.75      0.88      0.81        17
#       poloshirt       1.00      1.00      1.00        23
#            pula       0.68      0.79      0.73        24
#          puwede       0.94      0.94      0.94        18
#          saging       1.00      0.97      0.98        32
#         salamat       0.96      0.96      0.96        23
# sari-sari store       0.82      1.00      0.90        14
#          shorts       1.00      1.00      1.00        30
#            size       0.88      0.71      0.79        21
#   small (shirt)       0.64      0.50      0.56        14
#      softdrinks       0.81      0.62      0.70        21
#           sorry       0.95      0.91      0.93        23
#       spaghetti       1.00      1.00      1.00        18
#           supot       0.96      1.00      0.98        23
#         t-shirt       1.00      0.92      0.96        13
#           tatlo       0.87      0.62      0.72        21
#           tawad       0.86      0.80      0.83        15
#         tinapay       1.00      0.96      0.98        25
#           tubig       0.65      0.62      0.63        21
#           utang       1.00      0.90      0.95        21
#            wala       0.92      1.00      0.96        22
#
#     avg / total       0.87      0.87      0.87      1200
