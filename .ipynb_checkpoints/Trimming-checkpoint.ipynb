# %%
import glob
import pandas as pd

listOfFileNames = []
listOfClassNames = []
listOfDataPerClass = []
files = []
classNames = []
#path = "/Users/user/Desktop/asd/thesis/placeholder/"
#path = "/Users/user/Desktop/pinakalatest/thesis/placeholder/"
path = "non-signer_data/"
classNames = glob.glob(path + "*")

for c in classNames:
    className = c.split("\\")[1]
    listOfClassNames.append(c.split("\\")[1])
    files = glob.glob(path + className+"/*") 
    listOfFileNames = []
    for i in range(0, len(files)):
        data = glob.glob(path + className+"/" + str(i+1) + "/*.csv")
        
        for f in data:
            listOfFileNames.append(str(i+1) + "/" + f.split("\\")[1])
    listOfDataPerClass.append(listOfFileNames)
    
listOfDataFramesPerClass = {}
dataFrameDictionary = {}
dataFrames = []

for c, d in zip(listOfClassNames, listOfDataPerClass):
    print("----------------- Word " + c + "-----------------")
    emgDataFrames = {}
    emgDataFrames['right'] = []
    emgDataFrames['left'] = []
    
    accDataFrames = {}
    accDataFrames['right'] = []
    accDataFrames['left'] = []

    gyroDataFrames = {}
    gyroDataFrames['right'] = []
    gyroDataFrames['left'] = []

    dataFrameDictionary = {}
    className = c
    emgleftctr = 0
    emgrightctr = 0
    accleftctr = 0
    accrightctr = 0
    gyroleftctr = 0
    gyrorightctr = 0
    
    for fileName in d:
        fileLocation = path + className + "/" + fileName + ""
            
        df = pd.read_csv(fileLocation)
            
        if "emg" in fileName:   
            if "-0-" in fileName:
                emgDataFrames['right'].append(df)
                emgleftctr+=1
            else:
                emgDataFrames['left'].append(df)
                emgrightctr+=1
        elif ("accelerometer") in fileName:
            if "-0-" in fileName:
                accDataFrames['right'].append(df)
                accleftctr+=1
            else:
                accDataFrames['left'].append(df)
                accrightctr+=1
        elif ("gyro") in fileName:
            if "-0-" in fileName:
                gyroDataFrames['right'].append(df)
                gyroleftctr+=1
            else:
                gyroDataFrames['left'].append(df)
                gyrorightctr+=1
    
    dataFrameDictionary["emg"] = emgDataFrames
    dataFrameDictionary["acc"] = accDataFrames
    dataFrameDictionary["gyro"] = gyroDataFrames

    listOfDataFramesPerClass[className] = dataFrameDictionary
    print("Total of " + str(emgleftctr) + " left arm emg files and " + str(emgrightctr) + " right arm emg files.")
    print("Total of " + str(accleftctr) + " left arm acc files and " + str(accrightctr) + " right arm acc files.")
    print("Total of " + str(gyroleftctr) + " left arm gyro files and " + str(gyrorightctr) + " right arm gyro files.")
    
print("DONE!")
# Out:
# ----------------- Word ano-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word asul-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word ate-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word baboy-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word dalawa-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word dito-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word hello-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word isa-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word isda-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word itim-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word ito-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word kanin-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word kayo-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word ko-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word kulay-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word kuya-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word large (shirt)-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word magkano-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word manok-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word mantika-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word medium (shirt)-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word nito-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word niyo-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word pagkain-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word pula-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word salamat-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word small (shirt)-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word softdrinks-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word sorry-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word tatlo-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# ----------------- Word tubig-----------------
# Total of 85 left arm emg files and 85 right arm emg files.
# Total of 85 left arm acc files and 85 right arm acc files.
# Total of 85 left arm gyro files and 85 right arm gyro files.
# DONE!

# %%
end

# %%
listOfTrimmedDataFramesPerClass = {}

for className in classNames:
    className = className.split("\\")[1]
    print("----------------- Word " + className + "-----------------")
    ctr = 0
    trimmedDataFramesPerClass = {}
    trimmedDataFramesPerClass['left'] = []
    trimmedDataFramesPerClass['right'] = []
    
    dataFrameDictionary = {}
    
    emgDataFrames = listOfDataFramesPerClass[className]['emg']
    accDataFrames = listOfDataFramesPerClass[className]['acc']
    gyroDataFrames = listOfDataFramesPerClass[className]['gyro']
    
    trimmedAccDataFrames = []
    trimmedGyroDataFrames = []
    trimmedEmgDataFrames = []

    
    for i in range(0,len(listOfDataFramesPerClass[className]['acc']['right'])):
        start = -1
        end = -1
        counter = 0
        print("---- %s ----" % i)

        for x in listOfDataFramesPerClass[className]['acc']['right'][i]['x']:  
            noend = False

            if(x < 0.85 and start ==-1):
                print(x)
                start = counter - 9
                if start < 0:
                    start = 0
            elif(start != -1 and x>0.90):
                end = counter + 9
                break;
                
            noend = True

            counter += 1
            
        if noend == True or end >= len(listOfDataFramesPerClass[className]['acc']['right'][i]['x']):
            print(" NO END")
            end = len(listOfDataFramesPerClass[className]['acc']['right'][i]['x'])-1
        

        startEmg = -1
        endEmg = -1
        counter2 = 0
        
        print("Start index: %s End index: %s" % (start, end))
        for t in emgDataFrames['right'][i]['timestamp']:
            noend = False
            if(t > accDataFrames['right'][i].loc[start]['timestamp'] and startEmg == -1):
                #print("%s > %f" % (t, accDataFrames['right'][i].loc[start]['timestamp']))
                startEmg = counter2
            elif(startEmg != -1 and t > accDataFrames['right'][i].loc[end]['timestamp']):
                #print("%s > %f" % (t, accDataFrames['right'][i].loc[end]['timestamp']))
                endEmg = counter2
                break;
                
            noend = True
            counter2 += 1
        
        if noend == True:
            print(" NO END")
            endEmg = len(listOfDataFramesPerClass[className]['emg']['right'][i]['timestamp'])-1
        
        newAccDf = {}
        newAccDf['right'] = accDataFrames['right'][i].loc[start:end]
        newAccDf['right'] = newAccDf['right'].reset_index(drop=True)
        newAccDf['left'] = accDataFrames['left'][i].loc[start:end]
        newAccDf['left'] = newAccDf['left'].reset_index(drop=True)
        
        newGyroDf = {}
        newGyroDf['right'] = gyroDataFrames['right'][i].loc[start:end]
        newGyroDf['right'] = newGyroDf['right'].reset_index(drop=True)
        newGyroDf['left'] = gyroDataFrames['left'][i].loc[start:end]
        newGyroDf['left'] = newGyroDf['left'].reset_index(drop=True)
        
        newEmgDf = {}
        newEmgDf['right'] = emgDataFrames['right'][i].loc[startEmg:endEmg]
        newEmgDf['right'] = newEmgDf['right'].reset_index(drop=True)
        newEmgDf['left'] = emgDataFrames['left'][i].loc[startEmg:endEmg]
        newEmgDf['left'] = newEmgDf['left'].reset_index(drop=True)

        trimmedAccDataFrames.append(newAccDf)
        trimmedGyroDataFrames.append(newGyroDf)
        trimmedEmgDataFrames.append(newEmgDf)
        
        print("Start emg index: %s End emg index: %s" % (startEmg, endEmg))
        
    dataFrameDictionary['acc'] = trimmedAccDataFrames
    dataFrameDictionary['gyro'] = trimmedGyroDataFrames
    dataFrameDictionary['emg'] = trimmedEmgDataFrames
        
    listOfTrimmedDataFramesPerClass[className] = dataFrameDictionary

        
    
    print("Done Trimming " + className + " " + str(ctr) + " files")
# Out:
# ----------------- Word ano-----------------
# ---- 0 ----
# 0.84668
# Start index: 30 End index: 145
# Start emg index: 82 End emg index: 540
# ---- 1 ----
# 0.843262
# Start index: 41 End index: 169
# Start emg index: 134 End emg index: 644
# ---- 2 ----
# 0.831055
# Start index: 50 End index: 175
# Start emg index: 168 End emg index: 666
# ---- 3 ----
# 0.797363
# Start index: 58 End index: 184
# Start emg index: 194 End emg index: 696
# ---- 4 ----
# 0.820801
# Start index: 35 End index: 151
# Start emg index: 110 End emg index: 572
# ---- 5 ----
# 0.762695
# Start index: 24 End index: 116
# Start emg index: 68 End emg index: 434
# ---- 6 ----
# 0.84668
# Start index: 6 End index: 123
# Start emg index: 0 End emg index: 464
# ---- 7 ----
# 0.832031
# Start index: 9 End index: 134
# Start emg index: 10 End emg index: 506
# ---- 8 ----
# 0.842773
# Start index: 13 End index: 134
# Start emg index: 22 End emg index: 508
# ---- 9 ----
# 0.841797
# Start index: 13 End index: 136
# Start emg index: 24 End emg index: 512
# ---- 10 ----
# 0.837891
# Start index: 21 End index: 131
# Start emg index: 54 End emg index: 492
# ---- 11 ----
# 0.804199
# Start index: 18 End index: 150
# Start emg index: 44 End emg index: 568
# ---- 12 ----
# 0.817383
# Start index: 12 End index: 143
# Start emg index: 22 End emg index: 542
# ---- 13 ----
# 0.820801
# Start index: 6 End index: 136
# Start emg index: 0 End emg index: 514
# ---- 14 ----
# 0.833008
# Start index: 4 End index: 139
# Start emg index: 0 End emg index: 522
# ---- 15 ----
# 0.804199
# Start index: 42 End index: 144
# Start emg index: 130 End emg index: 536
# ---- 16 ----
# 0.609863
# Start index: 19 End index: 133
# Start emg index: 36 End emg index: 490
# ---- 17 ----
# 0.719727
# Start index: 14 End index: 117
# Start emg index: 26 End emg index: 442
# ---- 18 ----
# 0.742676
# Start index: 10 End index: 120
# Start emg index: 14 End emg index: 452
# ---- 19 ----
# 0.695801
# Start index: 18 End index: 127
# Start emg index: 42 End emg index: 476
# ---- 20 ----
# 0.787109
# Start index: 55 End index: 159
# Start emg index: 186 End emg index: 600
# ---- 21 ----
# 0.736816
# Start index: 25 End index: 143
# Start emg index: 66 End emg index: 536
# ---- 22 ----
# 0.848145
# Start index: 37 End index: 161
# Start emg index: 118 End emg index: 612
# ---- 23 ----
# 0.823242
# Start index: 0 End index: 136
# Start emg index: 0 End emg index: 506
# ---- 24 ----
# 0.799805
# Start index: 41 End index: 178
# Start emg index: 130 End emg index: 674
# ---- 25 ----
# 0.573242
# Start index: 42 End index: 155
# Start emg index: 140 End emg index: 592
# ---- 26 ----
# 0.77832
# Start index: 0 End index: 135
# Start emg index: 0 End emg index: 510
# ---- 27 ----
# 0.830078
# Start index: 25 End index: 159
# Start emg index: 72 End emg index: 606
# ---- 28 ----
# 0.524414
# Start index: 0 End index: 129
# Start emg index: 0 End emg index: 486
# ---- 29 ----
# 0.810059
# Start index: 24 End index: 152
# Start emg index: 68 End emg index: 576
# ---- 30 ----
# 0.812012
# Start index: 68 End index: 186
# Start emg index: 242 End emg index: 712
# ---- 31 ----
# 0.833984
# Start index: 32 End index: 138
# Start emg index: 104 End emg index: 524
# ---- 32 ----
# 0.762207
# Start index: 28 End index: 129
# Start emg index: 86 End emg index: 486
# ---- 33 ----
# 0.820801
# Start index: 0 End index: 107
# Start emg index: 0 End emg index: 394
# ---- 34 ----
# 0.820313
# Start index: 1 End index: 102
# Start emg index: 0 End emg index: 376
# ---- 35 ----
# 0.823242
# Start index: 107 End index: 239
# Start emg index: 400 End emg index: 926
# ---- 36 ----
# 0.842285
# Start index: 26 End index: 158
# Start emg index: 72 End emg index: 596
# ---- 37 ----
# 0.827637
# Start index: 14 End index: 155
# Start emg index: 28 End emg index: 592
# ---- 38 ----
# 0.833984
# Start index: 25 End index: 156
# Start emg index: 68 End emg index: 590
# ---- 39 ----
# 0.836914
# Start index: 20 End index: 145
# Start emg index: 54 End emg index: 552
# ---- 40 ----
# 0.790039
# Start index: 27 End index: 133
# Start emg index: 82 End emg index: 504
# ---- 41 ----
# 0.790527
# Start index: 29 End index: 126
# Start emg index: 86 End emg index: 472
# ---- 42 ----
# 0.794922
# Start index: 20 End index: 124
# Start emg index: 52 End emg index: 466
# ---- 43 ----
# 0.800781
# Start index: 9 End index: 108
# Start emg index: 0 End emg index: 398
# ---- 44 ----
# 0.844727
# Start index: 3 End index: 105
# Start emg index: 0 End emg index: 392
# ---- 45 ----
# 0.765137
# Start index: 36 End index: 122
# Start emg index: 102 End emg index: 432
# ---- 46 ----
# 0.703125
# Start index: 44 End index: 127
# Start emg index: 132 End emg index: 438
# ---- 47 ----
# 0.166016
# Start index: 0 End index: 80
# Start emg index: 0 End emg index: 254
# ---- 48 ----
# 0.768555
# Start index: 7 End index: 103
# Start emg index: 0 End emg index: 326
# ---- 49 ----
# 0.244629
# Start index: 0 End index: 84
# Start emg index: 0 End emg index: 256
# ---- 50 ----
# 0.84375
# Start index: 46 End index: 124
# Start emg index: 190 End emg index: 474
# ---- 51 ----
# 0.816895
# Start index: 14 End index: 97
# Start emg index: 46 End emg index: 324
# ---- 52 ----
# 0.800781
# Start index: 7 End index: 106
# Start emg index: 0 End emg index: 404
# ---- 53 ----
# 0.837402
# Start index: 6 End index: 118
# Start emg index: 0 End emg index: 394
# ---- 54 ----
# 0.736328
# Start index: 3 End index: 96
# Start emg index: 0 End emg index: 382
# ---- 55 ----
# 0.745605
# Start index: 46 End index: 123
# Start emg index: 138 End emg index: 510
# ---- 56 ----
# 0.828125
# Start index: 22 End index: 101
# Start emg index: 52 End emg index: 376
# ---- 57 ----
# -0.30957
# Start index: 0 End index: 81
# Start emg index: 0 End emg index: 312
# ---- 58 ----
# 0.170898
# Start index: 0 End index: 81
# Start emg index: 0 End emg index: 284
# ---- 59 ----
# 0.828125
# Start index: 0 End index: 77
# Start emg index: 0 End emg index: 304
# ---- 60 ----
# 0.845703
# Start index: 30 End index: 165
# Start emg index: 80 End emg index: 612
# ---- 61 ----
# 0.793945
# Start index: 31 End index: 128
# Start emg index: 100 End emg index: 484
# ---- 62 ----
# 0.755371
# Start index: 13 End index: 112
# Start emg index: 18 End emg index: 392
# ---- 63 ----
# 0.833984
# Start index: 2 End index: 118
# Start emg index: 0 End emg index: 410
# ---- 64 ----
# 0.83252
#  NO END
# Start index: 2 End index: 114
#  NO END
# Start emg index: 0 End emg index: 445
# ---- 65 ----
# 0.746094
# Start index: 47 End index: 190
# Start emg index: 158 End emg index: 730
# ---- 66 ----
# 0.845703
# Start index: 30 End index: 172
# Start emg index: 90 End emg index: 656
# ---- 67 ----
# 0.767578
# Start index: 28 End index: 170
# Start emg index: 82 End emg index: 648
# ---- 68 ----
# 0.845703
# Start index: 1 End index: 160
# Start emg index: 0 End emg index: 614
# ---- 69 ----
# 0.822754
# Start index: 17 End index: 173
# Start emg index: 38 End emg index: 658
# ---- 70 ----
# 0.770996
# Start index: 71 End index: 203
# Start emg index: 254 End emg index: 780
# ---- 71 ----
# 0.816895
# Start index: 34 End index: 128
# Start emg index: 104 End emg index: 480
# ---- 72 ----
# 0.797363
# Start index: 35 End index: 129
# Start emg index: 112 End emg index: 486
# ---- 73 ----
# 0.834961
# Start index: 11 End index: 113
# Start emg index: 14 End emg index: 420
# ---- 74 ----
# 0.847168
# Start index: 10 End index: 101
# Start emg index: 16 End emg index: 376
# ---- 75 ----
# 0.822754
# Start index: 16 End index: 116
# Start emg index: 32 End emg index: 432
# ---- 76 ----
# 0.811035
# Start index: 0 End index: 12
# Start emg index: 0 End emg index: 22
# ---- 77 ----
# 0.749512
# Start index: 0 End index: 77
# Start emg index: 0 End emg index: 276
# ---- 78 ----
# 0.138672
# Start index: 0 End index: 81
# Start emg index: 0 End emg index: 292
# ---- 79 ----
# 0.697266
# Start index: 0 End index: 88
# Start emg index: 0 End emg index: 322
# ---- 80 ----
# 0.731445
# Start index: 39 End index: 123
# Start emg index: 130 End emg index: 468
# ---- 81 ----
# 0.635742
# Start index: 0 End index: 113
# Start emg index: 0 End emg index: 420
# ---- 82 ----
# 0.810547
# Start index: 18 End index: 116
# Start emg index: 48 End emg index: 438
# ---- 83 ----
# 0.810547
# Start index: 5 End index: 97
# Start emg index: 0 End emg index: 354
# ---- 84 ----
# 0.829102
# Start index: 0 End index: 89
# Start emg index: 0 End emg index: 328
# Done Trimming ano 0 files
# ----------------- Word asul-----------------
# ---- 0 ----
# 0.82959
# Start index: 34 End index: 139
# Start emg index: 104 End emg index: 522
# ---- 1 ----
# 0.82666
# Start index: 24 End index: 121
# Start emg index: 70 End emg index: 456
# ---- 2 ----
# 0.825684
# Start index: 20 End index: 118
# Start emg index: 54 End emg index: 444
# ---- 3 ----
# 0.841309
# Start index: 31 End index: 126
# Start emg index: 92 End emg index: 472
# ---- 4 ----
# 0.785645
# Start index: 27 End index: 128
# Start emg index: 82 End emg index: 484
# ---- 5 ----
# 0.806152
# Start index: 36 End index: 141
# Start emg index: 110 End emg index: 528
# ---- 6 ----
# 0.810059
# Start index: 16 End index: 137
# Start emg index: 34 End emg index: 516
# ---- 7 ----
# 0.825684
# Start index: 12 End index: 135
# Start emg index: 20 End emg index: 508
# ---- 8 ----
# 0.809082
# Start index: 4 End index: 130
# Start emg index: 0 End emg index: 494
# ---- 9 ----
# 0.833496
# Start index: 16 End index: 155
# Start emg index: 24 End emg index: 580
# ---- 10 ----
# 0.841797
# Start index: 23 End index: 139
# Start emg index: 64 End emg index: 526
# ---- 11 ----
# 0.8125
# Start index: 11 End index: 150
# Start emg index: 14 End emg index: 566
# ---- 12 ----
# 0.817383
# Start index: 1 End index: 122
# Start emg index: 0 End emg index: 462
# ---- 13 ----
# 0.794922
# Start index: 7 End index: 123
# Start emg index: 0 End emg index: 462
# ---- 14 ----
# 0.827637
# Start index: 52 End index: 164
# Start emg index: 178 End emg index: 624
# ---- 15 ----
# 0.740234
# Start index: 21 End index: 104
# Start emg index: 28 End emg index: 362
# ---- 16 ----
# 0.740234
# Start index: 15 End index: 120
# Start emg index: 28 End emg index: 448
# ---- 17 ----
# 0.683594
# Start index: 10 End index: 109
# Start emg index: 14 End emg index: 406
# ---- 18 ----
# 0.605469
# Start index: 15 End index: 112
# Start emg index: 34 End emg index: 418
# ---- 19 ----
# 0.736328
# Start index: 12 End index: 105
# Start emg index: 22 End emg index: 390
# ---- 20 ----
# 0.776367
# Start index: 35 End index: 158
# Start emg index: 106 End emg index: 596
# ---- 21 ----
# 0.805176
# Start index: 17 End index: 162
# Start emg index: 32 End emg index: 606
# ---- 22 ----
# 0.768555
# Start index: 34 End index: 171
# Start emg index: 106 End emg index: 652
# ---- 23 ----
# 0.797363
# Start index: 20 End index: 156
# Start emg index: 44 End emg index: 584
# ---- 24 ----
# 0.799805
#  NO END
# Start index: 25 End index: 152
#  NO END
# Start emg index: 60 End emg index: 561
# ---- 25 ----
# 0.796875
# Start index: 23 End index: 157
# Start emg index: 64 End emg index: 598
# ---- 26 ----
# 0.84082
# Start index: 17 End index: 144
# Start emg index: 36 End emg index: 542
# ---- 27 ----
# 0.834961
# Start index: 0 End index: 115
# Start emg index: 0 End emg index: 432
# ---- 28 ----
# 0.826172
# Start index: 19 End index: 149
# Start emg index: 48 End emg index: 564
# ---- 29 ----
# 0.806641
# Start index: 17 End index: 149
# Start emg index: 42 End emg index: 568
# ---- 30 ----
# 0.788086
# Start index: 29 End index: 164
# Start emg index: 80 End emg index: 618
# ---- 31 ----
# 0.817383
# Start index: 10 End index: 157
# Start emg index: 12 End emg index: 596
# ---- 32 ----
# 0.837402
# Start index: 25 End index: 158
# Start emg index: 66 End emg index: 596
# ---- 33 ----
# 0.722168
# Start index: 18 End index: 138
# Start emg index: 42 End emg index: 520
# ---- 34 ----
# 0.791016
# Start index: 11 End index: 144
# Start emg index: 10 End emg index: 538
# ---- 35 ----
# 0.795898
# Start index: 33 End index: 156
# Start emg index: 106 End emg index: 596
# ---- 36 ----
# 0.835938
# Start index: 22 End index: 147
# Start emg index: 56 End emg index: 554
# ---- 37 ----
# 0.833496
# Start index: 27 End index: 152
# Start emg index: 82 End emg index: 580
# ---- 38 ----
# 0.82666
# Start index: 12 End index: 138
# Start emg index: 22 End emg index: 522
# ---- 39 ----
# 0.816895
# Start index: 21 End index: 138
# Start emg index: 58 End emg index: 524
# ---- 40 ----
# 0.827637
# Start index: 0 End index: 118
# Start emg index: 0 End emg index: 440
# ---- 41 ----
# 0.847168
# Start index: 15 End index: 121
# Start emg index: 32 End emg index: 456
# ---- 42 ----
# 0.538086
# Start index: 0 End index: 96
# Start emg index: 0 End emg index: 360
# ---- 43 ----
# 0.824707
# Start index: 17 End index: 122
# Start emg index: 36 End emg index: 456
# ---- 44 ----
# 0.838379
# Start index: 20 End index: 121
# Start emg index: 52 End emg index: 454
# ---- 45 ----
# 0.78418
# Start index: 19 End index: 114
# Start emg index: 42 End emg index: 352
# ---- 46 ----
# 0.79541
# Start index: 0 End index: 82
# Start emg index: 0 End emg index: 292
# ---- 47 ----
# 0.847168
# Start index: 0 End index: 76
# Start emg index: 0 End emg index: 314
# ---- 48 ----
# 0.83252
#  NO END
# Start index: 5 End index: 98
# Start emg index: 0 End emg index: 310
# ---- 49 ----
# 0.727539
# Start index: 0 End index: 90
# Start emg index: 0 End emg index: 338
# ---- 50 ----
# 0.686523
# Start index: 20 End index: 114
# Start emg index: 46 End emg index: 348
# ---- 51 ----
# 0.842285
#  NO END
# Start index: 21 End index: 136
#  NO END
# Start emg index: 72 End emg index: 495
# ---- 52 ----
# 0.816406
# Start index: 2 End index: 97
# Start emg index: 0 End emg index: 404
# ---- 53 ----
# 0.812012
# Start index: 0 End index: 95
# Start emg index: 0 End emg index: 378
# ---- 54 ----
# 0.791016
# Start index: 0 End index: 101
# Start emg index: 0 End emg index: 326
# ---- 55 ----
# 0.830566
# Start index: 4 End index: 108
# Start emg index: 0 End emg index: 346
# ---- 56 ----
# 0.849609
# Start index: 4 End index: 85
# Start emg index: 0 End emg index: 394
# ---- 57 ----
# 0.660156
# Start index: 13 End index: 102
# Start emg index: 24 End emg index: 388
# ---- 58 ----
# 0.813965
# Start index: 0 End index: 82
# Start emg index: 0 End emg index: 344
# ---- 59 ----
# 0.746094
# Start index: 0 End index: 88
# Start emg index: 0 End emg index: 276
# ---- 60 ----
# 0.831055
# Start index: 7 End index: 105
# Start emg index: 0 End emg index: 418
# ---- 61 ----
# 0.8125
# Start index: 1 End index: 126
# Start emg index: 0 End emg index: 402
# ---- 62 ----
# 0.847168
# Start index: 0 End index: 22
# Start emg index: 0 End emg index: 58
# ---- 63 ----
# 0.791992
# Start index: 0 End index: 110
# Start emg index: 0 End emg index: 410
# ---- 64 ----
# 0.849609
# Start index: 0 End index: 21
# Start emg index: 0 End emg index: 54
# ---- 65 ----
# 0.84082
# Start index: 26 End index: 148
# Start emg index: 76 End emg index: 562
# ---- 66 ----
# 0.737305
# Start index: 5 End index: 129
# Start emg index: 0 End emg index: 488
# ---- 67 ----
# 0.838379
# Start index: 0 End index: 136
# Start emg index: 0 End emg index: 514
# ---- 68 ----
# 0.84082
# Start index: 13 End index: 155
# Start emg index: 24 End emg index: 588
# ---- 69 ----
# 0.794434
# Start index: 10 End index: 143
# Start emg index: 12 End emg index: 542
# ---- 70 ----
# 0.799805
# Start index: 23 End index: 131
# Start emg index: 64 End emg index: 492
# ---- 71 ----
# 0.836426
# Start index: 22 End index: 125
# Start emg index: 60 End emg index: 474
# ---- 72 ----
# 0.822266
# Start index: 21 End index: 122
# Start emg index: 60 End emg index: 462
# ---- 73 ----
# 0.788086
# Start index: 11 End index: 112
# Start emg index: 18 End emg index: 420
# ---- 74 ----
# 0.845215
# Start index: 17 End index: 130
# Start emg index: 42 End emg index: 492
# ---- 75 ----
# 0.772461
# Start index: 10 End index: 94
# Start emg index: 14 End emg index: 346
# ---- 76 ----
# 0.767578
# Start index: 0 End index: 80
# Start emg index: 0 End emg index: 286
# ---- 77 ----
# 0.766602
# Start index: 0 End index: 92
# Start emg index: 0 End emg index: 338
# ---- 78 ----
# 0.838867
# Start index: 9 End index: 28
# Start emg index: 10 End emg index: 84
# ---- 79 ----
# 0.770508
# Start index: 12 End index: 100
# Start emg index: 22 End emg index: 372
# ---- 80 ----
# 0.817871
# Start index: 33 End index: 118
# Start emg index: 106 End emg index: 444
# ---- 81 ----
# 0.801758
# Start index: 10 End index: 108
# Start emg index: 14 End emg index: 402
# ---- 82 ----
# 0.763184
# Start index: 17 End index: 128
# Start emg index: 40 End emg index: 482
# ---- 83 ----
# 0.82373
# Start index: 13 End index: 121
# Start emg index: 24 End emg index: 452
# ---- 84 ----
# 0.76416
# Start index: 20 End index: 107
# Start emg index: 52 End emg index: 398
# Done Trimming asul 0 files
# ----------------- Word ate-----------------
# ---- 0 ----
# 0.797363
# Start index: 26 End index: 124
# Start emg index: 70 End emg index: 460
# ---- 1 ----
# 0.778809
# Start index: 24 End index: 131
# Start emg index: 64 End emg index: 490
# ---- 2 ----
# 0.839355
# Start index: 29 End index: 132
# Start emg index: 86 End emg index: 496
# ---- 3 ----
# 0.751953
# Start index: 23 End index: 121
# Start emg index: 60 End emg index: 450
# ---- 4 ----
# 0.775879
# Start index: 23 End index: 129
# Start emg index: 60 End emg index: 482
# ---- 5 ----
# 0.831543
# Start index: 32 End index: 144
# Start emg index: 102 End emg index: 550
# ---- 6 ----
# 0.842285
# Start index: 28 End index: 148
# Start emg index: 82 End emg index: 562
# ---- 7 ----
# 0.82373
# Start index: 28 End index: 152
# Start emg index: 82 End emg index: 576
# ---- 8 ----
# 0.842285
# Start index: 28 End index: 163
# Start emg index: 78 End emg index: 616
# ---- 9 ----
# 0.811035
# Start index: 27 End index: 168
# Start emg index: 76 End emg index: 638
# ---- 10 ----
# 0.809082
# Start index: 13 End index: 65
# Start emg index: 22 End emg index: 232
# ---- 11 ----
# 0.829102
# Start index: 0 End index: 50
# Start emg index: 0 End emg index: 172
# ---- 12 ----
# 0.810547
# Start index: 3 End index: 70
# Start emg index: 0 End emg index: 244
# ---- 13 ----
# 0.833008
# Start index: 1 End index: 103
# Start emg index: 0 End emg index: 380
# ---- 14 ----
# 0.848145
# Start index: 0 End index: 63
# Start emg index: 0 End emg index: 222
# ---- 15 ----
# 0.648438
# Start index: 20 End index: 104
# Start emg index: 44 End emg index: 378
# ---- 16 ----
# 0.817871
# Start index: 17 End index: 100
# Start emg index: 28 End emg index: 354
# ---- 17 ----
# 0.609863
# Start index: 13 End index: 98
# Start emg index: 0 End emg index: 342
# ---- 18 ----
# 0.745605
# Start index: 8 End index: 83
# Start emg index: 0 End emg index: 292
# ---- 19 ----
# 0.737793
# Start index: 2 End index: 84
# Start emg index: 0 End emg index: 298
# ---- 20 ----
# 0.849609
# Start index: 23 End index: 115
# Start emg index: 54 End emg index: 420
# ---- 21 ----
# 0.821777
# Start index: 25 End index: 143
# Start emg index: 68 End emg index: 536
# ---- 22 ----
# 0.844727
# Start index: 11 End index: 119
# Start emg index: 16 End emg index: 446
# ---- 23 ----
# 0.836426
# Start index: 26 End index: 148
# Start emg index: 62 End emg index: 548
# ---- 24 ----
# 0.836914
# Start index: 29 End index: 169
# Start emg index: 80 End emg index: 634
# ---- 25 ----
# 0.773438
# Start index: 36 End index: 125
# Start emg index: 116 End emg index: 470
# ---- 26 ----
# 0.842285
# Start index: 30 End index: 117
# Start emg index: 88 End emg index: 432
# ---- 27 ----
# 0.758301
# Start index: 32 End index: 126
# Start emg index: 102 End emg index: 476
# ---- 28 ----
# 0.817871
# Start index: 10 End index: 114
# Start emg index: 12 End emg index: 426
# ---- 29 ----
# 0.788574
# Start index: 5 End index: 105
# Start emg index: 0 End emg index: 392
# ---- 30 ----
# 0.773438
# Start index: 24 End index: 130
# Start emg index: 72 End emg index: 494
# ---- 31 ----
# 0.828125
# Start index: 14 End index: 118
# Start emg index: 24 End emg index: 440
# ---- 32 ----
# 0.754395
# Start index: 0 End index: 98
# Start emg index: 0 End emg index: 362
# ---- 33 ----
# 0.796387
# Start index: 11 End index: 111
# Start emg index: 16 End emg index: 412
# ---- 34 ----
# 0.830566
# Start index: 13 End index: 103
# Start emg index: 24 End emg index: 384
# ---- 35 ----
# 0.839355
# Start index: 18 End index: 118
# Start emg index: 42 End emg index: 438
# ---- 36 ----
# 0.849121
# Start index: 32 End index: 124
# Start emg index: 98 End emg index: 464
# ---- 37 ----
# 0.845703
# Start index: 21 End index: 113
# Start emg index: 58 End emg index: 424
# ---- 38 ----
# 0.847168
# Start index: 14 End index: 103
# Start emg index: 24 End emg index: 384
# ---- 39 ----
# 0.826172
# Start index: 9 End index: 94
# Start emg index: 2 End emg index: 344
# ---- 40 ----
# 0.841309
# Start index: 24 End index: 105
# Start emg index: 70 End emg index: 392
# ---- 41 ----
# 0.730957
# Start index: 16 End index: 103
# Start emg index: 38 End emg index: 382
# ---- 42 ----
# 0.791504
# Start index: 0 End index: 94
# Start emg index: 0 End emg index: 340
# ---- 43 ----
# 0.774902
#  NO END
# Start index: 16 End index: 127
#  NO END
# Start emg index: 36 End emg index: 479
# ---- 44 ----
# 0.798828
# Start index: 16 End index: 133
# Start emg index: 36 End emg index: 502
# ---- 45 ----
# 0.699219
# Start index: 7 End index: 96
# Start emg index: 0 End emg index: 376
# ---- 46 ----
# 0.458008
# Start index: 0 End index: 82
# Start emg index: 0 End emg index: 250
# ---- 47 ----
# 0.801758
# Start index: 0 End index: 95
# Start emg index: 0 End emg index: 292
# ---- 48 ----
# 0.820801
# Start index: 0 End index: 88
# Start emg index: 0 End emg index: 286
# ---- 49 ----
# 0.835938
#  NO END
# Start index: 0 End index: 79
# Start emg index: 0 End emg index: 280
# ---- 50 ----
# 0.815918
# Start index: 9 End index: 102
# Start emg index: 10 End emg index: 306
# ---- 51 ----
# -0.14502
# Start index: 0 End index: 82
# Start emg index: 0 End emg index: 290
# ---- 52 ----
# 0.845703
# Start index: 1 End index: 118
# Start emg index: 0 End emg index: 368
# ---- 53 ----
# 0.813965
# Start index: 0 End index: 94
# Start emg index: 0 End emg index: 304
# ---- 54 ----
# 0.835449
# Start index: 2 End index: 97
# Start emg index: 0 End emg index: 302
# ---- 55 ----
# 0.67334
# Start index: 3 End index: 76
# Start emg index: 0 End emg index: 308
# ---- 56 ----
# 0.689453
# Start index: 8 End index: 73
# Start emg index: 8 End emg index: 292
# ---- 57 ----
# 0.673828
# Start index: 3 End index: 31
# Start emg index: 0 End emg index: 132
# ---- 58 ----
# 0.849609
# Start index: 11 End index: 84
# Start emg index: 14 End emg index: 310
# ---- 59 ----
# 0.750977
# Start index: 6 End index: 86
# Start emg index: 0 End emg index: 330
# ---- 60 ----
# 0.841797
# Start index: 24 End index: 102
# Start emg index: 58 End emg index: 322
# ---- 61 ----
# 0.276367
# Start index: 0 End index: 95
# Start emg index: 0 End emg index: 322
# ---- 62 ----
# 0.815918
#  NO END
# Start index: 0 End index: 90
#  NO END
# Start emg index: 0 End emg index: 345
# ---- 63 ----
# 0.777832
# Start index: 16 End index: 125
# Start emg index: 36 End emg index: 404
# ---- 64 ----
# 0.822754
# Start index: 0 End index: 95
# Start emg index: 0 End emg index: 282
# ---- 65 ----
# 0.839355
# Start index: 12 End index: 149
# Start emg index: 22 End emg index: 566
# ---- 66 ----
# 0.751953
# Start index: 4 End index: 127
# Start emg index: 0 End emg index: 480
# ---- 67 ----
# 0.248535
# Start index: 0 End index: 131
# Start emg index: 0 End emg index: 496
# ---- 68 ----
# -0.211914
# Start index: 0 End index: 134
# Start emg index: 0 End emg index: 506
# ---- 69 ----
# 0.812988
# Start index: 6 End index: 161
# Start emg index: 0 End emg index: 614
# ---- 70 ----
# 0.796875
# Start index: 24 End index: 138
# Start emg index: 66 End emg index: 522
# ---- 71 ----
# 0.785645
# Start index: 15 End index: 117
# Start emg index: 36 End emg index: 444
# ---- 72 ----
# 0.775879
# Start index: 16 End index: 115
# Start emg index: 38 End emg index: 432
# ---- 73 ----
# 0.726563
# Start index: 25 End index: 191
# Start emg index: 72 End emg index: 734
# ---- 74 ----
# 0.73291
# Start index: 11 End index: 102
# Start emg index: 20 End emg index: 382
# ---- 75 ----
# 0.795898
# Start index: 18 End index: 90
# Start emg index: 42 End emg index: 328
# ---- 76 ----
# 0.799316
# Start index: 10 End index: 106
# Start emg index: 12 End emg index: 392
# ---- 77 ----
# 0.848633
# Start index: 5 End index: 108
# Start emg index: 0 End emg index: 404
# ---- 78 ----
# 0.818848
# Start index: 8 End index: 99
# Start emg index: 10 End emg index: 366
# ---- 79 ----
# 0.766602
# Start index: 0 End index: 101
# Start emg index: 0 End emg index: 374
# ---- 80 ----
# 0.729492
# Start index: 22 End index: 133
# Start emg index: 62 End emg index: 504
# ---- 81 ----
# 0.763184
# Start index: 6 End index: 108
# Start emg index: 0 End emg index: 402
# ---- 82 ----
# 0.848633
# Start index: 7 End index: 118
# Start emg index: 0 End emg index: 442
# ---- 83 ----
# 0.76416
# Start index: 24 End index: 133
# Start emg index: 68 End emg index: 504
# ---- 84 ----
# 0.72998
# Start index: 13 End index: 120
# Start emg index: 24 End emg index: 452
# Done Trimming ate 0 files
# ----------------- Word baboy-----------------
# ---- 0 ----
# 0.806641
# Start index: 28 End index: 130
# Start emg index: 78 End emg index: 484
# ---- 1 ----
# 0.841309
# Start index: 24 End index: 127
# Start emg index: 70 End emg index: 480
# ---- 2 ----
# 0.794434
# Start index: 22 End index: 132
# Start emg index: 56 End emg index: 494
# ---- 3 ----
# 0.839355
# Start index: 23 End index: 133
# Start emg index: 60 End emg index: 498
# ---- 4 ----
# 0.700195
# Start index: 21 End index: 123
# Start emg index: 56 End emg index: 464
# ---- 5 ----
# 0.808594
# Start index: 31 End index: 172
# Start emg index: 96 End emg index: 658
# ---- 6 ----
# 0.84668
# Start index: 27 End index: 177
# Start emg index: 82 End emg index: 682
# ---- 7 ----
# 0.84082
# Start index: 35 End index: 193
# Start emg index: 106 End emg index: 736
# ---- 8 ----
# 0.84082
# Start index: 39 End index: 187
# Start emg index: 126 End emg index: 712
# ---- 9 ----
# 0.846191
# Start index: 45 End index: 236
# Start emg index: 150 End emg index: 912
# ---- 10 ----
# 0.67627
# Start index: 18 End index: 144
# Start emg index: 44 End emg index: 544
# ---- 11 ----
# 0.813965
# Start index: 1 End index: 133
# Start emg index: 0 End emg index: 502
# ---- 12 ----
# 0.80957
# Start index: 0 End index: 134
# Start emg index: 0 End emg index: 510
# ---- 13 ----
# 0.792969
# Start index: 14 End index: 164
# Start emg index: 30 End emg index: 626
# ---- 14 ----
# 0.816406
# Start index: 6 End index: 147
# Start emg index: 0 End emg index: 558
# ---- 15 ----
# 0.816895
# Start index: 8 End index: 116
# Start emg index: 0 End emg index: 410
# ---- 16 ----
# 0.740234
# Start index: 0 End index: 101
# Start emg index: 0 End emg index: 368
# ---- 17 ----
# 0.682129
# Start index: 11 End index: 127
# Start emg index: 0 End emg index: 450
# ---- 18 ----
# 0.746094
# Start index: 3 End index: 114
# Start emg index: 0 End emg index: 406
# ---- 19 ----
# 0.615723
# Start index: 0 End index: 108
# Start emg index: 0 End emg index: 396
# ---- 20 ----
# 0.794922
# Start index: 12 End index: 139
# Start emg index: 20 End emg index: 524
# ---- 21 ----
# 0.847168
# Start index: 0 End index: 134
# Start emg index: 0 End emg index: 500
# ---- 22 ----
# 0.825195
# Start index: 12 End index: 150
# Start emg index: 16 End emg index: 562
# ---- 23 ----
# 0.835938
# Start index: 27 End index: 168
# Start emg index: 76 End emg index: 638
# ---- 24 ----
# 0.780762
# Start index: 34 End index: 181
# Start emg index: 106 End emg index: 692
# ---- 25 ----
# 0.830566
# Start index: 14 End index: 171
# Start emg index: 26 End emg index: 650
# ---- 26 ----
# 0.844238
# Start index: 6 End index: 142
# Start emg index: 0 End emg index: 536
# ---- 27 ----
# 0.791504
# Start index: 27 End index: 163
# Start emg index: 78 End emg index: 620
# ---- 28 ----
# 0.804688
# Start index: 32 End index: 184
# Start emg index: 96 End emg index: 702
# ---- 29 ----
# 0.834473
# Start index: 35 End index: 188
# Start emg index: 112 End emg index: 722
# ---- 30 ----
# 0.828125
# Start index: 29 End index: 153
# Start emg index: 86 End emg index: 580
# ---- 31 ----
# 0.765625
# Start index: 25 End index: 160
# Start emg index: 70 End emg index: 608
# ---- 32 ----
# 0.796387
# Start index: 15 End index: 145
# Start emg index: 22 End emg index: 546
# ---- 33 ----
# 0.810059
# Start index: 16 End index: 150
# Start emg index: 36 End emg index: 568
# ---- 34 ----
# 0.827148
# Start index: 0 End index: 124
# Start emg index: 0 End emg index: 466
# ---- 35 ----
# 0.818848
# Start index: 20 End index: 140
# Start emg index: 48 End emg index: 526
# ---- 36 ----
# 0.84375
# Start index: 13 End index: 139
# Start emg index: 20 End emg index: 526
# ---- 37 ----
# 0.800293
# Start index: 9 End index: 140
# Start emg index: 12 End emg index: 532
# ---- 38 ----
# 0.830566
# Start index: 17 End index: 131
# Start emg index: 38 End emg index: 492
# ---- 39 ----
# 0.720215
# Start index: 22 End index: 146
# Start emg index: 60 End emg index: 552
# ---- 40 ----
# 0.818848
# Start index: 4 End index: 131
# Start emg index: 0 End emg index: 494
# ---- 41 ----
# 0.661133
# Start index: 0 End index: 120
# Start emg index: 0 End emg index: 450
# ---- 42 ----
# 0.806641
# Start index: 3 End index: 131
# Start emg index: 0 End emg index: 492
# ---- 43 ----
# 0.399414
# Start index: 0 End index: 106
# Start emg index: 0 End emg index: 396
# ---- 44 ----
# 0.182129
# Start index: 0 End index: 108
# Start emg index: 0 End emg index: 398
# ---- 45 ----
# 0.828125
# Start index: 0 End index: 15
# Start emg index: 0 End emg index: 22
# ---- 46 ----
# 0.786621
#  NO END
# Start index: 0 End index: 110
# Start emg index: 0 End emg index: 372
# ---- 47 ----
# 0.814453
# Start index: 0 End index: 98
# Start emg index: 0 End emg index: 412
# ---- 48 ----
# 0.537109
# Start index: 0 End index: 98
# Start emg index: 0 End emg index: 346
# ---- 49 ----
# 0.849121
#  NO END
# Start index: 1 End index: 93
# Start emg index: 0 End emg index: 350
# ---- 50 ----
# 0.73584
# Start index: 13 End index: 128
# Start emg index: 24 End emg index: 448
# ---- 51 ----
# 0.8125
# Start index: 4 End index: 136
# Start emg index: 0 End emg index: 490
# ---- 52 ----
# 0.777344
# Start index: 17 End index: 154
# Start emg index: 36 End emg index: 488
# ---- 53 ----
# 0.80127
# Start index: 0 End index: 118
# Start emg index: 0 End emg index: 460
# ---- 54 ----
# 0.759766
# Start index: 10 End index: 148
# Start emg index: 16 End emg index: 556
# ---- 55 ----
# 0.809082
# Start index: 6 End index: 88
# Start emg index: 0 End emg index: 372
# ---- 56 ----
# 0.821289
# Start index: 4 End index: 107
# Start emg index: 0 End emg index: 322
# ---- 57 ----
# 0.657715
# Start index: 4 End index: 95
# Start emg index: 0 End emg index: 386
# ---- 58 ----
# 0.762695
# Start index: 20 End index: 106
# Start emg index: 46 End emg index: 384
# ---- 59 ----
# 0.848145
# Start index: 10 End index: 115
# Start emg index: 16 End emg index: 368
# ---- 60 ----
# 0.847168
# Start index: 2 End index: 28
# Start emg index: 0 End emg index: 74
# ---- 61 ----
# 0.65625
# Start index: 40 End index: 150
# Start emg index: 128 End emg index: 492
# ---- 62 ----
# 0.836426
# Start index: 2 End index: 115
# Start emg index: 0 End emg index: 400
# ---- 63 ----
# 0.757324
# Start index: 9 End index: 106
# Start emg index: 10 End emg index: 454
# ---- 64 ----
# 0.787109
# Start index: 10 End index: 130
# Start emg index: 14 End emg index: 446
# ---- 65 ----
# 0.82373
# Start index: 29 End index: 169
# Start emg index: 88 End emg index: 646
# ---- 66 ----
# 0.736328
# Start index: 8 End index: 154
# Start emg index: 2 End emg index: 584
# ---- 67 ----
# 0.709473
# Start index: 0 End index: 143
# Start emg index: 0 End emg index: 540
# ---- 68 ----
# 0.819824
# Start index: 1 End index: 165
# Start emg index: 0 End emg index: 630
# ---- 69 ----
# 0.761719
# Start index: 12 End index: 159
# Start emg index: 22 End emg index: 604
# ---- 70 ----
# 0.785645
# Start index: 15 End index: 123
# Start emg index: 30 End emg index: 460
# ---- 71 ----
# 0.706543
# Start index: 20 End index: 122
# Start emg index: 54 End emg index: 464
# ---- 72 ----
# 0.834473
# Start index: 3 End index: 111
# Start emg index: 0 End emg index: 416
# ---- 73 ----
# 0.762695
# Start index: 13 End index: 113
# Start emg index: 24 End emg index: 422
# ---- 74 ----
# 0.710938
# Start index: 9 End index: 101
# Start emg index: 14 End emg index: 376
# ---- 75 ----
# 0.815918
# Start index: 1 End index: 114
# Start emg index: 0 End emg index: 430
# ---- 76 ----
# 0.842773
# Start index: 1 End index: 116
# Start emg index: 0 End emg index: 432
# ---- 77 ----
# 0.79248
# Start index: 0 End index: 99
# Start emg index: 0 End emg index: 366
# ---- 78 ----
# 0.67041
# Start index: 11 End index: 111
# Start emg index: 16 End emg index: 414
# ---- 79 ----
# 0.758789
# Start index: 4 End index: 104
# Start emg index: 0 End emg index: 384
# ---- 80 ----
# 0.681641
# Start index: 6 End index: 97
# Start emg index: 0 End emg index: 362
# ---- 81 ----
# 0.792969
# Start index: 21 End index: 118
# Start emg index: 56 End emg index: 442
# ---- 82 ----
# 0.80127
# Start index: 26 End index: 126
# Start emg index: 78 End emg index: 478
# ---- 83 ----
# 0.838867
# Start index: 18 End index: 114
# Start emg index: 46 End emg index: 426
# ---- 84 ----
# 0.835449
# Start index: 56 End index: 140
# Start emg index: 238 End emg index: 530
# Done Trimming baboy 0 files
# ----------------- Word dalawa-----------------
# ---- 0 ----
# 0.746094
# Start index: 23 End index: 105
# Start emg index: 54 End emg index: 380
# ---- 1 ----
# 0.768066
# Start index: 24 End index: 125
# Start emg index: 62 End emg index: 464
# ---- 2 ----
# 0.832031
# Start index: 28 End index: 128
# Start emg index: 82 End emg index: 480
# ---- 3 ----
# 0.79541
# Start index: 27 End index: 132
# Start emg index: 80 End emg index: 498
# ---- 4 ----
# 0.753906
# Start index: 20 End index: 127
# Start emg index: 46 End emg index: 472
# ---- 5 ----
# 0.789063
# Start index: 39 End index: 136
# Start emg index: 128 End emg index: 516
# ---- 6 ----
# 0.78125
# Start index: 24 End index: 128
# Start emg index: 70 End emg index: 484
# ---- 7 ----
# 0.811035
# Start index: 12 End index: 107
# Start emg index: 22 End emg index: 398
# ---- 8 ----
# 0.844238
# Start index: 11 End index: 116
# Start emg index: 18 End emg index: 432
# ---- 9 ----
# 0.82666
# Start index: 16 End index: 122
# Start emg index: 34 End emg index: 458
# ---- 10 ----
# 0.814453
# Start index: 19 End index: 107
# Start emg index: 48 End emg index: 400
# ---- 11 ----
# 0.818359
# Start index: 8 End index: 104
# Start emg index: 8 End emg index: 388
# ---- 12 ----
# 0.842285
# Start index: 8 End index: 125
# Start emg index: 8 End emg index: 472
# ---- 13 ----
# 0.803223
# Start index: 22 End index: 143
# Start emg index: 56 End emg index: 538
# ---- 14 ----
# 0.796875
# Start index: 8 End index: 128
# Start emg index: 0 End emg index: 482
# ---- 15 ----
# 0.763672
# Start index: 0 End index: 19
# Start emg index: 0 End emg index: 38
# ---- 16 ----
# 0.821777
# Start index: 0 End index: 14
# Start emg index: 0 End emg index: 16
# ---- 17 ----
# 0.835449
# Start index: 6 End index: 77
# Start emg index: 0 End emg index: 260
# ---- 18 ----
# 0.841797
# Start index: 8 End index: 86
# Start emg index: 0 End emg index: 306
# ---- 19 ----
# 0.823242
# Start index: 12 End index: 96
# Start emg index: 10 End emg index: 342
# ---- 20 ----
# 0.654785
# Start index: 0 End index: 83
# Start emg index: 0 End emg index: 294
# ---- 21 ----
# 0.824219
# Start index: 21 End index: 125
# Start emg index: 50 End emg index: 464
# ---- 22 ----
# 0.849609
# Start index: 6 End index: 113
# Start emg index: 0 End emg index: 418
# ---- 23 ----
# 0.842773
# Start index: 19 End index: 113
# Start emg index: 46 End emg index: 420
# ---- 24 ----
# 0.845215
# Start index: 16 End index: 117
# Start emg index: 36 End emg index: 438
# ---- 25 ----
# 0.824707
# Start index: 0 End index: 98
# Start emg index: 0 End emg index: 362
# ---- 26 ----
# 0.830566
# Start index: 3 End index: 120
# Start emg index: 0 End emg index: 448
# ---- 27 ----
# 0.765137
# Start index: 30 End index: 133
# Start emg index: 90 End emg index: 500
# ---- 28 ----
# 0.779785
# Start index: 7 End index: 110
# Start emg index: 0 End emg index: 408
# ---- 29 ----
# 0.820801
# Start index: 16 End index: 114
# Start emg index: 36 End emg index: 426
# ---- 30 ----
# 0.841797
# Start index: 27 End index: 115
# Start emg index: 76 End emg index: 428
# ---- 31 ----
# 0.827637
# Start index: 16 End index: 106
# Start emg index: 38 End emg index: 398
# ---- 32 ----
# 0.838379
# Start index: 2 End index: 109
# Start emg index: 0 End emg index: 404
# ---- 33 ----
# 0.83252
# Start index: 11 End index: 99
# Start emg index: 18 End emg index: 366
# ---- 34 ----
# 0.768066
# Start index: 0 End index: 81
# Start emg index: 0 End emg index: 294
# ---- 35 ----
# 0.84668
# Start index: 21 End index: 131
# Start emg index: 56 End emg index: 494
# ---- 36 ----
# 0.800781
# Start index: 28 End index: 138
# Start emg index: 78 End emg index: 516
# ---- 37 ----
# 0.777832
# Start index: 15 End index: 116
# Start emg index: 36 End emg index: 436
# ---- 38 ----
# 0.828613
# Start index: 24 End index: 134
# Start emg index: 66 End emg index: 504
# ---- 39 ----
# 0.799805
# Start index: 8 End index: 120
# Start emg index: 0 End emg index: 446
# ---- 40 ----
# 0.811035
# Start index: 32 End index: 127
# Start emg index: 102 End emg index: 478
# ---- 41 ----
# 0.839844
# Start index: 25 End index: 131
# Start emg index: 66 End emg index: 488
# ---- 42 ----
# 0.84668
# Start index: 15 End index: 126
# Start emg index: 32 End emg index: 474
# ---- 43 ----
# 0.780762
# Start index: 10 End index: 106
# Start emg index: 12 End emg index: 396
# ---- 44 ----
# 0.765137
# Start index: 27 End index: 124
# Start emg index: 80 End emg index: 468
# ---- 45 ----
# 0.8125
# Start index: 2 End index: 100
# Start emg index: 0 End emg index: 378
# ---- 46 ----
# 0.831543
# Start index: 0 End index: 99
# Start emg index: 0 End emg index: 310
# ---- 47 ----
# 0.840332
# Start index: 0 End index: 104
# Start emg index: 0 End emg index: 370
# ---- 48 ----
# 0.835449
# Start index: 0 End index: 85
# Start emg index: 0 End emg index: 338
# ---- 49 ----
# 0.803223
#  NO END
# Start index: 0 End index: 69
#  NO END
# Start emg index: 0 End emg index: 247
# ---- 50 ----
# 0.849121
# Start index: 12 End index: 32
# Start emg index: 20 End emg index: 102
# ---- 51 ----
# 0.827637
# Start index: 0 End index: 91
# Start emg index: 0 End emg index: 300
# ---- 52 ----
# 0.719727
# Start index: 0 End index: 90
# Start emg index: 0 End emg index: 328
# ---- 53 ----
# 0.831055
# Start index: 0 End index: 109
# Start emg index: 0 End emg index: 340
# ---- 54 ----
# 0.849121
#  NO END
# Start index: 0 End index: 105
# Start emg index: 0 End emg index: 348
# ---- 55 ----
# 0.779297
# Start index: 8 End index: 88
# Start emg index: 8 End emg index: 334
# ---- 56 ----
# 0.804688
# Start index: 30 End index: 108
# Start emg index: 82 End emg index: 392
# ---- 57 ----
# 0.848145
# Start index: 3 End index: 84
# Start emg index: 0 End emg index: 278
# ---- 58 ----
# 0.843262
# Start index: 5 End index: 100
# Start emg index: 0 End emg index: 320
# ---- 59 ----
# 0.815918
# Start index: 28 End index: 121
# Start emg index: 66 End emg index: 370
# ---- 60 ----
# 0.845703
# Start index: 10 End index: 116
# Start emg index: 18 End emg index: 492
# ---- 61 ----
# 0.766113
# Start index: 20 End index: 97
# Start emg index: 48 End emg index: 336
# ---- 62 ----
# 0.812988
# Start index: 17 End index: 89
# Start emg index: 56 End emg index: 356
# ---- 63 ----
# 0.848633
# Start index: 0 End index: 87
# Start emg index: 0 End emg index: 320
# ---- 64 ----
# 0.844727
#  NO END
# Start index: 4 End index: 102
# Start emg index: 0 End emg index: 356
# ---- 65 ----
# 0.84375
# Start index: 10 End index: 102
# Start emg index: 12 End emg index: 374
# ---- 66 ----
# 0.83252
# Start index: 0 End index: 97
# Start emg index: 0 End emg index: 360
# ---- 67 ----
# 0.76123
# Start index: 8 End index: 110
# Start emg index: 4 End emg index: 412
# ---- 68 ----
# 0.833984
# Start index: 0 End index: 90
# Start emg index: 0 End emg index: 330
# ---- 69 ----
# 0.759766
# Start index: 8 End index: 98
# Start emg index: 0 End emg index: 362
# ---- 70 ----
# 0.824707
# Start index: 16 End index: 99
# Start emg index: 34 End emg index: 362
# ---- 71 ----
# 0.703613
# Start index: 18 End index: 101
# Start emg index: 40 End emg index: 372
# ---- 72 ----
# 0.835938
# Start index: 14 End index: 101
# Start emg index: 22 End emg index: 372
# ---- 73 ----
# 0.805176
# Start index: 11 End index: 111
# Start emg index: 14 End emg index: 410
# ---- 74 ----
# 0.833008
# Start index: 1 End index: 98
# Start emg index: 0 End emg index: 364
# ---- 75 ----
# 0.801758
# Start index: 23 End index: 121
# Start emg index: 58 End emg index: 448
# ---- 76 ----
# 0.803223
# Start index: 5 End index: 127
# Start emg index: 0 End emg index: 476
# ---- 77 ----
# 0.805664
# Start index: 16 End index: 132
# Start emg index: 40 End emg index: 502
# ---- 78 ----
# 0.782227
# Start index: 1 End index: 125
# Start emg index: 0 End emg index: 468
# ---- 79 ----
# 0.801758
# Start index: 11 End index: 145
# Start emg index: 16 End emg index: 550
# ---- 80 ----
# 0.629395
# Start index: 19 End index: 86
# Start emg index: 46 End emg index: 286
# ---- 81 ----
# 0.749023
# Start index: 0 End index: 72
# Start emg index: 0 End emg index: 268
# ---- 82 ----
# 0.672363
# Start index: 1 End index: 82
# Start emg index: 0 End emg index: 314
# ---- 83 ----
# 0.805664
# Start index: 6 End index: 86
# Start emg index: 0 End emg index: 300
# ---- 84 ----
# 0.557129
# Start index: 13 End index: 95
# Start emg index: 24 End emg index: 310
# Done Trimming dalawa 0 files
# ----------------- Word dito-----------------
# ---- 0 ----
# 0.791504
# Start index: 14 End index: 109
# Start emg index: 28 End emg index: 406
# ---- 1 ----
# 0.780762
# Start index: 25 End index: 123
# Start emg index: 70 End emg index: 458
# ---- 2 ----
# 0.844238
# Start index: 20 End index: 46
# Start emg index: 48 End emg index: 150
# ---- 3 ----
# 0.796387
# Start index: 19 End index: 84
# Start emg index: 46 End emg index: 304
# ---- 4 ----
# 0.783203
# Start index: 20 End index: 55
# Start emg index: 48 End emg index: 186
# ---- 5 ----
# 0.666504
# Start index: 20 End index: 63
# Start emg index: 48 End emg index: 220
# ---- 6 ----
# 0.821777
# Start index: 22 End index: 66
# Start emg index: 54 End emg index: 230
# ---- 7 ----
# 0.811523
# Start index: 18 End index: 128
# Start emg index: 46 End emg index: 484
# ---- 8 ----
# 0.766602
# Start index: 17 End index: 132
# Start emg index: 36 End emg index: 494
# ---- 9 ----
# 0.822266
# Start index: 8 End index: 131
# Start emg index: 0 End emg index: 492
# ---- 10 ----
# 0.754883
# Start index: 21 End index: 66
# Start emg index: 56 End emg index: 234
# ---- 11 ----
# 0.793457
# Start index: 35 End index: 85
# Start emg index: 112 End emg index: 312
# ---- 12 ----
# 0.76709
# Start index: 4 End index: 59
# Start emg index: 0 End emg index: 206
# ---- 13 ----
# 0.787109
# Start index: 15 End index: 58
# Start emg index: 28 End emg index: 200
# ---- 14 ----
# 0.838867
# Start index: 10 End index: 53
# Start emg index: 10 End emg index: 182
# ---- 15 ----
# 0.805664
# Start index: 15 End index: 115
# Start emg index: 32 End emg index: 428
# ---- 16 ----
# 0.799805
# Start index: 9 End index: 125
# Start emg index: 0 End emg index: 460
# ---- 17 ----
# 0.845215
# Start index: 4 End index: 113
# Start emg index: 0 End emg index: 420
# ---- 18 ----
# 0.736328
# Start index: 3 End index: 113
# Start emg index: 0 End emg index: 420
# ---- 19 ----
# 0.72168
# Start index: 12 End index: 116
# Start emg index: 16 End emg index: 428
# ---- 20 ----
# 0.833496
# Start index: 0 End index: 17
# Start emg index: 0 End emg index: 40
# ---- 21 ----
# 0.619629
# Start index: 0 End index: 13
# Start emg index: 0 End emg index: 24
# ---- 22 ----
# 0.792969
# Start index: 0 End index: 108
# Start emg index: 0 End emg index: 400
# ---- 23 ----
# 0.731445
# Start index: 18 End index: 140
# Start emg index: 44 End emg index: 528
# ---- 24 ----
# 0.796875
# Start index: 21 End index: 135
# Start emg index: 56 End emg index: 510
# ---- 25 ----
# 0.796387
# Start index: 32 End index: 157
# Start emg index: 94 End emg index: 592
# ---- 26 ----
# 0.584961
# Start index: 28 End index: 143
# Start emg index: 86 End emg index: 542
# ---- 27 ----
# 0.644531
# Start index: 29 End index: 145
# Start emg index: 88 End emg index: 550
# ---- 28 ----
# 0.658691
# Start index: 17 End index: 130
# Start emg index: 42 End emg index: 492
# ---- 29 ----
# 0.599609
# Start index: 5 End index: 123
# Start emg index: 0 End emg index: 460
# ---- 30 ----
# 0.811523
# Start index: 24 End index: 136
# Start emg index: 64 End emg index: 510
# ---- 31 ----
# 0.814941
# Start index: 24 End index: 133
# Start emg index: 68 End emg index: 502
# ---- 32 ----
# 0.827148
# Start index: 4 End index: 127
# Start emg index: 0 End emg index: 476
# ---- 33 ----
# 0.785645
# Start index: 15 End index: 121
# Start emg index: 36 End emg index: 458
# ---- 34 ----
# 0.816895
# Start index: 6 End index: 137
# Start emg index: 0 End emg index: 518
# ---- 35 ----
# 0.835449
# Start index: 8 End index: 127
# Start emg index: 0 End emg index: 478
# ---- 36 ----
# 0.842773
# Start index: 19 End index: 133
# Start emg index: 44 End emg index: 498
# ---- 37 ----
# 0.830566
# Start index: 19 End index: 129
# Start emg index: 48 End emg index: 486
# ---- 38 ----
# 0.848145
# Start index: 19 End index: 126
# Start emg index: 46 End emg index: 472
# ---- 39 ----
# 0.845215
# Start index: 8 End index: 119
# Start emg index: 2 End emg index: 444
# ---- 40 ----
# 0.822754
# Start index: 7 End index: 108
# Start emg index: 0 End emg index: 402
# ---- 41 ----
# 0.841797
# Start index: 0 End index: 109
# Start emg index: 0 End emg index: 410
# ---- 42 ----
# 0.818848
# Start index: 23 End index: 122
# Start emg index: 62 End emg index: 456
# ---- 43 ----
# 0.78125
# Start index: 10 End index: 119
# Start emg index: 14 End emg index: 448
# ---- 44 ----
# 0.823242
# Start index: 8 End index: 123
# Start emg index: 0 End emg index: 462
# ---- 45 ----
# 0.831055
# Start index: 15 End index: 120
# Start emg index: 34 End emg index: 372
# ---- 46 ----
# 0.848633
# Start index: 13 End index: 108
# Start emg index: 26 End emg index: 344
# ---- 47 ----
# 0.790527
# Start index: 0 End index: 82
# Start emg index: 0 End emg index: 296
# ---- 48 ----
# 0.708984
# Start index: 6 End index: 109
# Start emg index: 0 End emg index: 338
# ---- 49 ----
# 0.119141
# Start index: 0 End index: 94
# Start emg index: 0 End emg index: 286
# ---- 50 ----
# 0.848633
# Start index: 2 End index: 23
# Start emg index: 0 End emg index: 60
# ---- 51 ----
# 0.847656
# Start index: 9 End index: 126
# Start emg index: 12 End emg index: 442
# ---- 52 ----
# 0.615234
# Start index: 0 End index: 106
# Start emg index: 0 End emg index: 394
# ---- 53 ----
# 0.816895
#  NO END
# Start index: 5 End index: 101
# Start emg index: 0 End emg index: 420
# ---- 54 ----
# 0.800781
# Start index: 0 End index: 96
# Start emg index: 0 End emg index: 372
# ---- 55 ----
# 0.616211
# Start index: 31 End index: 114
# Start emg index: 86 End emg index: 428
# ---- 56 ----
# 0.794434
# Start index: 0 End index: 100
# Start emg index: 0 End emg index: 364
# ---- 57 ----
# 0.724121
# Start index: 8 End index: 81
# Start emg index: 0 End emg index: 278
# ---- 58 ----
# 0.28125
# Start index: 0 End index: 30
# Start emg index: 0 End emg index: 102
# ---- 59 ----
# 0.815918
# Start index: 6 End index: 101
# Start emg index: 0 End emg index: 382
# ---- 60 ----
# 0.820313
# Start index: 29 End index: 50
# Start emg index: 74 End emg index: 138
# ---- 61 ----
# 0.741699
# Start index: 28 End index: 109
# Start emg index: 74 End emg index: 424
# ---- 62 ----
# 0.133301
# Start index: 0 End index: 115
# Start emg index: 0 End emg index: 418
# ---- 63 ----
# 0.59668
# Start index: 0 End index: 14
# Start emg index: 0 End emg index: 30
# ---- 64 ----
# 0.743164
#  NO END
# Start index: 16 End index: 93
#  NO END
# Start emg index: 38 End emg index: 395
# ---- 65 ----
# 0.827148
# Start index: 0 End index: 98
# Start emg index: 0 End emg index: 362
# ---- 66 ----
# 0.805176
# Start index: 19 End index: 128
# Start emg index: 44 End emg index: 476
# ---- 67 ----
# 0.818359
# Start index: 0 End index: 121
# Start emg index: 0 End emg index: 458
# ---- 68 ----
# 0.698242
# Start index: 0 End index: 127
# Start emg index: 0 End emg index: 480
# ---- 69 ----
# 0.169922
# Start index: 0 End index: 111
# Start emg index: 0 End emg index: 414
# ---- 70 ----
# 0.77002
# Start index: 16 End index: 119
# Start emg index: 38 End emg index: 450
# ---- 71 ----
# 0.680664
# Start index: 21 End index: 121
# Start emg index: 56 End emg index: 454
# ---- 72 ----
# 0.710938
# Start index: 1 End index: 111
# Start emg index: 0 End emg index: 414
# ---- 73 ----
# 0.763184
# Start index: 0 End index: 96
# Start emg index: 0 End emg index: 354
# ---- 74 ----
# 0.771973
# Start index: 4 End index: 105
# Start emg index: 0 End emg index: 384
# ---- 75 ----
# 0.794434
# Start index: 18 End index: 107
# Start emg index: 44 End emg index: 398
# ---- 76 ----
# 0.757813
# Start index: 21 End index: 122
# Start emg index: 56 End emg index: 458
# ---- 77 ----
# 0.805176
# Start index: 14 End index: 117
# Start emg index: 26 End emg index: 440
# ---- 78 ----
# 0.747559
# Start index: 12 End index: 117
# Start emg index: 22 End emg index: 438
# ---- 79 ----
# 0.751465
# Start index: 6 End index: 111
# Start emg index: 0 End emg index: 412
# ---- 80 ----
# 0.684082
# Start index: 9 End index: 43
# Start emg index: 8 End emg index: 124
# ---- 81 ----
# 0.753418
# Start index: 0 End index: 31
# Start emg index: 0 End emg index: 88
# ---- 82 ----
# 0.758789
# Start index: 0 End index: 33
# Start emg index: 0 End emg index: 120
# ---- 83 ----
# 0.777832
# Start index: 0 End index: 33
# Start emg index: 0 End emg index: 86
# ---- 84 ----
# 0.782227
# Start index: 12 End index: 44
# Start emg index: 18 End emg index: 120
# Done Trimming dito 0 files
# ----------------- Word hello-----------------
# ---- 0 ----
# 0.748535
# Start index: 17 End index: 102
# Start emg index: 42 End emg index: 380
# ---- 1 ----
# 0.822266
# Start index: 22 End index: 110
# Start emg index: 56 End emg index: 406
# ---- 2 ----
# 0.814941
# Start index: 20 End index: 108
# Start emg index: 54 End emg index: 404
# ---- 3 ----
# 0.72168
# Start index: 23 End index: 112
# Start emg index: 56 End emg index: 410
# ---- 4 ----
# 0.836426
# Start index: 12 End index: 107
# Start emg index: 18 End emg index: 398
# ---- 5 ----
# 0.817871
# Start index: 20 End index: 117
# Start emg index: 52 End emg index: 438
# ---- 6 ----
# 0.808105
# Start index: 20 End index: 117
# Start emg index: 50 End emg index: 436
# ---- 7 ----
# 0.837402
# Start index: 17 End index: 122
# Start emg index: 40 End emg index: 458
# ---- 8 ----
# 0.79541
# Start index: 16 End index: 127
# Start emg index: 32 End emg index: 476
# ---- 9 ----
# 0.832031
# Start index: 13 End index: 109
# Start emg index: 24 End emg index: 408
# ---- 10 ----
# 0.846191
# Start index: 8 End index: 112
# Start emg index: 8 End emg index: 422
# ---- 11 ----
# 0.78125
# Start index: 11 End index: 107
# ...
# 0.838867
# Start index: 0 End index: 18
# Start emg index: 0 End emg index: 54
# ---- 82 ----
# 0.833984
# Start index: 0 End index: 16
# Start emg index: 0 End emg index: 34
# ---- 83 ----
# 0.807617
# Start index: 12 End index: 106
# Start emg index: 20 End emg index: 358
# ---- 84 ----
# 0.671875
# Start index: 19 End index: 116
# Start emg index: 50 End emg index: 350
# Done Trimming sorry 0 files
# ----------------- Word tatlo-----------------
# ---- 0 ----
# 0.807617
# Start index: 25 End index: 136
# Start emg index: 70 End emg index: 512
# ---- 1 ----
# 0.833008
# Start index: 37 End index: 158
# Start emg index: 116 End emg index: 596
# ---- 2 ----
# 0.831543
# Start index: 33 End index: 150
# Start emg index: 104 End emg index: 570
# ---- 3 ----
# 0.794434
# Start index: 35 End index: 159
# Start emg index: 110 End emg index: 604
# ---- 4 ----
# 0.835938
# Start index: 22 End index: 137
# Start emg index: 60 End emg index: 518
# ---- 5 ----
# 0.831055
# Start index: 21 End index: 126
# Start emg index: 52 End emg index: 470
# ---- 6 ----
# 0.807617
# Start index: 15 End index: 128
# Start emg index: 34 End emg index: 484
# ---- 7 ----
# 0.830078
# Start index: 9 End index: 137
# Start emg index: 12 End emg index: 518
# ---- 8 ----
# 0.799316
# Start index: 12 End index: 138
# Start emg index: 22 End emg index: 522
# ---- 9 ----
# 0.844727
# Start index: 20 End index: 148
# Start emg index: 46 End emg index: 556
# ---- 10 ----
# 0.842773
# Start index: 10 End index: 97
# Start emg index: 14 End emg index: 362
# ---- 11 ----
# 0.67334
# Start index: 11 End index: 118
# Start emg index: 14 End emg index: 440
# ---- 12 ----
# 0.848145
# Start index: 11 End index: 118
# Start emg index: 18 End emg index: 442
# ---- 13 ----
# 0.824707
# Start index: 0 End index: 108
# Start emg index: 0 End emg index: 400
# ---- 14 ----
# 0.783691
# Start index: 6 End index: 111
# Start emg index: 0 End emg index: 410
# ---- 15 ----
# 0.847168
# Start index: 0 End index: 15
# Start emg index: 0 End emg index: 20
# ---- 16 ----
# 0.845215
# Start index: 0 End index: 12
# Start emg index: 0 End emg index: 1
# ---- 17 ----
# 0.776855
# Start index: 13 End index: 105
# Start emg index: 10 End emg index: 372
# ---- 18 ----
# 0.813477
# Start index: 0 End index: 92
# Start emg index: 0 End emg index: 330
# ---- 19 ----
# 0.773926
# Start index: 20 End index: 105
# Start emg index: 44 End emg index: 382
# ---- 20 ----
# 0.786621
# Start index: 14 End index: 91
# Start emg index: 24 End emg index: 328
# ---- 21 ----
# 0.82666
# Start index: 12 End index: 93
# Start emg index: 10 End emg index: 332
# ---- 22 ----
# 0.758301
# Start index: 11 End index: 99
# Start emg index: 12 End emg index: 362
# ---- 23 ----
# 0.839844
# Start index: 17 End index: 108
# Start emg index: 36 End emg index: 396
# ---- 24 ----
# 0.768066
# Start index: 0 End index: 81
# Start emg index: 0 End emg index: 276
# ---- 25 ----
# 0.842285
# Start index: 32 End index: 157
# Start emg index: 98 End emg index: 596
# ---- 26 ----
# 0.826172
# Start index: 27 End index: 147
# Start emg index: 76 End emg index: 554
# ---- 27 ----
# 0.838867
# Start index: 16 End index: 143
# Start emg index: 34 End emg index: 540
# ---- 28 ----
# 0.813477
# Start index: 35 End index: 165
# Start emg index: 112 End emg index: 628
# ---- 29 ----
# 0.816406
# Start index: 27 End index: 147
# Start emg index: 80 End emg index: 556
# ---- 30 ----
# 0.80127
# Start index: 26 End index: 108
# Start emg index: 64 End emg index: 386
# ---- 31 ----
# 0.738281
# Start index: 16 End index: 88
# Start emg index: 32 End emg index: 316
# ---- 32 ----
# 0.72998
# Start index: 17 End index: 98
# Start emg index: 26 End emg index: 346
# ---- 33 ----
# 0.818848
# Start index: 20 End index: 86
# Start emg index: 48 End emg index: 316
# ---- 34 ----
# 0.777832
# Start index: 7 End index: 81
# Start emg index: 0 End emg index: 278
# ---- 35 ----
# 0.817383
# Start index: 12 End index: 116
# Start emg index: 20 End emg index: 432
# ---- 36 ----
# 0.842773
# Start index: 17 End index: 111
# Start emg index: 46 End emg index: 418
# ---- 37 ----
# 0.813965
# Start index: 7 End index: 97
# Start emg index: 0 End emg index: 360
# ---- 38 ----
# 0.799805
# Start index: 21 End index: 103
# Start emg index: 54 End emg index: 380
# ---- 39 ----
# 0.712402
# Start index: 12 End index: 104
# Start emg index: 18 End emg index: 382
# ---- 40 ----
# 0.728027
# Start index: 26 End index: 109
# Start emg index: 80 End emg index: 352
# ---- 41 ----
# 0.723633
# Start index: 20 End index: 99
# Start emg index: 48 End emg index: 310
# ---- 42 ----
# 0.808594
# Start index: 19 End index: 95
# Start emg index: 46 End emg index: 308
# ---- 43 ----
# 0.720215
# Start index: 21 End index: 86
# Start emg index: 46 End emg index: 332
# ---- 44 ----
# 0.847656
# Start index: 4 End index: 77
# Start emg index: 0 End emg index: 280
# ---- 45 ----
# 0.828125
# Start index: 2 End index: 97
# Start emg index: 0 End emg index: 374
# ---- 46 ----
# 0.58252
# Start index: 13 End index: 105
# Start emg index: 26 End emg index: 418
# ---- 47 ----
# 0.802246
# Start index: 21 End index: 108
# Start emg index: 50 End emg index: 410
# ---- 48 ----
# 0.836914
# Start index: 25 End index: 119
# Start emg index: 64 End emg index: 404
# ---- 49 ----
# 0.728516
# Start index: 13 End index: 102
# Start emg index: 24 End emg index: 378
# ---- 50 ----
# 0.834473
# Start index: 3 End index: 110
# Start emg index: 0 End emg index: 408
# ---- 51 ----
# 0.740234
# Start index: 0 End index: 102
# Start emg index: 0 End emg index: 376
# ---- 52 ----
# 0.827148
# Start index: 20 End index: 125
# Start emg index: 50 End emg index: 468
# ---- 53 ----
# 0.834961
# Start index: 3 End index: 117
# Start emg index: 0 End emg index: 438
# ---- 54 ----
# 0.815918
# Start index: 0 End index: 109
# Start emg index: 0 End emg index: 408
# ---- 55 ----
# 0.847168
# Start index: 16 End index: 87
# Start emg index: 50 End emg index: 346
# ---- 56 ----
# 0.791504
# Start index: 8 End index: 100
# Start emg index: 10 End emg index: 350
# ---- 57 ----
# 0.786621
# Start index: 11 End index: 92
# Start emg index: 18 End emg index: 290
# ---- 58 ----
# 0.719238
# Start index: 19 End index: 95
# Start emg index: 44 End emg index: 352
# ---- 59 ----
# 0.812988
# Start index: 17 End index: 108
# Start emg index: 40 End emg index: 366
# ---- 60 ----
# 0.831543
# Start index: 7 End index: 103
# Start emg index: 0 End emg index: 388
# ---- 61 ----
# 0.844727
# Start index: 0 End index: 97
# Start emg index: 0 End emg index: 384
# ---- 62 ----
# 0.828613
# Start index: 0 End index: 119
# Start emg index: 0 End emg index: 380
# ---- 63 ----
# 0.835449
# Start index: 0 End index: 100
# Start emg index: 0 End emg index: 356
# ---- 64 ----
# 0.837402
# Start index: 0 End index: 111
# Start emg index: 0 End emg index: 386
# ---- 65 ----
# 0.816406
# Start index: 27 End index: 150
# Start emg index: 82 End emg index: 574
# ---- 66 ----
# 0.807617
# Start index: 9 End index: 134
# Start emg index: 10 End emg index: 506
# ---- 67 ----
# 0.833984
# Start index: 9 End index: 127
# Start emg index: 10 End emg index: 478
# ---- 68 ----
# 0.836914
# Start index: 19 End index: 139
# Start emg index: 50 End emg index: 526
# ---- 69 ----
# 0.835938
# Start index: 10 End index: 123
# Start emg index: 14 End emg index: 462
# ---- 70 ----
# 0.772461
# Start index: 1 End index: 101
# Start emg index: 0 End emg index: 376
# ---- 71 ----
# 0.830566
# Start index: 14 End index: 98
# Start emg index: 24 End emg index: 362
# ---- 72 ----
# 0.798828
# Start index: 17 End index: 102
# Start emg index: 38 End emg index: 378
# ---- 73 ----
# 0.806641
# Start index: 20 End index: 101
# Start emg index: 52 End emg index: 376
# ---- 74 ----
# 0.782715
# Start index: 13 End index: 99
# Start emg index: 24 End emg index: 368
# ---- 75 ----
# 0.828613
# Start index: 21 End index: 107
# Start emg index: 58 End emg index: 400
# ---- 76 ----
# 0.794922
# Start index: 30 End index: 111
# Start emg index: 92 End emg index: 414
# ---- 77 ----
# 0.834961
# Start index: 16 End index: 122
# Start emg index: 36 End emg index: 454
# ---- 78 ----
# 0.771973
# Start index: 21 End index: 121
# Start emg index: 56 End emg index: 454
# ---- 79 ----
# 0.770508
# Start index: 27 End index: 130
# Start emg index: 80 End emg index: 490
# ---- 80 ----
# 0.727051
# Start index: 14 End index: 94
# Start emg index: 32 End emg index: 304
# ---- 81 ----
# 0.846191
# Start index: 12 End index: 91
# Start emg index: 14 End emg index: 288
# ---- 82 ----
# 0.800293
# Start index: 10 End index: 83
# Start emg index: 14 End emg index: 298
# ---- 83 ----
# 0.708496
# Start index: 11 End index: 92
# Start emg index: 12 End emg index: 290
# ---- 84 ----
# 0.822754
# Start index: 0 End index: 81
# Start emg index: 0 End emg index: 300
# Done Trimming tatlo 0 files
# ----------------- Word tubig-----------------
# ---- 0 ----
# 0.812012
# Start index: 15 End index: 110
# Start emg index: 36 End emg index: 412
# ---- 1 ----
# 0.779785
# Start index: 22 End index: 110
# Start emg index: 64 End emg index: 414
# ---- 2 ----
# 0.794434
# Start index: 25 End index: 115
# Start emg index: 70 End emg index: 428
# ---- 3 ----
# 0.846191
# Start index: 13 End index: 109
# Start emg index: 24 End emg index: 406
# ---- 4 ----
# 0.796387
# Start index: 25 End index: 125
# Start emg index: 76 End emg index: 470
# ---- 5 ----
# 0.822754
# Start index: 34 End index: 153
# Start emg index: 106 End emg index: 580
# ---- 6 ----
# 0.838379
# Start index: 11 End index: 140
# Start emg index: 14 End emg index: 526
# ---- 7 ----
# 0.829102
# Start index: 16 End index: 155
# Start emg index: 38 End emg index: 592
# ---- 8 ----
# 0.847656
# Start index: 23 End index: 160
# Start emg index: 64 End emg index: 610
# ---- 9 ----
# 0.847656
# Start index: 14 End index: 149
# Start emg index: 24 End emg index: 564
# ---- 10 ----
# 0.775391
# Start index: 7 End index: 104
# Start emg index: 0 End emg index: 388
# ---- 11 ----
# 0.792969
# Start index: 17 End index: 114
# Start emg index: 40 End emg index: 426
# ---- 12 ----
# 0.806641
# Start index: 9 End index: 122
# Start emg index: 14 End emg index: 462
# ---- 13 ----
# 0.824219
# Start index: 0 End index: 127
# Start emg index: 0 End emg index: 478
# ---- 14 ----
# 0.790039
# Start index: 12 End index: 120
# Start emg index: 24 End emg index: 452
# ---- 15 ----
# 0.826172
# Start index: 14 End index: 35
# Start emg index: 24 End emg index: 104
# ---- 16 ----
# 0.812988
# Start index: 6 End index: 97
# Start emg index: 0 End emg index: 352
# ---- 17 ----
# 0.849609
# Start index: 0 End index: 17
# Start emg index: 0 End emg index: 28
# ---- 18 ----
# 0.745117
#  NO END
# Start index: 15 End index: 101
#  NO END
# Start emg index: 24 End emg index: 363
# ---- 19 ----
# 0.819336
# Start index: 0 End index: 11
# Start emg index: 0 End emg index: 16
# ---- 20 ----
# 0.80957
# Start index: 21 End index: 106
# Start emg index: 48 End emg index: 386
# ---- 21 ----
# 0.834473
# Start index: 15 End index: 108
# Start emg index: 26 End emg index: 398
# ---- 22 ----
# 0.788574
# Start index: 17 End index: 131
# Start emg index: 34 End emg index: 486
# ---- 23 ----
# 0.834473
# Start index: 16 End index: 118
# Start emg index: 34 End emg index: 438
# ---- 24 ----
# 0.845703
# Start index: 14 End index: 129
# Start emg index: 10 End emg index: 466
# ---- 25 ----
# 0.842285
# Start index: 16 End index: 116
# Start emg index: 36 End emg index: 434
# ---- 26 ----
# 0.827148
# Start index: 13 End index: 130
# Start emg index: 26 End emg index: 488
# ---- 27 ----
# 0.779297
# Start index: 34 End index: 147
# Start emg index: 100 End emg index: 550
# ---- 28 ----
# 0.839355
# Start index: 8 End index: 139
# Start emg index: 0 End emg index: 522
# ---- 29 ----
# 0.838867
# Start index: 16 End index: 36
# Start emg index: 32 End emg index: 112
# ---- 30 ----
# 0.769043
# Start index: 11 End index: 98
# Start emg index: 0 End emg index: 350
# ---- 31 ----
# 0.821289
# Start index: 2 End index: 99
# Start emg index: 0 End emg index: 358
# ---- 32 ----
# 0.828613
# Start index: 0 End index: 102
# Start emg index: 0 End emg index: 370
# ---- 33 ----
# 0.724609
# Start index: 13 End index: 111
# Start emg index: 22 End emg index: 410
# ---- 34 ----
# 0.774414
# Start index: 15 End index: 123
# Start emg index: 24 End emg index: 456
# ---- 35 ----
# 0.755859
# Start index: 19 End index: 110
# Start emg index: 46 End emg index: 408
# ---- 36 ----
# 0.845215
# Start index: 19 End index: 115
# Start emg index: 50 End emg index: 432
# ---- 37 ----
# 0.843262
# Start index: 4 End index: 100
# Start emg index: 0 End emg index: 372
# ---- 38 ----
# 0.789063
# Start index: 19 End index: 108
# Start emg index: 40 End emg index: 394
# ---- 39 ----
# 0.849121
# Start index: 15 End index: 108
# Start emg index: 30 End emg index: 400
# ---- 40 ----
# 0.820801
# Start index: 18 End index: 104
# Start emg index: 36 End emg index: 324
# ---- 41 ----
# 0.834961
# Start index: 24 End index: 106
# Start emg index: 62 End emg index: 324
# ---- 42 ----
# 0.726074
# Start index: 16 End index: 85
# Start emg index: 32 End emg index: 328
# ---- 43 ----
# 0.793945
# Start index: 19 End index: 94
# Start emg index: 46 End emg index: 344
# ---- 44 ----
# 0.814453
# Start index: 14 End index: 95
# Start emg index: 38 End emg index: 310
# ---- 45 ----
# 0.76709
# Start index: 8 End index: 83
# Start emg index: 10 End emg index: 336
# ---- 46 ----
# 0.581543
# Start index: 20 End index: 91
# Start emg index: 54 End emg index: 338
# ---- 47 ----
# 0.782227
# Start index: 0 End index: 62
# Start emg index: 0 End emg index: 248
# ---- 48 ----
# 0.835449
# Start index: 4 End index: 68
# Start emg index: 0 End emg index: 262
# ---- 49 ----
# 0.70752
#  NO END
# Start index: 4 End index: 67
#  NO END
# Start emg index: 0 End emg index: 215
# ---- 50 ----
# 0.820313
# Start index: 15 End index: 114
# Start emg index: 32 End emg index: 426
# ---- 51 ----
# 0.827148
# Start index: 0 End index: 90
# Start emg index: 0 End emg index: 332
# ---- 52 ----
# 0.758301
# Start index: 1 End index: 102
# Start emg index: 0 End emg index: 378
# ---- 53 ----
# 0.837891
# Start index: 7 End index: 137
# Start emg index: 0 End emg index: 514
# ---- 54 ----
# 0.840332
# Start index: 20 End index: 123
# Start emg index: 52 End emg index: 462
# ---- 55 ----
# 0.801758
# Start index: 10 End index: 90
# Start emg index: 14 End emg index: 310
# ---- 56 ----
# 0.725586
# Start index: 0 End index: 83
# Start emg index: 0 End emg index: 268
# ---- 57 ----
# 0.845703
# Start index: 9 End index: 97
# Start emg index: 10 End emg index: 308
# ---- 58 ----
# 0.760742
# Start index: 17 End index: 93
# Start emg index: 44 End emg index: 342
# ---- 59 ----
# 0.845703
# Start index: 11 End index: 88
# Start emg index: 18 End emg index: 306
# ---- 60 ----
# 0.84668
# Start index: 0 End index: 78
# Start emg index: 0 End emg index: 352
# ---- 61 ----
# 0.834961
# Start index: 13 End index: 109
# Start emg index: 34 End emg index: 360
# ---- 62 ----
# 0.834473
# Start index: 20 End index: 39
# Start emg index: 46 End emg index: 112
# ---- 63 ----
# 0.849609
# Start index: 1 End index: 21
# Start emg index: 0 End emg index: 56
# ---- 64 ----
# 0.772949
# Start index: 0 End index: 85
# Start emg index: 0 End emg index: 288
# ---- 65 ----
# 0.808594
# Start index: 21 End index: 120
# Start emg index: 52 End emg index: 446
# ---- 66 ----
# 0.817871
# Start index: 2 End index: 25
# Start emg index: 0 End emg index: 70
# ---- 67 ----
# 0.821289
# Start index: 20 End index: 133
# Start emg index: 54 End emg index: 504
# ---- 68 ----
# 0.796387
# Start index: 18 End index: 131
# Start emg index: 44 End emg index: 492
# ---- 69 ----
# 0.773926
# Start index: 16 End index: 134
# Start emg index: 34 End emg index: 504
# ---- 70 ----
# 0.818359
# Start index: 12 End index: 81
# Start emg index: 20 End emg index: 292
# ---- 71 ----
# 0.754883
# Start index: 16 End index: 88
# Start emg index: 32 End emg index: 320
# ---- 72 ----
# 0.820801
# Start index: 21 End index: 101
# Start emg index: 56 End emg index: 376
# ---- 73 ----
# 0.655273
# Start index: 7 End index: 88
# Start emg index: 0 End emg index: 320
# ---- 74 ----
# 0.831055
# Start index: 15 End index: 92
# Start emg index: 32 End emg index: 338
# ---- 75 ----
# 0.731934
# Start index: 11 End index: 96
# Start emg index: 16 End emg index: 354
# ---- 76 ----
# 0.829102
# Start index: 0 End index: 88
# Start emg index: 0 End emg index: 324
# ---- 77 ----
# 0.766602
# Start index: 5 End index: 88
# Start emg index: 0 End emg index: 320
# ---- 78 ----
# 0.821289
# Start index: 2 End index: 81
# Start emg index: 0 End emg index: 300
# ---- 79 ----
# 0.808105
# Start index: 9 End index: 94
# Start emg index: 8 End emg index: 344
# ---- 80 ----
# 0.722168
# Start index: 8 End index: 87
# Start emg index: 0 End emg index: 268
# ---- 81 ----
# 0.814941
# Start index: 3 End index: 79
# Start emg index: 0 End emg index: 302
# ---- 82 ----
# 0.838867
# Start index: 4 End index: 88
# Start emg index: 0 End emg index: 284
# ---- 83 ----
# 0.752441
# Start index: 15 End index: 94
# Start emg index: 30 End emg index: 304
# ---- 84 ----
# 0.841309
# Start index: 8 End index: 92
# Start emg index: 0 End emg index: 292
# Done Trimming tubig 0 files

# %%
import os

directory = "trimmed_data"
if not os.path.exists(directory):
    os.makedirs(directory)
    
for className in classNames:
    className = className.split("\\")[1]
    if not os.path.exists(className):
        os.makedirs(className)
    listOfTrimmedDataFramesPerClass

# %%
listOfTrimmedDataFramesPerClass

# %%
# trimmedAccDataFrames = {}
# trimmedAccDataFrames['right'] = []
# trimmedAccDataFrames['left'] = []

# trimmedGyroDataFrames = {}
# trimmedGyroDataFrames['right'] = []
# trimmedGyroDataFrames['left'] = []

# trimmedEmgDataFrames = {}
# trimmedEmgDataFrames['right'] = []
# trimmedEmgDataFrames['left'] = []

# for i in range(0,len(gyroDataFrames['right'])):
#     start = -1
#     end = -1
#     counter = 0
#     for x in accDataFrames['right'][i]['x']:  
#         if(x < 0.85 and start ==-1):
#             print(x)
#             start = counter - 10
#         elif(start != -1 and x>0.99):
#             end = counter + 9
#             break;
#         counter += 1
    
#     startEmg = -1
#     endEmg = -1
#     counter2 = 0
#     for t in emgDataFrames['right'][i]['timestamp']:
#         if(t > accDataFrames['right'][i].loc[start]['timestamp'] and startEmg == -1):
#             #print("%s > %f" % (t, accDataFrames['right'][i].loc[start]['timestamp']))
#             startEmg = counter2-1
#         elif(startEmg != -1 and t > accDataFrames['right'][i].loc[end]['timestamp']):
#             #print("%s > %f" % (t, accDataFrames['right'][i].loc[end]['timestamp']))
#             endEmg = counter2-1
#             break;
#         counter2 += 1
    
#     newAccDf = accDataFrames['right'][i].loc[start:end]
#     newAccDf = newAccDf.reset_index(drop=True)
#     newGyroDf = gyroDataFrames['right'][i].loc[start:end]
#     newGyroDf = newGyroDf.reset_index(drop=True)
#     newEmgDf = emgDataFrames['right'][i].loc[startEmg:endEmg]
#     newEmgDf = newEmgDf.reset_index(drop=True)

#     trimmedAccDataFrames['right'].append(newAccDf)
#     trimmedGyroDataFrames['right'].append(newGyroDf)
#     trimmedEmgDataFrames['right'].append(newEmgDf)
    
#     print("Start index: %s End index: %s" % (start, end))
#     print("Start emg index: %s End emg index: %s" % (startEmg, endEmg))
# Out:
# Start index: 29 End index: 152
# Start emg index: 77 End emg index: 567
# Start index: 40 End index: 175
# Start emg index: 129 End emg index: 667
# Start index: 49 End index: 175
# Start emg index: 163 End emg index: 665
# Start index: 57 End index: 187
# Start emg index: 189 End emg index: 707
# Start index: 34 End index: 151
# Start emg index: 105 End emg index: 571

# %%
# import glob
# import pandas as pd

# listOfFileNames = []
# listOfClassNames = []
# listOfDataPerClass = []
# files = []
# classNames = []

# files = glob.glob("/Users/user/Desktop/FSL by non-signers/ano/1/*.csv")
# print(len(files))
# listOfFileNames = []
# for f in files:
#     listOfFileNames.append(f.split("\\")[1])
    
# emgDataFrames = {}
# emgDataFrames['right'] = []
# emgDataFrames['left'] = []
    
# accDataFrames = {}
# accDataFrames['right'] = []
# accDataFrames['left'] = []

# gyroDataFrames = {}
# gyroDataFrames['right'] = []
# gyroDataFrames['left'] = []

# dataFrameDictionary = {}
# leftctr = 0
# rightctr = 0
# for fileName in listOfFileNames:
#     fileLocation = "/Users/user/Desktop/FSL by non-signers/ano/1/"+fileName 
#     #print(fileLocation)
#     df = pd.read_csv(fileLocation)
    
#     if "emg" in fileName:   
#         if "-0-" in fileName:
#             emgDataFrames['right'].append(df)
#             leftctr+=1
#         else:
#             emgDataFrames['left'].append(df)
#             rightctr+=1
#     elif ("accelerometer") in fileName:
#         if "-0-" in fileName:
#             accDataFrames['right'].append(df)
#             leftctr+=1
#         else:
#             accDataFrames['left'].append(df)
#             rightctr+=1
#     elif ("gyro") in fileName:
#         if "-0-" in fileName:
#             gyroDataFrames['right'].append(df)
#             leftctr+=1
#         else:
#             gyroDataFrames['left'].append(df)      
#             rightctr+=1

# print("Total of " + str(leftctr) + " left arm files and " + str(rightctr) + " right arm files.")

    
# #listOfClassNames
# #listOfDataPerClass[0]
# print("Done listing the class and file names")
# Out:
# 50
# Total of 15 left arm files and 15 right arm files.
# Done listing the class and file names

# %% [markdown]
# # Pancheck if goods yung trim

# %%
# import matplotlib.pyplot as plt

# for i in range(0,len(trimmedAccDataFrames['right'])):
#     print("-----%s------" % str(i+1))
#     print("Untrimmed")

#     fig_size = plt.rcParams["figure.figsize"]    
#     fig_size[0] = 14
#     fig_size[1] = 4
#     plt.rcParams["figure.figsize"] = fig_size

#     plt.plot(accDataFrames['right'][i]['x'])
#     plt.plot(accDataFrames['right'][i]['y'])
#     plt.plot(accDataFrames['right'][i]['z'])
    
# #     plt.plot(emgDataFrames['right'][i]['emg1'])
# #     plt.plot(emgDataFrames['right'][i]['emg2'])
# #     plt.plot(emgDataFrames['right'][i]['emg3'])
# #     plt.plot(emgDataFrames['right'][i]['emg4'])
# #     plt.plot(emgDataFrames['right'][i]['emg5'])
# #     plt.plot(emgDataFrames['right'][i]['emg6'])
# #     plt.plot(emgDataFrames['right'][i]['emg7'])
# #     plt.plot(emgDataFrames['right'][i]['emg8'])
    
# #     plt.plot(gyroDataFrames['right'][i]['x'])
# #     plt.plot(gyroDataFrames['right'][i]['y'])
# #     plt.plot(gyroDataFrames['right'][i]['z'])
#     plt.show()
#     print("Trimmed")

#     fig_size = plt.rcParams["figure.figsize"]    
#     fig_size[0] = 14
#     fig_size[1] = 4
#     plt.rcParams["figure.figsize"] = fig_size
#     plt.plot(trimmedAccDataFrames['right'][i]['x'])
#     plt.plot(trimmedAccDataFrames['right'][i]['y'])
#     plt.plot(trimmedAccDataFrames['right'][i]['z'])
    
# #     plt.plot(trimmedEmgDataFrames['right'][i]['emg1'])
# #     plt.plot(trimmedEmgDataFrames['right'][i]['emg2'])
# #     plt.plot(trimmedEmgDataFrames['right'][i]['emg3'])
# #     plt.plot(trimmedEmgDataFrames['right'][i]['emg4'])
# #     plt.plot(trimmedEmgDataFrames['right'][i]['emg5'])
# #     plt.plot(trimmedEmgDataFrames['right'][i]['emg6'])
# #     plt.plot(trimmedEmgDataFrames['right'][i]['emg7'])
# #     plt.plot(trimmedEmgDataFrames['right'][i]['emg8'])

# #     plt.plot(trimmedGyroDataFrames['right'][i]['x'])
# #     plt.plot(trimmedGyroDataFrames['right'][i]['y'])
# #     plt.plot(trimmedGyroDataFrames['right'][i]['z'])
#     plt.show()
# Out:
# -----1------
# Untrimmed
# Trimmed
# -----2------
# Untrimmed
# Trimmed
# -----3------
# Untrimmed
# Trimmed
# -----4------
# Untrimmed
# Trimmed
# -----5------
# Untrimmed
# Trimmed

# %%
# import numpy as np

# start = -1
# end = -1
# counter = 0
# for x in accDataFrames['right'][1]['x']:  
#     mean = np.mean(accDataFrames['right'][0]['x'].loc[0:counter])
#     sd = np.std(accDataFrames['right'][0]['x'].loc[0:counter])*4
#     print("n: %s mean: %s sd: %s mean+sd = %s" % (accDataFrames['right'][0]['x'][counter], mean, sd, mean+sd))
    
#     if(counter>0):
#         if(accDataFrames['right'][1]['y'][counter+1] < (mean-sd)):
#             print(counter+1)
#             break;
#     counter +=1

# %% [markdown]
# # Save file
