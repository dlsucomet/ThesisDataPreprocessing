# %%
import glob
import pandas as pd

listOfFileNames = []
listOfClassNames = []
listOfDataPerClass = []
files = []
classNames = []
#path = "/Users/user/Desktop/asd/thesis/placeholder/"
#path = "/Users/user/Desktop/pinakalatest/thesis/placeholder/"
path = "C:/Users/user/Desktop/Data/nonsignerdatalatest/2 arm gestures/"
classNames = glob.glob(path + "*")

for c in classNames:
    className = c.split("\\")[1]
    listOfClassNames.append(c.split("\\")[1])
    files = glob.glob(path + className+"/*") 
    listOfFileNames = []
    for i in range(0, len(files)):
        data = glob.glob(path + className+"/" + str(i+1) + "/*.csv")
        
        for f in data:
            listOfFileNames.append(str(i+1) + "/" + f.split("\\")[1])
    listOfDataPerClass.append(listOfFileNames)
    
listOfDataFramesPerClass = {}
dataFrameDictionary = {}
dataFrames = []

for c, d in zip(listOfClassNames, listOfDataPerClass):
    print("----------------- Word " + c + "-----------------")
    emgDataFrames = {}
    emgDataFrames['right'] = []
    emgDataFrames['left'] = []
    
    accDataFrames = {}
    accDataFrames['right'] = []
    accDataFrames['left'] = []

    gyroDataFrames = {}
    gyroDataFrames['right'] = []
    gyroDataFrames['left'] = []

    dataFrameDictionary = {}
    className = c
    emgleftctr = 0
    emgrightctr = 0
    accleftctr = 0
    accrightctr = 0
    gyroleftctr = 0
    gyrorightctr = 0
    
    for fileName in d:
        fileLocation = path + className + "/" + fileName + ""
            
        df = pd.read_csv(fileLocation)
            
        if "emg" in fileName:   
            if "-0-" in fileName:
                emgDataFrames['right'].append(df)
                emgleftctr+=1
            else:
                emgDataFrames['left'].append(df)
                emgrightctr+=1
        elif ("accelerometer") in fileName:
            if "-0-" in fileName:
                accDataFrames['right'].append(df)
                accleftctr+=1
            else:
                accDataFrames['left'].append(df)
                accrightctr+=1
        elif ("gyro") in fileName:
            if "-0-" in fileName:
                gyroDataFrames['right'].append(df)
                gyroleftctr+=1
            else:
                gyroDataFrames['left'].append(df)
                gyrorightctr+=1
    
    dataFrameDictionary["emg"] = emgDataFrames
    dataFrameDictionary["acc"] = accDataFrames
    dataFrameDictionary["gyro"] = gyroDataFrames

    listOfDataFramesPerClass[className] = dataFrameDictionary
    print("Total of " + str(emgleftctr) + " left arm emg files and " + str(emgrightctr) + " right arm emg files.")
    print("Total of " + str(accleftctr) + " left arm acc files and " + str(accrightctr) + " right arm acc files.")
    print("Total of " + str(gyroleftctr) + " left arm gyro files and " + str(gyrorightctr) + " right arm gyro files.")
    
print("DONE!")
# Out:
# ----------------- Word binebenta-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word extra-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word gulay-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word gusto-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word itlog-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word juice-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word kape-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word kilo-----------------
# Total of 100 left arm emg files and 101 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word mahal-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word malaki-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word maliit-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word mayroon-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word nagbubukas-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word nagsasara-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word oras-----------------
# Total of 99 left arm emg files and 99 right arm emg files.
# Total of 99 left arm acc files and 99 right arm acc files.
# Total of 99 left arm gyro files and 99 right arm gyro files.
# ----------------- Word pabili-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word poloshirt-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word puwede-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word saging-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word sari-sari store-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word shorts-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word size-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word spaghetti-----------------
# Total of 99 left arm emg files and 99 right arm emg files.
# Total of 99 left arm acc files and 99 right arm acc files.
# Total of 99 left arm gyro files and 99 right arm gyro files.
# ----------------- Word supot-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word t-shirt-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word tawad-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word tinapay-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word utang-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# ----------------- Word wala-----------------
# Total of 100 left arm emg files and 100 right arm emg files.
# Total of 100 left arm acc files and 100 right arm acc files.
# Total of 100 left arm gyro files and 100 right arm gyro files.
# DONE!

# %%
import numpy as np
listOfTrimmedDataFramesPerClass = {}

for className in classNames:
    className = className.split("\\")[1]
    print("----------------- Word " + className + "-----------------")
    ctr = 0
    trimmedDataFramesPerClass = {}
    trimmedDataFramesPerClass['left'] = []
    trimmedDataFramesPerClass['right'] = []
    
    dataFrameDictionary = {}
    
    emgDataFrames = listOfDataFramesPerClass[className]['emg']
    accDataFrames = listOfDataFramesPerClass[className]['acc']
    gyroDataFrames = listOfDataFramesPerClass[className]['gyro']
    
    trimmedAccDataFrames = []
    trimmedGyroDataFrames = []
    trimmedEmgDataFrames = []

    
    for i in range(0,len(listOfDataFramesPerClass[className]['acc']['right'])):
        start = -1
        end = -1
        counter = 0
        print("---- %s ----" % i)
        ctr += 1
        dataFrame = listOfDataFramesPerClass[className]['acc']['right'][i]
        for x, z in zip(dataFrame['x'], dataFrame['z']):  
            noend = False
            isBreak = False
            if(className in ("kilo", "shorts")): #and i in range(60,65)):
                if(x < 0.85 and start ==-1):
                    #print(x)
                    start = counter - 10
                    if start < 0:
                        start = 0
                elif(start != -1 and x>0.85):
                    
                    end = counter + 10
                    print("rows: " + str(np.abs(start-end)))

                    if(np.abs(start-end) < 70):
                        end = -1
                    else:
                        break;                
            else:
                if(x < z and start ==-1):
                    #print(x)
                    start = counter - 10
                    if start < 0:
                        start = 0
                elif(start != -1 and x>0.85):
                    end = counter + 10
                    print("rows: " + str(np.abs(start-end)))
                    if(np.abs(start-end) < 70):
                        end = -1
                    else:
                        break;
                        
            noend = True                
            counter += 1
            
        if noend == True or end >= len(listOfDataFramesPerClass[className]['acc']['right'][i]['x']):
            print(" NO END ey" )
            end = len(listOfDataFramesPerClass[className]['acc']['right'][i]['x'])-1
        

        startEmg = -1
        endEmg = -1
        counter2 = 0
        
        #print("Start index: %s End index: %s" % (start, end))
        for t in emgDataFrames['right'][i]['timestamp']:
            noend = False
            if(t > accDataFrames['right'][i].loc[start]['timestamp'] and startEmg == -1):
                #print("%s > %f" % (t, accDataFrames['right'][i].loc[start]['timestamp']))
                startEmg = counter2
            elif(startEmg != -1 and t > accDataFrames['right'][i].loc[end]['timestamp']):
                #print("%s > %f" % (t, accDataFrames['right'][i].loc[end]['timestamp']))
                endEmg = counter2
                break;
            else:
                noend = True
            counter2 += 1
        
        if noend == True:
       #     print(" NO END")
            endEmg = len(listOfDataFramesPerClass[className]['emg']['right'][i]['timestamp'])-1
        
        newAccDf = {}
        newAccDf['right'] = accDataFrames['right'][i].loc[start:end]
        newAccDf['right'] = newAccDf['right'].reset_index(drop=True)
        newAccDf['left'] = accDataFrames['left'][i].loc[start:end]
        newAccDf['left'] = newAccDf['left'].reset_index(drop=True)
        
        newGyroDf = {}
        newGyroDf['right'] = gyroDataFrames['right'][i].loc[start:end]
        newGyroDf['right'] = newGyroDf['right'].reset_index(drop=True)
        newGyroDf['left'] = gyroDataFrames['left'][i].loc[start:end]
        newGyroDf['left'] = newGyroDf['left'].reset_index(drop=True)
        
        newEmgDf = {}
        newEmgDf['right'] = emgDataFrames['right'][i].loc[startEmg:endEmg]
        newEmgDf['right'] = newEmgDf['right'].reset_index(drop=True)
        newEmgDf['left'] = emgDataFrames['left'][i].loc[startEmg:endEmg]
        newEmgDf['left'] = newEmgDf['left'].reset_index(drop=True)

        trimmedAccDataFrames.append(newAccDf)
        trimmedGyroDataFrames.append(newGyroDf)
        trimmedEmgDataFrames.append(newEmgDf)
        
        #print("Start emg index: %s End emg index: %s" % (startEmg, endEmg))
        
    dataFrameDictionary['acc'] = trimmedAccDataFrames
    dataFrameDictionary['gyro'] = trimmedGyroDataFrames
    dataFrameDictionary['emg'] = trimmedEmgDataFrames
        
    listOfTrimmedDataFramesPerClass[className] = dataFrameDictionary

        
    
    print("Done Trimming " + className + " " + str(ctr) + " files")
# Out:
# ----------------- Word binebenta-----------------
# ---- 0 ----
# rows: 114
# ---- 1 ----
# rows: 101
# ---- 2 ----
# rows: 91
# ---- 3 ----
# rows: 85
# ---- 4 ----
# rows: 84
# ---- 5 ----
# rows: 152
# ---- 6 ----
# rows: 112
# ---- 7 ----
# rows: 116
# ---- 8 ----
# rows: 104
# ---- 9 ----
# rows: 109
# ---- 10 ----
# rows: 81
# ---- 11 ----
# rows: 84
# ---- 12 ----
# rows: 85
# ---- 13 ----
# rows: 87
# ---- 14 ----
# rows: 87
# ---- 15 ----
# rows: 117
# ---- 16 ----
# rows: 107
# ---- 17 ----
# rows: 109
# ---- 18 ----
# rows: 21
# rows: 106
# ---- 19 ----
# rows: 100
# ---- 20 ----
# rows: 100
# ---- 21 ----
# rows: 100
# ---- 22 ----
# rows: 103
# ---- 23 ----
# rows: 112
# ---- 24 ----
# rows: 115
# ---- 25 ----
# rows: 113
# ---- 26 ----
# rows: 97
# ---- 27 ----
# rows: 105
# ---- 28 ----
# rows: 97
# ---- 29 ----
# rows: 92
# ---- 30 ----
# rows: 114
# ---- 31 ----
# rows: 120
# ---- 32 ----
# rows: 109
# ---- 33 ----
# rows: 106
# ---- 34 ----
# rows: 132
# ---- 35 ----
# rows: 38
# rows: 41
# rows: 42
# rows: 43
# rows: 44
# rows: 54
# rows: 55
# rows: 56
#  NO END ey
# ---- 36 ----
# rows: 96
# ---- 37 ----
# rows: 91
# ---- 38 ----
# rows: 103
# ---- 39 ----
# rows: 87
# ---- 40 ----
# rows: 104
# ---- 41 ----
# rows: 92
# ---- 42 ----
# rows: 86
# ---- 43 ----
# rows: 93
# ---- 44 ----
# rows: 90
# ---- 45 ----
# rows: 56
# rows: 124
# ---- 46 ----
# rows: 56
# rows: 124
# ---- 47 ----
# rows: 129
# ---- 48 ----
# rows: 56
# rows: 83
# ---- 49 ----
# rows: 53
# rows: 83
# ---- 50 ----
# rows: 141
# ---- 51 ----
# rows: 140
# ---- 52 ----
# rows: 147
# ---- 53 ----
# rows: 141
# ---- 54 ----
# rows: 131
# ---- 55 ----
# rows: 150
# ---- 56 ----
# rows: 125
# ---- 57 ----
# rows: 96
# ---- 58 ----
# rows: 105
# ---- 59 ----
# rows: 118
# ---- 60 ----
# rows: 115
# ---- 61 ----
# rows: 107
# ---- 62 ----
# rows: 111
# ---- 63 ----
# rows: 105
# ---- 64 ----
# rows: 101
# ---- 65 ----
# rows: 104
# ---- 66 ----
# rows: 106
# ---- 67 ----
# rows: 89
# ---- 68 ----
# rows: 95
# ---- 69 ----
# rows: 94
# ---- 70 ----
# rows: 102
# ---- 71 ----
# rows: 106
# ---- 72 ----
# rows: 115
# ---- 73 ----
# rows: 102
# ---- 74 ----
# rows: 90
# ---- 75 ----
# rows: 103
# ---- 76 ----
# rows: 109
# ---- 77 ----
# rows: 97
# ---- 78 ----
# rows: 121
# ---- 79 ----
# rows: 122
# ---- 80 ----
# rows: 164
# ---- 81 ----
# rows: 174
# ---- 82 ----
# rows: 177
# ---- 83 ----
# rows: 180
# ---- 84 ----
# rows: 171
# ---- 85 ----
# rows: 98
# ---- 86 ----
# rows: 75
# ---- 87 ----
# rows: 107
# ---- 88 ----
# rows: 93
# ---- 89 ----
# rows: 101
# ---- 90 ----
# rows: 135
# ---- 91 ----
# rows: 114
# ---- 92 ----
# rows: 105
# ---- 93 ----
# rows: 113
# ---- 94 ----
# rows: 98
# ---- 95 ----
# rows: 132
# ---- 96 ----
# rows: 121
# ---- 97 ----
# rows: 113
# ---- 98 ----
# rows: 116
# ---- 99 ----
# rows: 110
# Done Trimming binebenta 100 files
# ----------------- Word extra-----------------
# ---- 0 ----
# rows: 108
# ---- 1 ----
# rows: 124
# ---- 2 ----
# rows: 119
# ---- 3 ----
# rows: 127
# ---- 4 ----
# rows: 106
# ---- 5 ----
# rows: 111
# ---- 6 ----
# rows: 107
# ---- 7 ----
# rows: 97
# ---- 8 ----
# rows: 99
# ---- 9 ----
# rows: 94
# ---- 10 ----
# rows: 80
# ---- 11 ----
# rows: 89
# ---- 12 ----
# rows: 90
# ---- 13 ----
# rows: 86
# ---- 14 ----
# rows: 83
# ---- 15 ----
# rows: 101
# ---- 16 ----
# rows: 104
# ---- 17 ----
# rows: 105
# ---- 18 ----
# rows: 112
# ---- 19 ----
# rows: 113
# ---- 20 ----
# rows: 107
# ---- 21 ----
# rows: 139
# ---- 22 ----
# rows: 110
# ---- 23 ----
# rows: 114
# ---- 24 ----
# rows: 95
# ---- 25 ----
# rows: 91
# ---- 26 ----
# rows: 95
# ---- 27 ----
# rows: 103
# ---- 28 ----
# rows: 98
# ---- 29 ----
# rows: 97
# ---- 30 ----
# rows: 110
# ---- 31 ----
# rows: 109
# ---- 32 ----
# rows: 62
# rows: 118
# ---- 33 ----
# rows: 115
# ---- 34 ----
# rows: 131
# ---- 35 ----
# rows: 98
# ---- 36 ----
# rows: 108
# ---- 37 ----
# rows: 103
# ---- 38 ----
# rows: 114
# ---- 39 ----
# rows: 102
# ---- 40 ----
# rows: 74
# ---- 41 ----
# rows: 86
# ---- 42 ----
# rows: 74
# ---- 43 ----
# rows: 77
# ---- 44 ----
# rows: 91
# ---- 45 ----
# rows: 125
# ---- 46 ----
# rows: 116
# ---- 47 ----
# rows: 142
# ---- 48 ----
# rows: 127
# ---- 49 ----
# rows: 119
# ---- 50 ----
# rows: 119
# ---- 51 ----
# rows: 123
# ---- 52 ----
# rows: 130
# ---- 53 ----
# rows: 33
# rows: 34
# rows: 35
# rows: 36
# rows: 115
# ---- 54 ----
# rows: 123
# ---- 55 ----
# rows: 33
# rows: 82
# ---- 56 ----
# rows: 37
# rows: 88
# ---- 57 ----
# rows: 41
# rows: 89
# ---- 58 ----
# rows: 80
# ---- 59 ----
# rows: 78
# ---- 60 ----
# rows: 103
# ---- 61 ----
# rows: 101
# ---- 62 ----
# rows: 109
# ---- 63 ----
# rows: 99
# ---- 64 ----
# rows: 100
# ---- 65 ----
# rows: 103
# ---- 66 ----
# rows: 77
# ---- 67 ----
# rows: 87
# ---- 68 ----
# rows: 96
# ---- 69 ----
# rows: 75
# ---- 70 ----
# rows: 71
# ---- 71 ----
# rows: 70
# ---- 72 ----
# rows: 64
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 73 ----
# rows: 82
# ---- 74 ----
# rows: 71
# ---- 75 ----
# rows: 93
# ---- 76 ----
# rows: 112
# ---- 77 ----
# rows: 92
# ---- 78 ----
# rows: 91
# ---- 79 ----
# rows: 105
# ---- 80 ----
# rows: 106
# ---- 81 ----
# rows: 117
# ---- 82 ----
# rows: 114
# ---- 83 ----
# rows: 112
# ---- 84 ----
# rows: 100
# ---- 85 ----
# rows: 108
# ---- 86 ----
# rows: 101
# ---- 87 ----
# rows: 112
# ---- 88 ----
# rows: 108
# ---- 89 ----
# rows: 48
# rows: 109
# ---- 90 ----
# rows: 101
# ---- 91 ----
# rows: 106
# ---- 92 ----
# rows: 104
# ---- 93 ----
# rows: 111
# ---- 94 ----
# rows: 86
# ---- 95 ----
# rows: 94
# ---- 96 ----
# rows: 103
# ---- 97 ----
# rows: 112
# ---- 98 ----
# rows: 103
# ---- 99 ----
# rows: 95
# Done Trimming extra 100 files
# ----------------- Word gulay-----------------
# ---- 0 ----
# rows: 125
# ---- 1 ----
# rows: 134
# ---- 2 ----
# rows: 134
# ---- 3 ----
# rows: 134
# ---- 4 ----
# rows: 115
# ---- 5 ----
# rows: 88
# ---- 6 ----
# rows: 82
# ---- 7 ----
# rows: 94
# ---- 8 ----
# rows: 79
# ---- 9 ----
# rows: 90
# ---- 10 ----
# rows: 93
# ---- 11 ----
# rows: 97
# ---- 12 ----
# rows: 81
# ---- 13 ----
# rows: 98
# ---- 14 ----
# rows: 100
# ---- 15 ----
# rows: 21
# rows: 124
# ---- 16 ----
# rows: 21
# rows: 22
# rows: 23
# rows: 125
# ---- 17 ----
# rows: 21
# rows: 22
# rows: 23
# rows: 122
# ---- 18 ----
# rows: 21
# rows: 22
# rows: 23
# rows: 126
# ---- 19 ----
# rows: 21
# rows: 22
# rows: 128
# ---- 20 ----
# rows: 103
# ---- 21 ----
# rows: 114
# ---- 22 ----
# rows: 118
# ---- 23 ----
# rows: 125
# ---- 24 ----
# rows: 135
# ---- 25 ----
# rows: 93
# ---- 26 ----
# rows: 84
# ---- 27 ----
# rows: 72
# ---- 28 ----
# rows: 88
# ---- 29 ----
# rows: 99
# ---- 30 ----
# rows: 118
# ---- 31 ----
# rows: 124
# ---- 32 ----
# rows: 112
# ---- 33 ----
# rows: 134
# ---- 34 ----
# rows: 149
# ---- 35 ----
# rows: 102
# ---- 36 ----
# rows: 75
# ---- 37 ----
# rows: 90
# ---- 38 ----
# rows: 88
# ---- 39 ----
# rows: 90
# ---- 40 ----
# rows: 97
# ---- 41 ----
# rows: 91
# ---- 42 ----
# rows: 97
# ---- 43 ----
# rows: 102
# ---- 44 ----
# rows: 100
# ---- 45 ----
# rows: 131
# ---- 46 ----
# rows: 48
# rows: 120
# ---- 47 ----
# rows: 130
# ---- 48 ----
# rows: 125
# ---- 49 ----
# rows: 52
# rows: 120
# ---- 50 ----
# rows: 107
# ---- 51 ----
# rows: 119
# ---- 52 ----
# rows: 127
# ---- 53 ----
# rows: 117
# ---- 54 ----
# rows: 119
# ---- 55 ----
# rows: 21
# rows: 85
# ---- 56 ----
# rows: 47
# rows: 88
# ---- 57 ----
# rows: 96
# ---- 58 ----
# rows: 21
# rows: 93
# ---- 59 ----
# rows: 21
# rows: 41
# rows: 60
# rows: 93
# ---- 60 ----
# rows: 113
# ---- 61 ----
# rows: 108
# ---- 62 ----
# rows: 115
# ---- 63 ----
# rows: 118
# ---- 64 ----
# rows: 114
# ---- 65 ----
# rows: 86
# ---- 66 ----
# rows: 105
# ---- 67 ----
# rows: 93
# ---- 68 ----
# rows: 86
# ---- 69 ----
# rows: 99
# ---- 70 ----
# rows: 74
# ---- 71 ----
# rows: 21
# rows: 93
# ---- 72 ----
# rows: 87
# ---- 73 ----
# rows: 86
# ---- 74 ----
# rows: 82
# ---- 75 ----
# rows: 96
# ---- 76 ----
# rows: 98
# ---- 77 ----
# rows: 43
# rows: 76
# ---- 78 ----
# rows: 84
# ---- 79 ----
# rows: 80
# ---- 80 ----
# rows: 115
# ---- 81 ----
# rows: 110
# ---- 82 ----
# rows: 109
# ---- 83 ----
# rows: 100
# ---- 84 ----
# rows: 102
# ---- 85 ----
# rows: 95
# ---- 86 ----
# rows: 89
# ---- 87 ----
# rows: 92
# ---- 88 ----
# rows: 96
# ---- 89 ----
# rows: 97
# ---- 90 ----
# rows: 94
# ---- 91 ----
# rows: 101
# ---- 92 ----
# rows: 123
#  NO END ey
# ---- 93 ----
# rows: 120
#  NO END ey
# ---- 94 ----
# rows: 120
# ---- 95 ----
# rows: 105
# ---- 96 ----
# rows: 110
# ---- 97 ----
# rows: 103
# ---- 98 ----
# rows: 101
# ---- 99 ----
# rows: 102
# Done Trimming gulay 100 files
# ----------------- Word gusto-----------------
# ---- 0 ----
# rows: 97
# ---- 1 ----
# rows: 84
#  NO END ey
# ---- 2 ----
# rows: 46
# rows: 59
# rows: 60
# rows: 69
# rows: 70
# ---- 3 ----
# rows: 77
# ---- 4 ----
# rows: 86
# ---- 5 ----
# rows: 75
# ---- 6 ----
# rows: 89
# ---- 7 ----
# rows: 74
# ---- 8 ----
# rows: 78
#  NO END ey
# ---- 9 ----
# rows: 81
# ---- 10 ----
# rows: 78
# ---- 11 ----
# rows: 82
# ---- 12 ----
# rows: 100
# ---- 13 ----
# rows: 99
# ---- 14 ----
# rows: 88
# ---- 15 ----
# rows: 128
# ---- 16 ----
# rows: 136
# ---- 17 ----
# rows: 138
# ---- 18 ----
# rows: 137
# ---- 19 ----
# rows: 147
# ---- 20 ----
# rows: 112
# ---- 21 ----
# rows: 129
# ---- 22 ----
# rows: 118
# ---- 23 ----
# rows: 117
# ---- 24 ----
# rows: 113
# ---- 25 ----
# rows: 71
# ---- 26 ----
# rows: 77
# ---- 27 ----
# rows: 85
# ---- 28 ----
# rows: 77
# ---- 29 ----
# rows: 98
# ---- 30 ----
# rows: 106
# ---- 31 ----
# rows: 98
# ---- 32 ----
# rows: 102
# ---- 33 ----
# rows: 124
# ---- 34 ----
# rows: 107
# ---- 35 ----
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 36 ----
# rows: 53
# rows: 54
# rows: 55
# rows: 56
# rows: 57
# rows: 58
# rows: 59
# rows: 60
# rows: 61
# rows: 62
# rows: 63
# rows: 64
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 37 ----
# rows: 73
# ---- 38 ----
# rows: 72
# ---- 39 ----
# rows: 70
# ---- 40 ----
# rows: 77
# ---- 41 ----
# rows: 68
# rows: 69
# rows: 70
# ---- 42 ----
# rows: 80
# ---- 43 ----
# rows: 80
# ---- 44 ----
# rows: 63
# rows: 64
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 45 ----
# rows: 113
# ---- 46 ----
# rows: 38
# rows: 39
# rows: 92
# ---- 47 ----
# rows: 86
# ---- 48 ----
# rows: 75
# ---- 49 ----
# rows: 77
# ---- 50 ----
# rows: 70
# ---- 51 ----
# rows: 61
# rows: 62
# rows: 63
# rows: 64
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 52 ----
# rows: 102
# ---- 53 ----
# rows: 41
# rows: 106
# ---- 54 ----
# rows: 68
# rows: 71
# ---- 55 ----
# rows: 31
# rows: 32
# rows: 33
# rows: 45
# rows: 46
# rows: 47
# rows: 48
# rows: 49
# rows: 50
# rows: 77
# ---- 56 ----
# rows: 36
# rows: 37
# rows: 38
# rows: 51
# rows: 52
# rows: 53
# rows: 54
# rows: 55
# rows: 56
# rows: 78
# ---- 57 ----
# rows: 35
# rows: 100
# ---- 58 ----
# rows: 40
# rows: 41
# rows: 60
# rows: 61
# rows: 62
# rows: 112
# ---- 59 ----
# rows: 63
# rows: 104
# ---- 60 ----
# rows: 79
# ---- 61 ----
# rows: 80
# ---- 62 ----
# rows: 49
# rows: 50
# rows: 51
# rows: 52
# rows: 53
# rows: 54
# rows: 55
# rows: 56
# rows: 57
# rows: 58
# rows: 59
# rows: 60
# rows: 61
# rows: 62
# rows: 63
# rows: 64
# rows: 65
# rows: 66
# rows: 67
# rows: 69
# rows: 70
# ---- 63 ----
# rows: 48
# rows: 49
# rows: 50
# rows: 51
# rows: 52
# rows: 53
# rows: 54
# rows: 55
# rows: 56
# rows: 57
# rows: 58
# rows: 59
# rows: 60
# rows: 61
# rows: 62
# rows: 63
# rows: 64
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 64 ----
# rows: 52
# rows: 55
# rows: 56
# rows: 57
# rows: 58
# rows: 59
# rows: 60
# rows: 61
# rows: 62
# rows: 63
# rows: 64
# rows: 65
# rows: 66
# rows: 67
# rows: 72
# ---- 65 ----
# rows: 96
# ---- 66 ----
# rows: 90
# ---- 67 ----
# rows: 89
# ---- 68 ----
# rows: 116
# ---- 69 ----
# rows: 82
# ---- 70 ----
# rows: 91
# ---- 71 ----
# rows: 97
# ---- 72 ----
#  NO END ey
# ---- 73 ----
# rows: 115
# ---- 74 ----
# rows: 85
# ---- 75 ----
# rows: 33
# rows: 34
# rows: 103
# ---- 76 ----
# rows: 111
# ---- 77 ----
# rows: 30
# rows: 31
# rows: 125
# ---- 78 ----
# rows: 26
# rows: 27
# rows: 28
# rows: 29
# rows: 30
# rows: 31
# rows: 32
# rows: 33
# rows: 114
# ---- 79 ----
# rows: 31
# rows: 32
# rows: 33
# rows: 34
# rows: 35
# rows: 36
# rows: 37
# rows: 133
# ---- 80 ----
# rows: 111
# ---- 81 ----
# rows: 105
# ---- 82 ----
# rows: 111
# ---- 83 ----
# rows: 125
# ---- 84 ----
# rows: 112
# ---- 85 ----
# rows: 33
# rows: 34
# rows: 91
# ---- 86 ----
# rows: 71
# ---- 87 ----
# rows: 78
# ---- 88 ----
# rows: 70
# ---- 89 ----
# rows: 77
# ---- 90 ----
# rows: 71
# ---- 91 ----
# rows: 73
# ---- 92 ----
# rows: 82
# ---- 93 ----
# rows: 86
# ---- 94 ----
# rows: 61
# rows: 62
# rows: 63
# rows: 64
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 95 ----
# rows: 88
# ---- 96 ----
# rows: 68
# rows: 69
# rows: 70
# ---- 97 ----
# rows: 60
# rows: 61
# rows: 62
# rows: 63
# rows: 64
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 98 ----
# rows: 70
# ---- 99 ----
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# Done Trimming gusto 100 files
# ----------------- Word itlog-----------------
# ---- 0 ----
# rows: 110
# ---- 1 ----
# rows: 117
# ---- 2 ----
# rows: 131
# ---- 3 ----
# rows: 105
# ---- 4 ----
# rows: 104
# ---- 5 ----
# rows: 62
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 70
# ---- 6 ----
# rows: 82
# ---- 7 ----
# rows: 81
#  NO END ey
# ---- 8 ----
# rows: 96
#  NO END ey
# ---- 9 ----
#  NO END ey
# ---- 10 ----
# rows: 86
# ---- 11 ----
# rows: 90
# ---- 12 ----
# rows: 87
# ---- 13 ----
# rows: 94
# ---- 14 ----
# rows: 95
# ---- 15 ----
# rows: 90
# ---- 16 ----
# rows: 99
# ---- 17 ----
# rows: 104
# ---- 18 ----
# rows: 114
# ---- 19 ----
# rows: 104
# ---- 20 ----
# rows: 108
# ---- 21 ----
# rows: 94
# ---- 22 ----
# rows: 100
# ---- 23 ----
# rows: 108
# ---- 24 ----
# rows: 105
# ---- 25 ----
# rows: 86
# ---- 26 ----
# rows: 85
# ---- 27 ----
# rows: 82
# ---- 28 ----
# rows: 91
# ---- 29 ----
# rows: 93
# ---- 30 ----
# rows: 88
# ---- 31 ----
# rows: 84
# ---- 32 ----
# rows: 96
# ---- 33 ----
# rows: 85
# ---- 34 ----
# rows: 91
# ---- 35 ----
# rows: 90
# ---- 36 ----
# rows: 101
# ---- 37 ----
# rows: 101
# ---- 38 ----
# rows: 105
# ---- 39 ----
# rows: 103
# ---- 40 ----
# rows: 76
# ---- 41 ----
# rows: 80
# ---- 42 ----
# rows: 74
# ---- 43 ----
# rows: 73
# ---- 44 ----
# rows: 61
# rows: 62
# rows: 63
# rows: 64
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 73
# ---- 45 ----
# rows: 82
# ---- 46 ----
# rows: 88
# ---- 47 ----
# rows: 77
# ---- 48 ----
# rows: 85
# ---- 49 ----
# rows: 78
# ---- 50 ----
# rows: 96
# ---- 51 ----
# rows: 84
# ---- 52 ----
# rows: 91
# ---- 53 ----
# rows: 96
# ---- 54 ----
# rows: 102
# ---- 55 ----
# rows: 105
# ---- 56 ----
# rows: 95
# ---- 57 ----
# rows: 111
# ---- 58 ----
# rows: 110
# ---- 59 ----
# rows: 119
# ---- 60 ----
# rows: 96
# ---- 61 ----
# rows: 100
# ---- 62 ----
# rows: 108
# ---- 63 ----
# rows: 100
# ---- 64 ----
# rows: 99
# ---- 65 ----
# rows: 82
# ---- 66 ----
# rows: 94
# ---- 67 ----
# rows: 84
# ---- 68 ----
# rows: 77
# ---- 69 ----
# rows: 76
# ---- 70 ----
# rows: 76
# ---- 71 ----
# rows: 76
# ---- 72 ----
# rows: 87
# ---- 73 ----
# rows: 86
# ---- 74 ----
# rows: 64
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 78
# ---- 75 ----
# rows: 87
# ---- 76 ----
# rows: 48
# rows: 86
# ---- 77 ----
# rows: 85
# ---- 78 ----
# rows: 51
# rows: 52
# rows: 93
# ---- 79 ----
# rows: 53
# rows: 89
# ---- 80 ----
# rows: 103
# ---- 81 ----
# rows: 98
# ---- 82 ----
# rows: 68
# rows: 102
# ---- 83 ----
# rows: 57
# rows: 58
# rows: 59
# rows: 60
# rows: 61
# rows: 62
# rows: 89
# ---- 84 ----
# rows: 90
# ---- 85 ----
# rows: 86
# ---- 86 ----
# rows: 77
# ---- 87 ----
# rows: 79
# ---- 88 ----
# rows: 79
# ---- 89 ----
# rows: 88
# ---- 90 ----
# rows: 77
# ---- 91 ----
# rows: 90
# ---- 92 ----
# rows: 85
# ---- 93 ----
# rows: 93
# ---- 94 ----
# rows: 77
# ---- 95 ----
# rows: 113
# ---- 96 ----
# rows: 88
# ---- 97 ----
# rows: 83
# ---- 98 ----
# rows: 78
# ---- 99 ----
# rows: 85
# Done Trimming itlog 100 files
# ----------------- Word juice-----------------
# ---- 0 ----
# rows: 84
# ---- 1 ----
# rows: 82
# ---- 2 ----
# rows: 98
# ---- 3 ----
# rows: 96
# ---- 4 ----
# rows: 102
#  NO END ey
# ---- 5 ----
# rows: 99
#  NO END ey
# ---- 6 ----
# rows: 88
#  NO END ey
# ---- 7 ----
# rows: 100
# ---- 8 ----
# rows: 111
# ---- 9 ----
# rows: 111
# ---- 10 ----
# rows: 97
# ---- 11 ----
# rows: 96
# ---- 12 ----
# rows: 90
# ---- 13 ----
# rows: 24
# rows: 95
# ---- 14 ----
# rows: 82
# ---- 15 ----
# rows: 21
# rows: 22
# rows: 112
# ---- 16 ----
# rows: 21
# rows: 119
# ---- 17 ----
# rows: 21
# rows: 22
# rows: 23
# rows: 24
# rows: 119
# ---- 18 ----
# rows: 21
# rows: 113
# ---- 19 ----
# rows: 21
# rows: 126
# ---- 20 ----
# rows: 112
# ---- 21 ----
# rows: 102
# ---- 22 ----
# rows: 136
# ---- 23 ----
# rows: 144
# ---- 24 ----
# rows: 137
# ---- 25 ----
# rows: 121
# ---- 26 ----
# rows: 130
# ---- 27 ----
# rows: 124
# ---- 28 ----
# rows: 122
# ---- 29 ----
# rows: 124
# ---- 30 ----
# rows: 121
# ---- 31 ----
# rows: 124
# ---- 32 ----
# rows: 143
# ---- 33 ----
# rows: 144
# ---- 34 ----
# rows: 132
# ---- 35 ----
# rows: 122
# ---- 36 ----
# rows: 119
# ---- 37 ----
# rows: 110
# ---- 38 ----
# rows: 105
# ---- 39 ----
# rows: 90
# ---- 40 ----
# rows: 95
# ---- 41 ----
# rows: 91
# ---- 42 ----
# rows: 85
# ---- 43 ----
# rows: 81
# ---- 44 ----
# rows: 95
# ---- 45 ----
# rows: 106
# ---- 46 ----
# rows: 109
# ---- 47 ----
# rows: 145
# ---- 48 ----
# rows: 116
# ---- 49 ----
# rows: 150
# ---- 50 ----
# rows: 114
# ---- 51 ----
# rows: 115
# ---- 52 ----
# rows: 114
# ---- 53 ----
# rows: 133
# ---- 54 ----
# rows: 124
# ---- 55 ----
# rows: 104
# ---- 56 ----
# rows: 130
# ---- 57 ----
# rows: 121
# ---- 58 ----
# rows: 109
# ---- 59 ----
# rows: 109
# ---- 60 ----
# rows: 105
# ---- 61 ----
# rows: 114
# ---- 62 ----
# rows: 111
# ---- 63 ----
# rows: 106
# ---- 64 ----
# rows: 110
# ---- 65 ----
# rows: 120
# ---- 66 ----
# rows: 121
# ---- 67 ----
# rows: 102
# ---- 68 ----
# rows: 116
# ---- 69 ----
# rows: 109
# ---- 70 ----
# rows: 90
# ---- 71 ----
# rows: 85
# ---- 72 ----
# rows: 88
# ---- 73 ----
# rows: 99
# ---- 74 ----
# rows: 110
# ---- 75 ----
# rows: 91
# ---- 76 ----
# rows: 127
# ---- 77 ----
# rows: 116
# ---- 78 ----
# rows: 116
# ---- 79 ----
# rows: 120
# ---- 80 ----
# rows: 104
# ---- 81 ----
# rows: 120
# ---- 82 ----
# rows: 125
# ---- 83 ----
# rows: 107
# ---- 84 ----
# rows: 107
# ---- 85 ----
# rows: 112
# ---- 86 ----
# rows: 106
# ---- 87 ----
# rows: 102
# ---- 88 ----
# rows: 112
# ---- 89 ----
# rows: 118
# ---- 90 ----
# rows: 97
# ---- 91 ----
# rows: 115
# ---- 92 ----
# rows: 118
# ---- 93 ----
# rows: 121
# ---- 94 ----
# rows: 121
# ---- 95 ----
# rows: 136
# ---- 96 ----
# rows: 128
# ---- 97 ----
# rows: 127
# ---- 98 ----
# rows: 122
# ---- 99 ----
# rows: 140
# Done Trimming juice 100 files
# ----------------- Word kape-----------------
# ---- 0 ----
# rows: 105
# ---- 1 ----
# rows: 112
#  NO END ey
# ---- 2 ----
# rows: 120
#  NO END ey
# ---- 3 ----
# rows: 117
#  NO END ey
# ---- 4 ----
# rows: 111
#  NO END ey
# ---- 5 ----
#  NO END ey
# ---- 6 ----
# rows: 33
# rows: 34
# rows: 107
# ---- 7 ----
# rows: 112
# ---- 8 ----
# rows: 116
# ---- 9 ----
# rows: 107
# ---- 10 ----
# rows: 38
# rows: 87
# ---- 11 ----
# rows: 36
# rows: 87
# ---- 12 ----
# rows: 91
# ---- 13 ----
# rows: 41
# rows: 88
# ---- 14 ----
# rows: 23
# rows: 24
# rows: 94
# ---- 15 ----
# rows: 126
# ---- 16 ----
# rows: 121
# ---- 17 ----
# rows: 110
# ---- 18 ----
# rows: 120
# ---- 19 ----
# rows: 116
# ---- 20 ----
# rows: 118
# ---- 21 ----
# rows: 148
# ---- 22 ----
# rows: 150
# ---- 23 ----
# rows: 137
# ---- 24 ----
# rows: 134
# ---- 25 ----
# rows: 97
# ---- 26 ----
# rows: 100
# ---- 27 ----
# rows: 120
# ---- 28 ----
# rows: 118
# ---- 29 ----
# rows: 116
# ---- 30 ----
# rows: 113
# ---- 31 ----
# rows: 118
# ---- 32 ----
# rows: 137
# ---- 33 ----
# rows: 137
# ---- 34 ----
# rows: 137
# ---- 35 ----
# rows: 96
# ---- 36 ----
# rows: 92
# ---- 37 ----
# rows: 97
# ---- 38 ----
# rows: 110
# ---- 39 ----
# rows: 106
# ---- 40 ----
# rows: 78
# ---- 41 ----
# rows: 92
# ---- 42 ----
# rows: 74
# ---- 43 ----
# rows: 107
# ---- 44 ----
# rows: 89
# ---- 45 ----
# rows: 131
# ---- 46 ----
# rows: 118
# ---- 47 ----
# rows: 124
# ---- 48 ----
# rows: 119
# ---- 49 ----
# rows: 119
# ---- 50 ----
# rows: 23
# rows: 24
# rows: 27
# rows: 28
# rows: 29
# rows: 30
# rows: 31
# rows: 38
# rows: 39
# rows: 40
# rows: 41
# rows: 42
# rows: 43
# rows: 44
# rows: 45
# rows: 46
# rows: 47
# rows: 48
# rows: 49
# rows: 50
# rows: 51
# rows: 52
# rows: 66
# rows: 140
# ---- 51 ----
# rows: 99
# ---- 52 ----
# rows: 111
# ---- 53 ----
# rows: 105
# ---- 54 ----
# rows: 110
# ---- 55 ----
# rows: 100
# ---- 56 ----
# rows: 90
# ---- 57 ----
# rows: 105
# ---- 58 ----
# rows: 92
# ---- 59 ----
# rows: 101
# ---- 60 ----
# rows: 111
# ---- 61 ----
# rows: 101
# ---- 62 ----
# rows: 108
# ---- 63 ----
# rows: 105
# ---- 64 ----
# rows: 109
# ---- 65 ----
# rows: 106
# ---- 66 ----
# rows: 116
# ---- 67 ----
# rows: 103
# ---- 68 ----
# rows: 108
# ---- 69 ----
# rows: 109
# ---- 70 ----
# rows: 81
# ---- 71 ----
# rows: 102
# ---- 72 ----
# rows: 117
# ---- 73 ----
# rows: 94
# ---- 74 ----
# rows: 106
# ---- 75 ----
# rows: 100
# ---- 76 ----
# rows: 95
# ---- 77 ----
# rows: 61
# rows: 91
# ---- 78 ----
# rows: 66
# rows: 104
# ---- 79 ----
# rows: 103
# ---- 80 ----
# rows: 105
# ---- 81 ----
# rows: 77
# ---- 82 ----
# rows: 104
# ---- 83 ----
# rows: 53
# rows: 54
# rows: 55
# rows: 99
# ---- 84 ----
# rows: 106
# ---- 85 ----
# rows: 100
# ---- 86 ----
# rows: 96
# ---- 87 ----
# rows: 89
# ---- 88 ----
# rows: 95
# ---- 89 ----
# rows: 94
# ---- 90 ----
# rows: 111
# ---- 91 ----
# rows: 123
# ---- 92 ----
# rows: 98
# ---- 93 ----
# rows: 121
# ---- 94 ----
# rows: 121
# ---- 95 ----
# rows: 111
# ---- 96 ----
# rows: 115
# ---- 97 ----
# rows: 118
# ---- 98 ----
# rows: 122
# ---- 99 ----
# rows: 128
# Done Trimming kape 100 files
# ----------------- Word kilo-----------------
# ---- 0 ----
# rows: 107
# ---- 1 ----
# rows: 101
# ---- 2 ----
#  NO END ey
# ---- 3 ----
# rows: 124
#  NO END ey
# ---- 4 ----
# rows: 118
#  NO END ey
# ---- 5 ----
# rows: 106
# ---- 6 ----
# rows: 119
# ---- 7 ----
# rows: 127
# ---- 8 ----
# rows: 127
#  NO END ey
# ---- 9 ----
# rows: 122
# ---- 10 ----
# rows: 116
# ---- 11 ----
# rows: 118
# ---- 12 ----
# rows: 124
# ---- 13 ----
# rows: 131
# ---- 14 ----
# rows: 120
# ---- 15 ----
# rows: 137
# ---- 16 ----
# rows: 137
# ---- 17 ----
# rows: 135
# ---- 18 ----
# rows: 145
# ---- 19 ----
# rows: 134
# ---- 20 ----
# rows: 21
# rows: 122
# ---- 21 ----
# rows: 142
# ---- 22 ----
# rows: 129
# ---- 23 ----
# rows: 133
# ---- 24 ----
# rows: 142
# ---- 25 ----
# rows: 128
# ---- 26 ----
# rows: 130
# ---- 27 ----
# rows: 128
# ---- 28 ----
# rows: 133
# ---- 29 ----
# rows: 129
# ---- 30 ----
# rows: 130
# ---- 31 ----
# rows: 143
# ---- 32 ----
# rows: 152
# ---- 33 ----
# rows: 155
# ---- 34 ----
# rows: 128
# ---- 35 ----
# rows: 123
# ---- 36 ----
# rows: 109
# ---- 37 ----
# rows: 128
# ---- 38 ----
# rows: 117
# ---- 39 ----
# rows: 124
# ---- 40 ----
# rows: 105
# ---- 41 ----
# rows: 99
# ---- 42 ----
# rows: 115
# ---- 43 ----
# rows: 106
# ---- 44 ----
# rows: 103
# ---- 45 ----
# rows: 137
# ---- 46 ----
# rows: 158
# ---- 47 ----
# rows: 25
# rows: 148
# ---- 48 ----
# rows: 163
# ---- 49 ----
# rows: 153
# ---- 50 ----
# rows: 115
# ---- 51 ----
# rows: 123
# ---- 52 ----
# rows: 129
# ---- 53 ----
# rows: 129
# ---- 54 ----
# rows: 134
# ---- 55 ----
# rows: 109
# ---- 56 ----
# rows: 123
# ---- 57 ----
# rows: 22
# rows: 23
# rows: 24
# rows: 25
# rows: 26
# rows: 27
# rows: 129
# ---- 58 ----
# rows: 128
# ---- 59 ----
# rows: 120
# ---- 60 ----
# rows: 136
# ---- 61 ----
# rows: 155
# ---- 62 ----
# rows: 153
# ---- 63 ----
# rows: 165
# ---- 64 ----
# rows: 162
# ---- 65 ----
# rows: 120
# ---- 66 ----
# rows: 134
# ---- 67 ----
# rows: 140
# ---- 68 ----
# rows: 143
# ---- 69 ----
# rows: 139
# ---- 70 ----
# rows: 104
# ---- 71 ----
# rows: 106
# ---- 72 ----
# rows: 114
# ---- 73 ----
# rows: 116
# ---- 74 ----
# rows: 99
# ---- 75 ----
# rows: 21
# rows: 22
# rows: 23
# rows: 24
# rows: 25
# rows: 123
# ---- 76 ----
# rows: 133
# ---- 77 ----
# rows: 21
# rows: 148
# ---- 78 ----
# rows: 129
# ---- 79 ----
# rows: 138
# ---- 80 ----
# rows: 131
# ---- 81 ----
# rows: 152
# ---- 82 ----
# rows: 148
# ---- 83 ----
# rows: 145
# ---- 84 ----
# rows: 137
# ---- 85 ----
# rows: 113
# ---- 86 ----
# rows: 117
# ---- 87 ----
# rows: 109
# ---- 88 ----
# rows: 113
# ---- 89 ----
# rows: 113
# ---- 90 ----
# rows: 113
# ---- 91 ----
# rows: 154
# ---- 92 ----
# rows: 132
# ---- 93 ----
# rows: 136
# ---- 94 ----
# rows: 128
# ---- 95 ----
# rows: 127
# ---- 96 ----
# rows: 122
# ---- 97 ----
# rows: 126
# ---- 98 ----
# rows: 126
# ---- 99 ----
# rows: 131
# Done Trimming kilo 100 files
# ----------------- Word mahal-----------------
# ---- 0 ----
# rows: 39
# rows: 40
# rows: 105
#  NO END ey
# ---- 1 ----
# rows: 45
# rows: 109
#  NO END ey
# ---- 2 ----
# rows: 43
# rows: 92
# ---- 3 ----
# rows: 46
# rows: 47
# rows: 100
# ---- 4 ----
# rows: 30
# rows: 31
# rows: 84
# ---- 5 ----
# rows: 42
# rows: 81
# ---- 6 ----
# rows: 46
# rows: 105
# ---- 7 ----
# rows: 45
# rows: 115
# ---- 8 ----
# rows: 102
# ---- 9 ----
# rows: 48
# rows: 110
# ---- 10 ----
# rows: 37
# rows: 40
# rows: 85
# ---- 11 ----
# rows: 38
# rows: 41
# rows: 78
# ---- 12 ----
# rows: 40
# rows: 43
# rows: 92
# ---- 13 ----
# rows: 37
# rows: 40
# rows: 83
# ---- 14 ----
# rows: 40
# rows: 43
# rows: 93
# ---- 15 ----
# rows: 21
# rows: 22
# rows: 23
# rows: 45
# rows: 107
# ---- 16 ----
# rows: 53
# rows: 54
# rows: 122
# ---- 17 ----
# rows: 50
# rows: 125
# ---- 18 ----
# rows: 48
# rows: 49
# rows: 128
# ---- 19 ----
# rows: 52
# rows: 136
# ---- 20 ----
# rows: 31
# rows: 95
# ---- 21 ----
# rows: 36
# rows: 106
# ---- 22 ----
# rows: 101
# ---- 23 ----
# rows: 41
# rows: 105
# ---- 24 ----
# rows: 98
# ---- 25 ----
# rows: 40
# rows: 41
# rows: 96
# ---- 26 ----
# rows: 43
# rows: 125
# ---- 27 ----
# rows: 46
# rows: 131
# ---- 28 ----
# rows: 39
# rows: 114
# ---- 29 ----
# rows: 38
# rows: 103
# ---- 30 ----
# rows: 34
# rows: 95
# ---- 31 ----
# rows: 41
# rows: 105
# ---- 32 ----
# rows: 40
# rows: 102
# ---- 33 ----
# rows: 42
# rows: 46
# rows: 108
# ---- 34 ----
# rows: 106
# ---- 35 ----
# rows: 33
# rows: 91
# ---- 36 ----
# rows: 40
# rows: 86
# ---- 37 ----
# rows: 33
# rows: 34
# rows: 90
# ---- 38 ----
# rows: 41
# rows: 108
# ---- 39 ----
# rows: 39
# rows: 107
# ---- 40 ----
# rows: 79
# ---- 41 ----
# rows: 78
# ---- 42 ----
# rows: 81
# ---- 43 ----
# rows: 89
# ---- 44 ----
# rows: 89
# ---- 45 ----
# rows: 110
# ---- 46 ----
# rows: 96
# ---- 47 ----
# rows: 91
# ---- 48 ----
# rows: 105
# ---- 49 ----
# rows: 120
#  NO END ey
# ---- 50 ----
# rows: 85
# ---- 51 ----
# rows: 94
# ---- 52 ----
# rows: 94
# ---- 53 ----
# rows: 103
# ---- 54 ----
# rows: 93
# ---- 55 ----
# rows: 46
# rows: 47
# rows: 99
# ---- 56 ----
# rows: 46
# rows: 47
# rows: 99
# ---- 57 ----
# rows: 39
# rows: 120
# ---- 58 ----
# rows: 51
# rows: 126
# ---- 59 ----
# rows: 44
# rows: 45
# rows: 94
# ---- 60 ----
# rows: 42
# rows: 85
# ---- 61 ----
# rows: 45
# rows: 46
# rows: 91
# ---- 62 ----
# rows: 45
# rows: 86
# ---- 63 ----
# rows: 43
# rows: 85
# ---- 64 ----
# rows: 48
# rows: 90
# ---- 65 ----
# rows: 40
# rows: 41
# rows: 82
# ---- 66 ----
# rows: 36
# rows: 37
# rows: 72
# ---- 67 ----
# rows: 43
# rows: 86
# ---- 68 ----
# rows: 41
# rows: 42
# rows: 87
# ---- 69 ----
# rows: 39
# rows: 40
# rows: 93
# ---- 70 ----
# rows: 86
# ---- 71 ----
# rows: 89
# ---- 72 ----
# rows: 96
# ---- 73 ----
# rows: 85
# ---- 74 ----
# rows: 87
# ---- 75 ----
# rows: 39
# rows: 40
# rows: 44
# rows: 101
# ---- 76 ----
# rows: 43
# rows: 116
# ---- 77 ----
# rows: 36
# rows: 39
# rows: 88
# ---- 78 ----
# rows: 41
# rows: 97
# ---- 79 ----
# rows: 45
# rows: 46
# rows: 104
# ---- 80 ----
# rows: 79
# ---- 81 ----
# rows: 70
# ---- 82 ----
# rows: 75
# ---- 83 ----
# rows: 71
# ---- 84 ----
# rows: 71
# ---- 85 ----
# rows: 86
# ---- 86 ----
# rows: 40
# rows: 95
# ---- 87 ----
# rows: 39
# rows: 90
# ---- 88 ----
# rows: 76
# ---- 89 ----
# rows: 41
# rows: 82
# ---- 90 ----
# rows: 39
# rows: 79
# ---- 91 ----
# rows: 42
# rows: 75
# ---- 92 ----
# rows: 47
# rows: 79
# ---- 93 ----
# rows: 45
# rows: 88
# ---- 94 ----
# rows: 44
# rows: 93
# ---- 95 ----
# rows: 91
#  NO END ey
# ---- 96 ----
# rows: 108
# ---- 97 ----
# rows: 113
# ---- 98 ----
# rows: 96
# ---- 99 ----
#  NO END ey
# Done Trimming mahal 100 files
# ----------------- Word malaki-----------------
# ---- 0 ----
# rows: 37
# rows: 113
# ---- 1 ----
# rows: 104
# ---- 2 ----
# rows: 105
#  NO END ey
# ---- 3 ----
# rows: 108
# ---- 4 ----
# rows: 39
# rows: 103
# ---- 5 ----
# rows: 109
# ---- 6 ----
# rows: 110
# ---- 7 ----
# rows: 85
# ---- 8 ----
# rows: 102
# ---- 9 ----
# rows: 90
# ---- 10 ----
# rows: 35
# rows: 75
# ---- 11 ----
# rows: 34
# rows: 37
# rows: 82
# ---- 12 ----
# rows: 34
# rows: 37
# rows: 84
# ---- 13 ----
# rows: 34
# rows: 37
# rows: 82
# ---- 14 ----
# rows: 36
# rows: 39
# rows: 81
# ---- 15 ----
# rows: 103
# ---- 16 ----
# rows: 114
# ---- 17 ----
# rows: 117
# ---- 18 ----
# rows: 113
# ---- 19 ----
# rows: 125
# ---- 20 ----
# rows: 96
# ---- 21 ----
# rows: 90
# ---- 22 ----
# rows: 84
# ---- 23 ----
# rows: 103
# ---- 24 ----
# rows: 91
# ---- 25 ----
# rows: 98
# ---- 26 ----
# rows: 96
# ---- 27 ----
# rows: 91
# ---- 28 ----
# rows: 98
# ---- 29 ----
# rows: 91
# ---- 30 ----
# rows: 93
# ---- 31 ----
# rows: 103
# ---- 32 ----
# rows: 103
# ---- 33 ----
# rows: 128
# ---- 34 ----
# rows: 93
# ---- 35 ----
# rows: 106
# ---- 36 ----
# rows: 123
# ---- 37 ----
# rows: 116
# ---- 38 ----
# rows: 125
# ---- 39 ----
# rows: 103
# ---- 40 ----
# rows: 74
# ---- 41 ----
# rows: 112
# ---- 42 ----
# rows: 88
# ---- 43 ----
# rows: 90
# ---- 44 ----
# rows: 108
# ---- 45 ----
# rows: 110
# ---- 46 ----
# rows: 114
# ---- 47 ----
# rows: 111
# ---- 48 ----
# rows: 92
# ---- 49 ----
# rows: 112
# ---- 50 ----
# rows: 92
# ---- 51 ----
# rows: 104
# ---- 52 ----
# rows: 101
# ---- 53 ----
# rows: 98
# ---- 54 ----
# rows: 102
# ---- 55 ----
# rows: 110
# ---- 56 ----
# rows: 114
# ---- 57 ----
# rows: 111
# ---- 58 ----
# rows: 108
# ---- 59 ----
# rows: 118
# ---- 60 ----
# rows: 85
# ---- 61 ----
# rows: 89
# ---- 62 ----
# rows: 87
# ---- 63 ----
# rows: 94
# ---- 64 ----
# rows: 82
# ---- 65 ----
# rows: 86
# ---- 66 ----
# rows: 93
# ---- 67 ----
# rows: 95
# ---- 68 ----
# rows: 89
# ---- 69 ----
# rows: 89
# ---- 70 ----
# rows: 78
# ---- 71 ----
# rows: 77
# ---- 72 ----
# rows: 87
# ---- 73 ----
# rows: 86
# ---- 74 ----
# rows: 81
# ---- 75 ----
# rows: 89
# ---- 76 ----
# rows: 95
# ---- 77 ----
# rows: 86
# ---- 78 ----
# rows: 98
# ---- 79 ----
# rows: 112
# ---- 80 ----
# rows: 85
# ---- 81 ----
# rows: 90
# ---- 82 ----
# rows: 85
# ---- 83 ----
# rows: 96
# ---- 84 ----
# rows: 89
# ---- 85 ----
# rows: 80
# ---- 86 ----
# rows: 101
# ---- 87 ----
# rows: 87
# ---- 88 ----
# rows: 92
# ---- 89 ----
# rows: 103
# ---- 90 ----
# rows: 89
# ---- 91 ----
# rows: 79
# ---- 92 ----
# rows: 77
# ---- 93 ----
# rows: 83
# ---- 94 ----
# rows: 86
# ---- 95 ----
# rows: 103
# ---- 96 ----
# rows: 103
# ---- 97 ----
# rows: 106
# ---- 98 ----
# rows: 108
# ---- 99 ----
# rows: 107
# Done Trimming malaki 100 files
# ----------------- Word maliit-----------------
# ---- 0 ----
# rows: 59
# rows: 94
# ---- 1 ----
# rows: 55
#  NO END ey
# ---- 2 ----
# rows: 57
# rows: 101
# ---- 3 ----
# rows: 62
# rows: 98
# ---- 4 ----
# rows: 65
# rows: 98
# ---- 5 ----
# rows: 62
# rows: 100
# ---- 6 ----
# rows: 105
# ---- 7 ----
# rows: 62
# rows: 105
#  NO END ey
# ---- 8 ----
# rows: 63
# rows: 102
# ---- 9 ----
# rows: 104
# ---- 10 ----
# rows: 45
# rows: 72
# ---- 11 ----
# rows: 72
# ---- 12 ----
# rows: 51
# rows: 52
# rows: 82
# ---- 13 ----
# rows: 47
# rows: 50
# rows: 74
# ---- 14 ----
# rows: 38
# rows: 61
# rows: 62
# rows: 63
# rows: 64
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 15 ----
# rows: 117
# ---- 16 ----
# rows: 120
# ---- 17 ----
# rows: 118
# ---- 18 ----
# rows: 119
# ---- 19 ----
# rows: 115
# ---- 20 ----
# rows: 85
# ---- 21 ----
# rows: 92
# ---- 22 ----
# rows: 82
# ---- 23 ----
# rows: 96
# ---- 24 ----
# rows: 103
# ---- 25 ----
# rows: 87
# ---- 26 ----
# rows: 90
# ---- 27 ----
# rows: 100
# ---- 28 ----
# rows: 94
# ---- 29 ----
# rows: 91
# ---- 30 ----
# rows: 59
# rows: 93
# ---- 31 ----
# rows: 76
# ---- 32 ----
# rows: 76
# ---- 33 ----
# rows: 118
# ---- 34 ----
# rows: 109
# ---- 35 ----
# rows: 60
# rows: 61
# rows: 102
# ---- 36 ----
# rows: 64
# rows: 96
# ---- 37 ----
# rows: 65
# rows: 66
# rows: 100
# ---- 38 ----
# rows: 54
# rows: 85
# ---- 39 ----
# rows: 54
# rows: 85
# ---- 40 ----
# rows: 90
# ---- 41 ----
# rows: 94
# ---- 42 ----
# rows: 88
# ---- 43 ----
# rows: 89
# ---- 44 ----
# rows: 90
# ---- 45 ----
# rows: 99
# ---- 46 ----
# rows: 115
# ---- 47 ----
# rows: 104
# ---- 48 ----
# rows: 100
# ---- 49 ----
# rows: 103
# ---- 50 ----
# rows: 91
# ---- 51 ----
# rows: 98
# ---- 52 ----
# rows: 112
# ---- 53 ----
# rows: 100
# ---- 54 ----
# rows: 111
# ---- 55 ----
# rows: 106
# ---- 56 ----
# rows: 100
# ---- 57 ----
# rows: 113
# ---- 58 ----
# rows: 110
# ---- 59 ----
# rows: 99
# ---- 60 ----
# rows: 89
# ---- 61 ----
# rows: 90
# ---- 62 ----
# rows: 95
# ---- 63 ----
# rows: 96
# ---- 64 ----
# rows: 90
# ---- 65 ----
# rows: 79
# ---- 66 ----
# rows: 78
# ---- 67 ----
# rows: 87
# ---- 68 ----
# rows: 89
# ---- 69 ----
# rows: 84
# ---- 70 ----
# rows: 72
# ---- 71 ----
# rows: 84
# ---- 72 ----
# rows: 80
# ---- 73 ----
# rows: 83
# ---- 74 ----
# rows: 83
# ---- 75 ----
# rows: 105
# ---- 76 ----
# rows: 108
# ---- 77 ----
# rows: 97
# ---- 78 ----
# rows: 99
# ---- 79 ----
# rows: 67
# rows: 89
# ---- 80 ----
# rows: 64
# rows: 103
# ---- 81 ----
# rows: 107
# ---- 82 ----
# rows: 110
# ---- 83 ----
# rows: 101
# ---- 84 ----
# rows: 56
# rows: 99
# ---- 85 ----
# rows: 92
# ---- 86 ----
# rows: 94
# ---- 87 ----
# rows: 105
# ---- 88 ----
# rows: 92
# ---- 89 ----
# rows: 88
# ---- 90 ----
# rows: 84
# ---- 91 ----
# rows: 81
# ---- 92 ----
# rows: 78
# ---- 93 ----
# rows: 78
# ---- 94 ----
# rows: 82
# ---- 95 ----
# rows: 91
# ---- 96 ----
# rows: 92
# ---- 97 ----
# rows: 93
# ---- 98 ----
# rows: 96
# ---- 99 ----
# rows: 96
# Done Trimming maliit 100 files
# ----------------- Word mayroon-----------------
# ---- 0 ----
# rows: 89
# ---- 1 ----
# rows: 84
# ---- 2 ----
# rows: 88
# ---- 3 ----
# rows: 85
# ---- 4 ----
# rows: 74
# ---- 5 ----
# rows: 75
# ---- 6 ----
# rows: 81
# ---- 7 ----
# rows: 78
# ---- 8 ----
# rows: 82
# ---- 9 ----
# rows: 83
# ---- 10 ----
# rows: 69
# rows: 70
# ---- 11 ----
# rows: 71
# ---- 12 ----
# rows: 71
# ---- 13 ----
# rows: 70
# ---- 14 ----
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 15 ----
# rows: 101
# ---- 16 ----
# rows: 96
# ---- 17 ----
# rows: 92
# ---- 18 ----
# rows: 124
# ---- 19 ----
# rows: 110
# ---- 20 ----
# rows: 76
# ---- 21 ----
# rows: 85
# ---- 22 ----
# rows: 87
# ---- 23 ----
# rows: 95
# ---- 24 ----
# rows: 90
# ---- 25 ----
# rows: 75
# ---- 26 ----
# rows: 85
# ---- 27 ----
# rows: 84
# ---- 28 ----
# rows: 81
# ---- 29 ----
# rows: 83
# ---- 30 ----
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 31 ----
# rows: 63
# rows: 64
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 32 ----
# rows: 74
# ---- 33 ----
# rows: 75
# ---- 34 ----
# rows: 73
# ---- 35 ----
# rows: 68
# rows: 69
# rows: 70
# ---- 36 ----
# rows: 71
# ---- 37 ----
# rows: 68
# rows: 69
# rows: 70
# ---- 38 ----
# rows: 83
# ---- 39 ----
# rows: 80
# ---- 40 ----
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 72
# ---- 41 ----
# rows: 63
# rows: 64
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 42 ----
# rows: 78
# ---- 43 ----
# rows: 73
# ---- 44 ----
# rows: 77
# ---- 45 ----
# rows: 89
# ---- 46 ----
# rows: 97
# ---- 47 ----
# rows: 103
# ---- 48 ----
# rows: 78
# ---- 49 ----
# rows: 79
# ---- 50 ----
# rows: 69
# rows: 70
# ---- 51 ----
# rows: 68
# rows: 71
# ---- 52 ----
# rows: 76
# ---- 53 ----
# rows: 74
# ---- 54 ----
# rows: 91
# ---- 55 ----
# rows: 83
# ---- 56 ----
# rows: 94
# ---- 57 ----
# rows: 92
# ---- 58 ----
# rows: 86
# ---- 59 ----
# rows: 94
# ---- 60 ----
# rows: 85
# ---- 61 ----
# rows: 90
# ---- 62 ----
# rows: 92
# ---- 63 ----
# rows: 88
# ---- 64 ----
# rows: 92
# ---- 65 ----
# rows: 85
# ---- 66 ----
# rows: 85
# ---- 67 ----
# rows: 85
# ---- 68 ----
# rows: 89
# ---- 69 ----
# rows: 84
# ---- 70 ----
# rows: 71
# ---- 71 ----
# rows: 71
# ---- 72 ----
# rows: 75
# ---- 73 ----
# rows: 61
# rows: 62
# rows: 63
# rows: 64
# rows: 65
# rows: 66
# rows: 67
# rows: 76
# ---- 74 ----
# rows: 82
# ---- 75 ----
# rows: 21
# rows: 22
# rows: 64
# rows: 67
# rows: 70
# ---- 76 ----
# rows: 69
# rows: 70
# ---- 77 ----
# rows: 21
# rows: 22
# rows: 23
# rows: 24
# rows: 25
# rows: 26
# rows: 87
# ---- 78 ----
# rows: 21
# rows: 22
# rows: 23
# rows: 24
# rows: 25
# rows: 26
# rows: 83
# ---- 79 ----
# rows: 21
# rows: 22
# rows: 23
# rows: 24
# rows: 84
# ---- 80 ----
# rows: 88
# ---- 81 ----
# rows: 101
# ---- 82 ----
# rows: 95
# ---- 83 ----
# rows: 82
# ---- 84 ----
# rows: 96
# ---- 85 ----
# rows: 78
# ---- 86 ----
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 87 ----
# rows: 61
# rows: 62
# rows: 63
# rows: 64
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 88 ----
# rows: 69
# rows: 70
# ---- 89 ----
# rows: 78
# ---- 90 ----
# rows: 73
# ---- 91 ----
# rows: 73
# ---- 92 ----
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 93 ----
# rows: 76
# ---- 94 ----
# rows: 70
# ---- 95 ----
# rows: 77
# ---- 96 ----
# rows: 86
# ---- 97 ----
# rows: 90
# ---- 98 ----
# rows: 86
# ---- 99 ----
# rows: 89
# Done Trimming mayroon 100 files
# ----------------- Word nagbubukas-----------------
# ---- 0 ----
# rows: 123
#  NO END ey
# ---- 1 ----
# rows: 136
# ---- 2 ----
# rows: 117
# ---- 3 ----
# rows: 109
# ---- 4 ----
# rows: 48
# rows: 108
# ---- 5 ----
# rows: 114
# ---- 6 ----
# rows: 107
# ---- 7 ----
# rows: 108
# ---- 8 ----
# rows: 110
# ---- 9 ----
# rows: 111
# ---- 10 ----
# rows: 91
# ---- 11 ----
# rows: 99
# ---- 12 ----
# rows: 100
# ---- 13 ----
# rows: 96
# ---- 14 ----
# rows: 94
# ---- 15 ----
# rows: 146
# ---- 16 ----
# rows: 154
#  NO END ey
# ---- 17 ----
# rows: 21
# rows: 129
# ---- 18 ----
# rows: 21
# rows: 22
# rows: 23
# rows: 128
# ---- 19 ----
# rows: 158
# ---- 20 ----
# rows: 108
# ---- 21 ----
# rows: 105
# ---- 22 ----
# rows: 125
# ---- 23 ----
# rows: 116
# ---- 24 ----
# rows: 102
# ---- 25 ----
# rows: 98
# ---- 26 ----
# rows: 103
# ---- 27 ----
# rows: 123
#  NO END ey
# ---- 28 ----
# rows: 81
# ---- 29 ----
# rows: 96
# ---- 30 ----
# rows: 100
# ---- 31 ----
# rows: 105
# ---- 32 ----
# rows: 111
# ---- 33 ----
# rows: 101
# ---- 34 ----
# rows: 111
# ---- 35 ----
# rows: 85
# ---- 36 ----
# rows: 99
# ---- 37 ----
# rows: 87
# ---- 38 ----
# rows: 110
# ---- 39 ----
# rows: 108
# ---- 40 ----
# rows: 92
# ---- 41 ----
# rows: 99
# ---- 42 ----
# rows: 94
# ---- 43 ----
# rows: 94
# ---- 44 ----
# rows: 115
# ---- 45 ----
# rows: 104
# ---- 46 ----
# rows: 109
# ---- 47 ----
# rows: 104
# ---- 48 ----
# rows: 106
# ---- 49 ----
# rows: 114
# ---- 50 ----
# rows: 97
# ---- 51 ----
# rows: 96
# ---- 52 ----
# rows: 88
# ---- 53 ----
# rows: 84
# ---- 54 ----
# rows: 94
# ---- 55 ----
# rows: 106
# ---- 56 ----
# rows: 117
# ---- 57 ----
# rows: 102
# ---- 58 ----
# rows: 108
# ---- 59 ----
# rows: 110
# ---- 60 ----
# rows: 94
# ---- 61 ----
# rows: 95
# ---- 62 ----
# rows: 90
# ---- 63 ----
# rows: 93
# ---- 64 ----
# rows: 99
# ---- 65 ----
# rows: 97
# ---- 66 ----
# rows: 108
# ---- 67 ----
# rows: 102
# ---- 68 ----
# rows: 111
# ---- 69 ----
# rows: 97
# ---- 70 ----
# rows: 99
# ---- 71 ----
# rows: 101
# ---- 72 ----
# rows: 111
# ---- 73 ----
# rows: 104
# ---- 74 ----
# rows: 93
# ---- 75 ----
# rows: 111
# ---- 76 ----
# rows: 109
# ---- 77 ----
# rows: 111
# ---- 78 ----
# rows: 115
# ---- 79 ----
# rows: 121
# ---- 80 ----
# rows: 130
# ---- 81 ----
# rows: 120
# ---- 82 ----
# rows: 112
# ---- 83 ----
# rows: 107
# ---- 84 ----
# rows: 102
# ---- 85 ----
# rows: 96
# ---- 86 ----
# rows: 85
# ---- 87 ----
# rows: 98
# ---- 88 ----
# rows: 93
# ---- 89 ----
# rows: 84
# ---- 90 ----
# rows: 89
# ---- 91 ----
# rows: 101
# ---- 92 ----
# rows: 93
# ---- 93 ----
# rows: 106
# ---- 94 ----
# rows: 91
# ---- 95 ----
# rows: 151
# ---- 96 ----
# rows: 119
# ---- 97 ----
# rows: 121
# ---- 98 ----
# rows: 117
# ---- 99 ----
# rows: 129
# Done Trimming nagbubukas 100 files
# ----------------- Word nagsasara-----------------
# ---- 0 ----
# rows: 111
# ---- 1 ----
# rows: 110
# ---- 2 ----
# rows: 115
# ---- 3 ----
# rows: 102
# ---- 4 ----
# rows: 88
# ---- 5 ----
# rows: 118
#  NO END ey
# ---- 6 ----
# rows: 117
#  NO END ey
# ---- 7 ----
# rows: 111
# ---- 8 ----
# rows: 110
# ---- 9 ----
# rows: 110
#  NO END ey
# ---- 10 ----
# rows: 97
# ---- 11 ----
# rows: 94
# ---- 12 ----
# rows: 93
# ---- 13 ----
# rows: 96
# ---- 14 ----
# rows: 96
# ---- 15 ----
# rows: 21
# rows: 136
# ---- 16 ----
# rows: 21
# rows: 140
# ---- 17 ----
# rows: 21
# rows: 143
# ---- 18 ----
# rows: 21
# rows: 139
# ---- 19 ----
# rows: 130
# ---- 20 ----
# rows: 153
# ---- 21 ----
# rows: 103
# ---- 22 ----
# rows: 107
# ---- 23 ----
# rows: 111
# ---- 24 ----
# rows: 107
# ---- 25 ----
# rows: 93
# ---- 26 ----
# rows: 97
# ---- 27 ----
# rows: 96
# ---- 28 ----
# rows: 108
# ---- 29 ----
# rows: 105
# ---- 30 ----
# rows: 62
# rows: 104
# ---- 31 ----
# rows: 106
# ---- 32 ----
# rows: 126
# ---- 33 ----
# rows: 78
# ---- 34 ----
# rows: 115
# ---- 35 ----
# rows: 88
# ---- 36 ----
# rows: 88
# ---- 37 ----
# rows: 72
# ---- 38 ----
# rows: 87
# ---- 39 ----
# rows: 86
# ---- 40 ----
# rows: 94
# ---- 41 ----
# rows: 101
# ---- 42 ----
# rows: 106
# ---- 43 ----
# rows: 112
# ---- 44 ----
# rows: 100
# ---- 45 ----
# rows: 121
# ---- 46 ----
# rows: 113
# ---- 47 ----
# rows: 105
# ---- 48 ----
# rows: 110
# ---- 49 ----
# rows: 117
# ---- 50 ----
# rows: 94
# ---- 51 ----
# rows: 111
# ---- 52 ----
# rows: 79
# ---- 53 ----
# rows: 89
# ---- 54 ----
# rows: 113
# ---- 55 ----
# rows: 96
# ---- 56 ----
# rows: 111
#  NO END ey
# ---- 57 ----
# rows: 114
# ---- 58 ----
# rows: 119
# ---- 59 ----
# rows: 113
# ---- 60 ----
# rows: 91
# ---- 61 ----
# rows: 87
# ---- 62 ----
# rows: 86
# ---- 63 ----
# rows: 85
# ---- 64 ----
# rows: 82
# ---- 65 ----
# rows: 108
# ---- 66 ----
# rows: 114
# ---- 67 ----
# rows: 124
# ---- 68 ----
# rows: 111
# ---- 69 ----
# rows: 115
# ---- 70 ----
# rows: 87
# ---- 71 ----
# rows: 84
# ---- 72 ----
# rows: 107
# ---- 73 ----
# rows: 95
# ---- 74 ----
# rows: 98
# ---- 75 ----
# rows: 102
# ---- 76 ----
# rows: 106
# ---- 77 ----
# rows: 102
# ---- 78 ----
# rows: 118
# ---- 79 ----
# rows: 119
# ---- 80 ----
# rows: 90
# ---- 81 ----
# rows: 102
# ---- 82 ----
# rows: 106
# ---- 83 ----
# rows: 100
# ---- 84 ----
# rows: 105
# ---- 85 ----
# rows: 97
# ---- 86 ----
# rows: 95
# ---- 87 ----
# rows: 90
# ---- 88 ----
# rows: 101
# ---- 89 ----
# rows: 92
# ---- 90 ----
# rows: 90
# ---- 91 ----
# rows: 83
# ---- 92 ----
# rows: 80
# ---- 93 ----
# rows: 88
# ---- 94 ----
# rows: 98
# ---- 95 ----
# rows: 110
# ---- 96 ----
# rows: 122
# ---- 97 ----
# rows: 124
# ---- 98 ----
# rows: 115
# ---- 99 ----
# rows: 115
# Done Trimming nagsasara 100 files
# ----------------- Word oras-----------------
# ---- 0 ----
# rows: 37
# rows: 50
# rows: 85
# ---- 1 ----
# rows: 66
# rows: 67
# rows: 76
#  NO END ey
# ---- 2 ----
# rows: 54
# rows: 89
# ---- 3 ----
# rows: 82
# ---- 4 ----
# rows: 79
# ---- 5 ----
# rows: 92
# ---- 6 ----
# rows: 92
# ---- 7 ----
# rows: 94
# ---- 8 ----
# rows: 94
# ---- 9 ----
# rows: 93
# ---- 10 ----
# rows: 90
# ---- 11 ----
# rows: 96
# ---- 12 ----
# rows: 91
# ---- 13 ----
# rows: 98
# ---- 14 ----
# rows: 90
# ---- 15 ----
# rows: 106
# ---- 16 ----
# rows: 113
# ---- 17 ----
# rows: 113
# ---- 18 ----
# rows: 116
# ---- 19 ----
# rows: 95
# ---- 20 ----
# rows: 88
# ---- 21 ----
# rows: 105
# ---- 22 ----
# rows: 21
# rows: 110
# ---- 23 ----
# rows: 97
# ---- 24 ----
# rows: 100
# ---- 25 ----
# rows: 102
# ---- 26 ----
# rows: 104
# ---- 27 ----
# rows: 100
# ---- 28 ----
# rows: 101
# ---- 29 ----
# rows: 89
# ---- 30 ----
# rows: 108
# ---- 31 ----
# rows: 115
# ---- 32 ----
# rows: 115
# ---- 33 ----
# rows: 120
# ---- 34 ----
# rows: 72
# ---- 35 ----
# rows: 80
# ---- 36 ----
# rows: 52
# rows: 71
# ---- 37 ----
# rows: 32
# rows: 50
# rows: 51
# rows: 70
# ---- 38 ----
# rows: 32
# rows: 50
# rows: 69
# rows: 86
# ---- 39 ----
# rows: 88
# ---- 40 ----
# rows: 91
# ---- 41 ----
# rows: 99
# ---- 42 ----
# rows: 90
# ---- 43 ----
# rows: 88
# ---- 44 ----
# rows: 116
# ---- 45 ----
# rows: 113
# ---- 46 ----
# rows: 121
# ---- 47 ----
# rows: 121
# ---- 48 ----
# rows: 119
# ---- 49 ----
# rows: 94
# ---- 50 ----
# rows: 116
# ---- 51 ----
# rows: 96
# ---- 52 ----
# rows: 98
# ---- 53 ----
# rows: 116
# ---- 54 ----
# rows: 103
# ---- 55 ----
# rows: 93
# ---- 56 ----
# rows: 57
# rows: 108
# ---- 57 ----
# rows: 101
# ---- 58 ----
# rows: 38
# rows: 39
# rows: 72
# ---- 59 ----
# rows: 65
# rows: 90
# ---- 60 ----
# rows: 64
# rows: 89
# ---- 61 ----
# rows: 39
# rows: 53
# rows: 54
# rows: 66
# rows: 67
# rows: 91
# ---- 62 ----
# rows: 38
# rows: 39
# rows: 66
# rows: 67
# rows: 89
# ---- 63 ----
# rows: 39
# rows: 53
# rows: 67
# rows: 88
# ---- 64 ----
# rows: 90
# ---- 65 ----
# rows: 98
# ---- 66 ----
# rows: 92
# ---- 67 ----
# rows: 97
# ---- 68 ----
# rows: 95
# ---- 69 ----
# rows: 83
# ---- 70 ----
# rows: 85
# ---- 71 ----
# rows: 81
# ---- 72 ----
# rows: 84
# ---- 73 ----
# rows: 81
# ---- 74 ----
# rows: 103
# ---- 75 ----
# rows: 107
# ---- 76 ----
# rows: 98
# ---- 77 ----
# rows: 93
# ---- 78 ----
# rows: 103
# ---- 79 ----
# rows: 105
# ---- 80 ----
# rows: 56
# rows: 57
# rows: 78
# ---- 81 ----
# rows: 50
# rows: 51
# rows: 73
# ---- 82 ----
# rows: 49
# rows: 50
# rows: 65
# rows: 82
# ---- 83 ----
# rows: 55
# rows: 56
# rows: 107
# ---- 84 ----
# rows: 97
# ---- 85 ----
# rows: 98
# ---- 86 ----
# rows: 105
# ---- 87 ----
# rows: 92
# ---- 88 ----
# rows: 117
# ---- 89 ----
# rows: 89
# ---- 90 ----
# rows: 103
# ---- 91 ----
# rows: 78
# ---- 92 ----
# rows: 82
# ---- 93 ----
# rows: 87
# ---- 94 ----
# rows: 101
# ---- 95 ----
# rows: 108
# ---- 96 ----
# rows: 102
# ---- 97 ----
# rows: 106
# ---- 98 ----
# rows: 98
# Done Trimming oras 99 files
# ----------------- Word pabili-----------------
# ---- 0 ----
# rows: 102
# ---- 1 ----
# rows: 44
#  NO END ey
# ---- 2 ----
# rows: 39
#  NO END ey
# ---- 3 ----
# rows: 33
# rows: 82
# ---- 4 ----
# rows: 37
# rows: 79
# ---- 5 ----
# rows: 37
# rows: 95
# ---- 6 ----
# rows: 100
# ---- 7 ----
# rows: 98
# ---- 8 ----
# rows: 117
# ---- 9 ----
# rows: 105
# ---- 10 ----
# rows: 37
# rows: 86
# ---- 11 ----
# rows: 38
# rows: 89
# ---- 12 ----
# rows: 37
# rows: 38
# rows: 91
# ---- 13 ----
# rows: 38
# rows: 92
# ---- 14 ----
# rows: 37
# rows: 38
# rows: 88
# ---- 15 ----
# rows: 111
# ---- 16 ----
# rows: 118
# ---- 17 ----
# rows: 120
# ---- 18 ----
# rows: 122
# ---- 19 ----
# rows: 115
# ---- 20 ----
# rows: 81
# ---- 21 ----
# rows: 97
# ---- 22 ----
# rows: 93
# ---- 23 ----
# rows: 94
# ---- 24 ----
# rows: 94
# ---- 25 ----
# rows: 86
# ---- 26 ----
# rows: 90
# ---- 27 ----
# rows: 96
# ---- 28 ----
# rows: 99
# ---- 29 ----
# rows: 37
# rows: 98
# ---- 30 ----
# rows: 38
# rows: 85
# ---- 31 ----
# rows: 38
# rows: 39
# rows: 99
# ---- 32 ----
# rows: 93
# ---- 33 ----
# rows: 41
# rows: 102
# ---- 34 ----
# rows: 41
# rows: 102
# ---- 35 ----
# rows: 69
# rows: 70
# ---- 36 ----
# rows: 32
# rows: 33
# rows: 94
# ---- 37 ----
# rows: 81
# ---- 38 ----
# rows: 31
# rows: 32
# rows: 92
# ---- 39 ----
# rows: 31
# rows: 32
# rows: 95
# ---- 40 ----
# rows: 82
# ---- 41 ----
# rows: 98
# ---- 42 ----
# rows: 50
# rows: 51
# rows: 108
# ---- 43 ----
# rows: 91
# ---- 44 ----
# rows: 84
# ---- 45 ----
# rows: 70
# ---- 46 ----
# rows: 71
# ---- 47 ----
# rows: 75
# ---- 48 ----
# rows: 130
# ---- 49 ----
# rows: 122
# ---- 50 ----
# rows: 113
# ---- 51 ----
# rows: 104
# ---- 52 ----
# rows: 100
# ---- 53 ----
# rows: 111
# ---- 54 ----
# rows: 113
# ---- 55 ----
# rows: 32
# rows: 100
# ---- 56 ----
# rows: 43
# rows: 44
# rows: 101
# ---- 57 ----
# rows: 40
# rows: 41
# rows: 42
# rows: 45
# rows: 78
# ---- 58 ----
# rows: 40
# rows: 92
# ---- 59 ----
# rows: 40
# rows: 41
# rows: 101
# ---- 60 ----
# rows: 35
# rows: 36
# rows: 84
# ---- 61 ----
# rows: 35
# rows: 36
# rows: 87
# ---- 62 ----
# rows: 39
# rows: 40
# rows: 91
# ---- 63 ----
# rows: 37
# rows: 85
# ---- 64 ----
# rows: 44
# rows: 45
# rows: 84
# ---- 65 ----
# rows: 26
# rows: 81
# ---- 66 ----
# rows: 81
# ---- 67 ----
# rows: 83
# ---- 68 ----
# rows: 91
# ---- 69 ----
# rows: 93
# ---- 70 ----
# rows: 81
# ---- 71 ----
# rows: 95
# ---- 72 ----
# rows: 87
# ---- 73 ----
# rows: 91
# ---- 74 ----
# rows: 91
# ---- 75 ----
# rows: 37
# rows: 90
# ---- 76 ----
# rows: 35
# rows: 36
# rows: 104
# ---- 77 ----
# rows: 39
# rows: 100
# ---- 78 ----
# rows: 36
# rows: 91
# ---- 79 ----
# rows: 35
# rows: 93
# ---- 80 ----
# rows: 112
# ---- 81 ----
# rows: 45
# rows: 97
#  NO END ey
# ---- 82 ----
# rows: 89
# ---- 83 ----
# rows: 40
# rows: 98
# ---- 84 ----
# rows: 103
# ---- 85 ----
# rows: 74
# ---- 86 ----
# rows: 89
# ---- 87 ----
# rows: 92
# ---- 88 ----
# rows: 96
# ---- 89 ----
# rows: 101
# ---- 90 ----
# rows: 31
# rows: 78
# ---- 91 ----
# rows: 28
# rows: 74
# ---- 92 ----
# rows: 30
# rows: 79
# ---- 93 ----
# rows: 76
# ---- 94 ----
# rows: 77
# ---- 95 ----
# rows: 93
# ---- 96 ----
# rows: 102
# ---- 97 ----
# rows: 103
# ---- 98 ----
# rows: 106
# ---- 99 ----
# rows: 102
# Done Trimming pabili 100 files
# ----------------- Word poloshirt-----------------
# ---- 0 ----
# rows: 78
# ---- 1 ----
# rows: 66
# rows: 67
# rows: 68
# rows: 120
# ---- 2 ----
# rows: 117
# ---- 3 ----
# rows: 130
# ---- 4 ----
# rows: 113
# ---- 5 ----
# rows: 125
# ---- 6 ----
# rows: 140
# ---- 7 ----
# rows: 136
# ---- 8 ----
# rows: 90
# ---- 9 ----
# rows: 85
# ---- 10 ----
# rows: 124
# ---- 11 ----
# rows: 126
# ---- 12 ----
# rows: 131
# ---- 13 ----
# rows: 85
# ---- 14 ----
# rows: 129
# ---- 15 ----
# rows: 158
# ---- 16 ----
# rows: 153
# ---- 17 ----
# rows: 169
# ---- 18 ----
# rows: 166
# ---- 19 ----
# rows: 180
# ---- 20 ----
# rows: 154
# ---- 21 ----
# rows: 151
# ---- 22 ----
# rows: 153
# ---- 23 ----
# rows: 155
# ---- 24 ----
# rows: 146
# ---- 25 ----
# rows: 136
# ---- 26 ----
# rows: 135
# ---- 27 ----
# rows: 132
# ---- 28 ----
# rows: 142
# ---- 29 ----
# rows: 137
# ---- 30 ----
# rows: 111
# ---- 31 ----
# rows: 127
# ---- 32 ----
# rows: 121
# ---- 33 ----
# rows: 124
# ---- 34 ----
# rows: 150
# ---- 35 ----
# rows: 117
# ---- 36 ----
# rows: 116
# ---- 37 ----
# rows: 146
# ---- 38 ----
# rows: 140
# ---- 39 ----
# rows: 75
# ---- 40 ----
# rows: 113
# ---- 41 ----
# rows: 128
# ---- 42 ----
# rows: 138
# ---- 43 ----
# rows: 119
# ---- 44 ----
# rows: 125
# ---- 45 ----
# rows: 153
# ---- 46 ----
# rows: 154
# ---- 47 ----
# rows: 147
# ---- 48 ----
# rows: 144
# ---- 49 ----
# rows: 152
# ---- 50 ----
# rows: 127
# ---- 51 ----
# rows: 130
# ---- 52 ----
# rows: 117
# ---- 53 ----
# rows: 129
# ---- 54 ----
# rows: 129
# ---- 55 ----
# rows: 116
# ---- 56 ----
# rows: 123
# ---- 57 ----
# rows: 79
# ---- 58 ----
# rows: 123
# ---- 59 ----
# rows: 122
# ---- 60 ----
# rows: 87
# ---- 61 ----
# rows: 126
# ---- 62 ----
# rows: 129
# ---- 63 ----
# rows: 87
# ---- 64 ----
# rows: 127
# ---- 65 ----
# rows: 129
# ---- 66 ----
# rows: 113
# ---- 67 ----
# rows: 129
# ---- 68 ----
# rows: 113
# ---- 69 ----
# rows: 139
# ---- 70 ----
# rows: 124
# ---- 71 ----
# rows: 131
# ---- 72 ----
# rows: 133
# ---- 73 ----
# rows: 133
# ---- 74 ----
# rows: 123
# ---- 75 ----
# rows: 105
# ---- 76 ----
# rows: 150
# ---- 77 ----
# rows: 86
# ---- 78 ----
# rows: 95
# ---- 79 ----
# rows: 154
# ---- 80 ----
# rows: 94
# ---- 81 ----
# rows: 105
# ---- 82 ----
# rows: 106
# ---- 83 ----
# rows: 85
# ---- 84 ----
# rows: 136
# ---- 85 ----
# rows: 90
# ---- 86 ----
# rows: 133
# ---- 87 ----
# rows: 122
# ---- 88 ----
# rows: 116
# ---- 89 ----
# rows: 125
# ---- 90 ----
# rows: 106
# ---- 91 ----
# rows: 89
# ---- 92 ----
# rows: 93
# ---- 93 ----
# rows: 99
# ---- 94 ----
# rows: 106
# ---- 95 ----
# rows: 149
# ---- 96 ----
# rows: 150
# ---- 97 ----
# rows: 151
# ---- 98 ----
# rows: 152
# ---- 99 ----
# rows: 140
# Done Trimming poloshirt 100 files
# ----------------- Word puwede-----------------
# ---- 0 ----
# rows: 87
#  NO END ey
# ---- 1 ----
#  NO END ey
# ---- 2 ----
# rows: 85
#  NO END ey
# ---- 3 ----
# rows: 91
# ---- 4 ----
# rows: 88
# ---- 5 ----
# rows: 86
# ---- 6 ----
# rows: 81
# ---- 7 ----
# rows: 78
# ---- 8 ----
# rows: 78
# ---- 9 ----
# rows: 80
# ---- 10 ----
# rows: 76
# ---- 11 ----
# rows: 77
# ---- 12 ----
# rows: 80
# ---- 13 ----
# rows: 45
# rows: 77
# ---- 14 ----
# rows: 74
# ---- 15 ----
# rows: 105
# ---- 16 ----
# rows: 96
# ---- 17 ----
# rows: 94
# ---- 18 ----
# rows: 99
# ---- 19 ----
# rows: 88
# ---- 20 ----
# rows: 21
# rows: 22
# rows: 80
# ---- 21 ----
# rows: 80
# ---- 22 ----
# rows: 21
# rows: 84
# ---- 23 ----
# rows: 21
# rows: 22
# rows: 23
# rows: 24
# rows: 25
# rows: 86
# ---- 24 ----
# rows: 21
# rows: 82
# ---- 25 ----
# rows: 78
# ---- 26 ----
# rows: 79
# ---- 27 ----
# rows: 83
# ---- 28 ----
# rows: 82
# ---- 29 ----
# rows: 80
# ---- 30 ----
# rows: 76
# ---- 31 ----
# rows: 88
# ---- 32 ----
# rows: 89
# ---- 33 ----
# rows: 85
# ---- 34 ----
# rows: 94
# ---- 35 ----
# rows: 87
# ---- 36 ----
# rows: 76
# ---- 37 ----
# rows: 70
# ---- 38 ----
# rows: 82
# ---- 39 ----
# rows: 82
# ---- 40 ----
# rows: 76
# ---- 41 ----
# rows: 71
# ---- 42 ----
# rows: 72
# ---- 43 ----
# rows: 85
# ---- 44 ----
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 45 ----
# rows: 91
# ---- 46 ----
# rows: 95
# ---- 47 ----
# rows: 91
# ---- 48 ----
# rows: 94
# ---- 49 ----
# rows: 94
# ---- 50 ----
# rows: 85
# ---- 51 ----
# rows: 89
# ---- 52 ----
# rows: 101
# ---- 53 ----
# rows: 90
# ---- 54 ----
# rows: 95
# ---- 55 ----
# rows: 80
# ---- 56 ----
# rows: 88
# ---- 57 ----
# rows: 77
# ---- 58 ----
# rows: 89
# ---- 59 ----
# rows: 97
# ---- 60 ----
# rows: 74
# ---- 61 ----
# rows: 87
# ---- 62 ----
# rows: 88
# ---- 63 ----
# rows: 72
# ---- 64 ----
# rows: 81
# ---- 65 ----
# rows: 68
# rows: 69
# rows: 70
# ---- 66 ----
# rows: 78
# ---- 67 ----
# rows: 81
# ---- 68 ----
# rows: 80
# ---- 69 ----
# rows: 87
# ---- 70 ----
# rows: 73
# ---- 71 ----
# rows: 78
# ---- 72 ----
# rows: 80
# ---- 73 ----
# rows: 78
# ---- 74 ----
# rows: 78
# ---- 75 ----
# rows: 89
# ---- 76 ----
# rows: 113
# ---- 77 ----
# rows: 93
# ---- 78 ----
# rows: 95
# ---- 79 ----
# rows: 91
# ---- 80 ----
# rows: 94
# ---- 81 ----
# rows: 109
# ---- 82 ----
# rows: 108
# ---- 83 ----
# rows: 93
# ---- 84 ----
# rows: 104
# ---- 85 ----
# rows: 96
# ---- 86 ----
# rows: 110
# ---- 87 ----
# rows: 101
# ---- 88 ----
# rows: 99
# ---- 89 ----
# rows: 111
# ---- 90 ----
# rows: 82
# ---- 91 ----
# rows: 71
# ---- 92 ----
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 93 ----
# rows: 76
# ---- 94 ----
# rows: 77
# ---- 95 ----
# rows: 90
# ---- 96 ----
# rows: 83
# ---- 97 ----
# rows: 88
# ---- 98 ----
# rows: 84
# ---- 99 ----
# ...
# ---- 88 ----
# rows: 164
# ---- 89 ----
# rows: 169
# ---- 90 ----
# rows: 159
# ---- 91 ----
# rows: 169
# ---- 92 ----
# rows: 171
# ---- 93 ----
# rows: 159
# ---- 94 ----
# rows: 184
# ---- 95 ----
# rows: 186
# ---- 96 ----
# rows: 173
# ---- 97 ----
# rows: 181
# ---- 98 ----
# rows: 180
# Done Trimming spaghetti 99 files
# ----------------- Word supot-----------------
# ---- 0 ----
# rows: 65
# rows: 66
# rows: 79
# ---- 1 ----
# rows: 85
# ---- 2 ----
# rows: 126
#  NO END ey
# ---- 3 ----
# rows: 134
#  NO END ey
# ---- 4 ----
# rows: 141
#  NO END ey
# ---- 5 ----
# rows: 123
# ---- 6 ----
# rows: 61
# rows: 62
# rows: 63
# rows: 64
# rows: 65
# rows: 66
# rows: 77
# ---- 7 ----
# rows: 71
# ---- 8 ----
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 9 ----
# rows: 58
# rows: 59
# rows: 60
# rows: 61
# rows: 62
# rows: 63
# rows: 84
# ---- 10 ----
# rows: 115
# ---- 11 ----
# rows: 148
# ---- 12 ----
# rows: 137
# ---- 13 ----
# rows: 144
# ---- 14 ----
# rows: 134
# ---- 15 ----
# rows: 133
# ---- 16 ----
# rows: 135
# ---- 17 ----
# rows: 146
# ---- 18 ----
# rows: 133
# ---- 19 ----
# rows: 142
# ---- 20 ----
# rows: 160
# ---- 21 ----
# rows: 162
# ---- 22 ----
# rows: 155
# ---- 23 ----
# rows: 148
# ---- 24 ----
# rows: 154
# ---- 25 ----
# rows: 142
# ---- 26 ----
# rows: 133
# ---- 27 ----
# rows: 134
# ---- 28 ----
# rows: 133
# ---- 29 ----
# rows: 133
# ---- 30 ----
# rows: 141
# ---- 31 ----
# rows: 122
# ---- 32 ----
# rows: 157
# ---- 33 ----
# rows: 142
# ---- 34 ----
# rows: 152
# ---- 35 ----
# rows: 149
# ---- 36 ----
# rows: 155
# ---- 37 ----
# rows: 134
# ---- 38 ----
# rows: 146
# ---- 39 ----
# rows: 133
# ---- 40 ----
# rows: 122
# ---- 41 ----
# rows: 106
# ---- 42 ----
# rows: 122
# ---- 43 ----
# rows: 64
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 44 ----
# rows: 120
# ---- 45 ----
# rows: 161
# ---- 46 ----
# rows: 174
# ---- 47 ----
# rows: 172
# ---- 48 ----
# rows: 160
# ---- 49 ----
# rows: 157
# ---- 50 ----
# rows: 124
# ---- 51 ----
# rows: 150
# ---- 52 ----
# rows: 134
# ---- 53 ----
# rows: 156
# ---- 54 ----
# rows: 143
# ---- 55 ----
# rows: 77
# ---- 56 ----
# rows: 85
# ---- 57 ----
# rows: 124
# ---- 58 ----
# rows: 126
# ---- 59 ----
# rows: 175
# ---- 60 ----
# rows: 123
# ---- 61 ----
# rows: 116
# ---- 62 ----
# rows: 111
# ---- 63 ----
# rows: 125
# ---- 64 ----
# rows: 116
# ---- 65 ----
# rows: 119
# ---- 66 ----
# rows: 125
# ---- 67 ----
# rows: 135
# ---- 68 ----
# rows: 121
# ---- 69 ----
# rows: 138
# ---- 70 ----
# rows: 104
# ---- 71 ----
# rows: 134
# ---- 72 ----
# rows: 123
# ---- 73 ----
# rows: 127
# ---- 74 ----
# rows: 145
# ---- 75 ----
# rows: 149
# ---- 76 ----
# rows: 170
# ---- 77 ----
# rows: 175
# ---- 78 ----
# rows: 153
# ---- 79 ----
# rows: 152
# ---- 80 ----
# rows: 106
# ---- 81 ----
# rows: 107
# ---- 82 ----
# rows: 67
# rows: 103
# ---- 83 ----
# rows: 73
# ---- 84 ----
# rows: 90
# ---- 85 ----
# rows: 76
# ---- 86 ----
# rows: 64
# rows: 65
# rows: 66
# rows: 67
# rows: 81
# ---- 87 ----
# rows: 81
# ---- 88 ----
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 107
# ---- 89 ----
# rows: 67
# rows: 68
# rows: 113
# ---- 90 ----
# rows: 122
# ---- 91 ----
# rows: 124
# ---- 92 ----
# rows: 124
# ---- 93 ----
# rows: 125
# ---- 94 ----
# rows: 127
# ---- 95 ----
# rows: 124
# ---- 96 ----
# rows: 126
# ---- 97 ----
# rows: 137
# ---- 98 ----
# rows: 142
# ---- 99 ----
# rows: 142
# Done Trimming supot 100 files
# ----------------- Word t-shirt-----------------
# ---- 0 ----
# rows: 122
#  NO END ey
# ---- 1 ----
# rows: 135
# ---- 2 ----
# rows: 126
# ---- 3 ----
# rows: 143
# ---- 4 ----
# rows: 136
# ---- 5 ----
# rows: 115
# ---- 6 ----
# rows: 128
# ---- 7 ----
# rows: 121
#  NO END ey
# ---- 8 ----
# rows: 119
# ---- 9 ----
# rows: 127
# ---- 10 ----
# rows: 137
# ---- 11 ----
# rows: 131
# ---- 12 ----
# rows: 146
# ---- 13 ----
# rows: 132
# ---- 14 ----
# rows: 135
# ---- 15 ----
# rows: 158
# ---- 16 ----
# rows: 21
# rows: 140
# ---- 17 ----
# rows: 132
# ---- 18 ----
# rows: 144
# ---- 19 ----
# rows: 138
# ---- 20 ----
# rows: 177
# ---- 21 ----
# rows: 147
# ---- 22 ----
# rows: 144
# ---- 23 ----
# rows: 144
# ---- 24 ----
# rows: 153
# ---- 25 ----
# rows: 118
# ---- 26 ----
# rows: 141
# ---- 27 ----
# rows: 133
# ---- 28 ----
# rows: 118
# ---- 29 ----
# rows: 125
# ---- 30 ----
# rows: 109
# ---- 31 ----
# rows: 122
# ---- 32 ----
# rows: 129
# ---- 33 ----
# rows: 116
# ---- 34 ----
# rows: 120
# ---- 35 ----
# rows: 136
# ---- 36 ----
# rows: 145
# ---- 37 ----
# rows: 139
# ---- 38 ----
# rows: 133
# ---- 39 ----
# rows: 142
# ---- 40 ----
# rows: 126
# ---- 41 ----
# rows: 94
# ---- 42 ----
#  NO END ey
# ---- 43 ----
# rows: 69
# rows: 70
# ---- 44 ----
# rows: 109
# ---- 45 ----
# rows: 158
# ---- 46 ----
# rows: 159
# ---- 47 ----
# rows: 163
# ---- 48 ----
# rows: 165
# ---- 49 ----
# rows: 169
# ---- 50 ----
# rows: 135
# ---- 51 ----
# rows: 144
# ---- 52 ----
# rows: 144
# ---- 53 ----
# rows: 151
# ---- 54 ----
# rows: 127
# ---- 55 ----
# rows: 150
# ---- 56 ----
# rows: 146
# ---- 57 ----
# rows: 135
# ---- 58 ----
# rows: 152
# ---- 59 ----
# rows: 137
# ---- 60 ----
# rows: 109
# ---- 61 ----
# rows: 106
# ---- 62 ----
# rows: 118
# ---- 63 ----
# rows: 121
# ---- 64 ----
# rows: 114
# ---- 65 ----
# rows: 137
# ---- 66 ----
# rows: 115
# ---- 67 ----
# rows: 145
# ---- 68 ----
# rows: 160
# ---- 69 ----
# rows: 121
# ---- 70 ----
# rows: 127
# ---- 71 ----
# rows: 136
# ---- 72 ----
# rows: 144
# ---- 73 ----
# rows: 142
# ---- 74 ----
# rows: 135
# ---- 75 ----
# rows: 158
# ---- 76 ----
# rows: 144
# ---- 77 ----
# rows: 151
# ---- 78 ----
# rows: 127
# ---- 79 ----
# rows: 134
# ---- 80 ----
# rows: 141
# ---- 81 ----
# rows: 150
# ---- 82 ----
# rows: 142
# ---- 83 ----
# rows: 138
# ---- 84 ----
# rows: 126
# ---- 85 ----
# rows: 115
# ---- 86 ----
# rows: 115
# ---- 87 ----
# rows: 115
# ---- 88 ----
# rows: 124
# ---- 89 ----
# rows: 118
# ---- 90 ----
# rows: 109
# ---- 91 ----
# rows: 112
# ---- 92 ----
# rows: 121
# ---- 93 ----
# rows: 105
# ---- 94 ----
# rows: 100
# ---- 95 ----
# rows: 138
# ---- 96 ----
# rows: 135
# ---- 97 ----
# rows: 138
# ---- 98 ----
# rows: 133
# ---- 99 ----
# rows: 133
# Done Trimming t-shirt 100 files
# ----------------- Word tawad-----------------
# ---- 0 ----
# rows: 84
# ---- 1 ----
# rows: 87
# ---- 2 ----
# rows: 91
# ---- 3 ----
# rows: 83
# ---- 4 ----
# rows: 72
# ---- 5 ----
# rows: 91
# ---- 6 ----
# rows: 94
# ---- 7 ----
# rows: 80
# ---- 8 ----
# rows: 86
# ---- 9 ----
# rows: 99
# ---- 10 ----
# rows: 104
# ---- 11 ----
# rows: 100
# ---- 12 ----
# rows: 97
# ---- 13 ----
# rows: 106
# ---- 14 ----
# rows: 101
# ---- 15 ----
# rows: 95
# ---- 16 ----
# rows: 93
# ---- 17 ----
# rows: 92
# ---- 18 ----
# rows: 88
# ---- 19 ----
# rows: 100
# ---- 20 ----
# rows: 100
# ---- 21 ----
# rows: 97
# ---- 22 ----
# rows: 99
# ---- 23 ----
# rows: 102
# ---- 24 ----
# rows: 95
# ---- 25 ----
# rows: 89
# ---- 26 ----
# rows: 93
# ---- 27 ----
# rows: 94
# ---- 28 ----
# rows: 97
# ---- 29 ----
# rows: 94
# ---- 30 ----
# rows: 94
# ---- 31 ----
# rows: 97
# ---- 32 ----
# rows: 99
# ---- 33 ----
# rows: 105
# ---- 34 ----
# rows: 108
# ---- 35 ----
# rows: 39
# rows: 42
# rows: 63
# rows: 68
# rows: 69
# rows: 72
# ---- 36 ----
# rows: 78
# ---- 37 ----
# rows: 36
# rows: 40
# rows: 41
# rows: 43
# rows: 60
# rows: 63
# rows: 64
# rows: 65
# rows: 66
# rows: 67
# rows: 77
# ---- 38 ----
# rows: 42
# rows: 43
# rows: 75
# ---- 39 ----
# rows: 41
# rows: 45
# rows: 46
# rows: 70
# ---- 40 ----
# rows: 93
# ---- 41 ----
# rows: 96
# ---- 42 ----
# rows: 90
# ---- 43 ----
# rows: 93
# ---- 44 ----
# rows: 84
# ---- 45 ----
# rows: 109
# ---- 46 ----
# rows: 106
# ---- 47 ----
# rows: 106
# ---- 48 ----
# rows: 106
# ---- 49 ----
# rows: 105
# ---- 50 ----
# rows: 75
# ---- 51 ----
# rows: 97
# ---- 52 ----
# rows: 106
# ---- 53 ----
# rows: 95
# ---- 54 ----
# rows: 104
# ---- 55 ----
# rows: 130
# ---- 56 ----
# rows: 122
# ---- 57 ----
# rows: 133
# ---- 58 ----
# rows: 99
# ---- 59 ----
# rows: 106
# ---- 60 ----
# rows: 76
# ---- 61 ----
# rows: 87
# ---- 62 ----
# rows: 91
# ---- 63 ----
# rows: 81
# ---- 64 ----
# rows: 89
# ---- 65 ----
# rows: 93
# ---- 66 ----
# rows: 92
# ---- 67 ----
# rows: 92
# ---- 68 ----
# rows: 94
# ---- 69 ----
# rows: 101
# ---- 70 ----
# rows: 93
# ---- 71 ----
# rows: 93
# ---- 72 ----
# rows: 103
# ---- 73 ----
# rows: 98
# ---- 74 ----
# rows: 91
# ---- 75 ----
# rows: 93
# ---- 76 ----
# rows: 107
# ---- 77 ----
# rows: 114
# ---- 78 ----
# rows: 118
# ---- 79 ----
# rows: 81
# ---- 80 ----
# rows: 89
# ---- 81 ----
# rows: 102
# ---- 82 ----
# rows: 111
# ---- 83 ----
# rows: 106
# ---- 84 ----
# rows: 103
# ---- 85 ----
# rows: 83
# ---- 86 ----
# rows: 89
# ---- 87 ----
# rows: 77
# ---- 88 ----
# rows: 92
# ---- 89 ----
# rows: 93
# ---- 90 ----
# rows: 87
# ---- 91 ----
# rows: 93
# ---- 92 ----
# rows: 86
# ---- 93 ----
# rows: 90
# ---- 94 ----
# rows: 76
# ---- 95 ----
# rows: 94
# ---- 96 ----
# rows: 93
# ---- 97 ----
# rows: 90
# ---- 98 ----
# rows: 96
# ---- 99 ----
# rows: 96
# Done Trimming tawad 100 files
# ----------------- Word tinapay-----------------
# ---- 0 ----
# rows: 79
#  NO END ey
# ---- 1 ----
# rows: 86
# ---- 2 ----
# rows: 79
#  NO END ey
# ---- 3 ----
# rows: 84
# ---- 4 ----
# rows: 82
# ---- 5 ----
# rows: 90
# ---- 6 ----
# rows: 83
# ---- 7 ----
# rows: 92
# ---- 8 ----
# rows: 102
# ---- 9 ----
# rows: 102
# ---- 10 ----
# rows: 97
# ---- 11 ----
# rows: 94
# ---- 12 ----
# rows: 93
# ---- 13 ----
# rows: 90
# ---- 14 ----
# rows: 100
# ---- 15 ----
# rows: 21
# rows: 96
# ---- 16 ----
# rows: 21
# rows: 22
# rows: 99
# ---- 17 ----
# rows: 21
# rows: 81
# ---- 18 ----
# rows: 94
# ---- 19 ----
# rows: 21
# rows: 98
# ---- 20 ----
# rows: 104
# ---- 21 ----
# rows: 108
# ---- 22 ----
# rows: 105
# ---- 23 ----
# rows: 109
# ---- 24 ----
# rows: 109
# ---- 25 ----
# rows: 85
# ---- 26 ----
# rows: 89
# ---- 27 ----
# rows: 97
# ---- 28 ----
# rows: 89
# ---- 29 ----
# rows: 93
# ---- 30 ----
# rows: 93
# ---- 31 ----
# rows: 104
# ---- 32 ----
# rows: 109
# ---- 33 ----
# rows: 101
# ---- 34 ----
# rows: 114
# ---- 35 ----
# rows: 86
# ---- 36 ----
# rows: 88
# ---- 37 ----
# rows: 96
# ---- 38 ----
# rows: 93
# ---- 39 ----
# rows: 90
# ---- 40 ----
# rows: 88
# ---- 41 ----
# rows: 78
# ---- 42 ----
# rows: 88
# ---- 43 ----
# rows: 82
# ---- 44 ----
# rows: 89
# ---- 45 ----
# rows: 109
# ---- 46 ----
# rows: 109
# ---- 47 ----
# rows: 111
# ---- 48 ----
# rows: 114
# ---- 49 ----
# rows: 120
# ---- 50 ----
# rows: 81
# ---- 51 ----
# rows: 97
# ---- 52 ----
# rows: 106
# ---- 53 ----
# rows: 92
# ---- 54 ----
# rows: 103
# ---- 55 ----
# rows: 123
# ---- 56 ----
# rows: 127
# ---- 57 ----
# rows: 125
# ---- 58 ----
# rows: 131
# ---- 59 ----
# rows: 120
# ---- 60 ----
# rows: 85
# ---- 61 ----
# rows: 98
# ---- 62 ----
# rows: 84
# ---- 63 ----
# rows: 94
# ---- 64 ----
# rows: 88
# ---- 65 ----
# rows: 92
# ---- 66 ----
# rows: 97
# ---- 67 ----
# rows: 83
# ---- 68 ----
# rows: 101
# ---- 69 ----
# rows: 97
# ---- 70 ----
# rows: 90
# ---- 71 ----
# rows: 83
# ---- 72 ----
# rows: 88
# ---- 73 ----
# rows: 89
# ---- 74 ----
# rows: 93
# ---- 75 ----
# rows: 93
# ---- 76 ----
# rows: 82
# ---- 77 ----
# rows: 103
# ---- 78 ----
# rows: 97
# ---- 79 ----
# rows: 98
# ---- 80 ----
# rows: 97
# ---- 81 ----
# rows: 93
# ---- 82 ----
# rows: 110
# ---- 83 ----
# rows: 107
# ---- 84 ----
# rows: 104
# ---- 85 ----
# rows: 87
# ---- 86 ----
# rows: 85
# ---- 87 ----
# rows: 91
# ---- 88 ----
# rows: 94
# ---- 89 ----
# rows: 89
# ---- 90 ----
# rows: 67
# rows: 71
# ---- 91 ----
# rows: 70
# ---- 92 ----
# rows: 68
# rows: 69
# rows: 70
# ---- 93 ----
# rows: 72
# ---- 94 ----
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 95 ----
# rows: 87
# ---- 96 ----
# rows: 91
# ---- 97 ----
# rows: 99
# ---- 98 ----
# rows: 104
# ---- 99 ----
# rows: 103
# Done Trimming tinapay 100 files
# ----------------- Word utang-----------------
# ---- 0 ----
# rows: 58
# rows: 88
# ---- 1 ----
# rows: 54
# rows: 85
# ---- 2 ----
# rows: 51
# rows: 86
# ---- 3 ----
# rows: 43
# rows: 62
# rows: 97
# ---- 4 ----
# rows: 97
# ---- 5 ----
# rows: 98
# ---- 6 ----
# rows: 60
# rows: 95
# ---- 7 ----
# rows: 66
# rows: 105
# ---- 8 ----
# rows: 106
# ---- 9 ----
# rows: 95
# ---- 10 ----
# rows: 40
# rows: 63
# rows: 102
# ---- 11 ----
# rows: 41
# rows: 42
# rows: 63
# rows: 97
# ---- 12 ----
# rows: 101
# ---- 13 ----
# rows: 35
# rows: 57
# rows: 92
# ---- 14 ----
# rows: 35
# rows: 55
# rows: 91
# ---- 15 ----
# rows: 95
# ---- 16 ----
# rows: 101
# ---- 17 ----
# rows: 110
# ---- 18 ----
# rows: 102
# ---- 19 ----
# rows: 64
# rows: 89
# ---- 20 ----
# rows: 65
# rows: 106
# ---- 21 ----
# rows: 42
# rows: 67
# rows: 99
# ---- 22 ----
# rows: 97
# ---- 23 ----
# rows: 67
# rows: 105
# ---- 24 ----
# rows: 96
# ---- 25 ----
# rows: 60
# rows: 85
# ---- 26 ----
# rows: 53
# rows: 81
# ---- 27 ----
# rows: 85
# ---- 28 ----
# rows: 51
# rows: 75
# ---- 29 ----
# rows: 75
# ---- 30 ----
# rows: 82
# ---- 31 ----
# rows: 50
# rows: 88
# ---- 32 ----
# rows: 40
# rows: 91
# ---- 33 ----
# rows: 54
# rows: 89
# ---- 34 ----
# rows: 66
# rows: 109
# ---- 35 ----
# rows: 34
# rows: 58
# rows: 91
# ---- 36 ----
# rows: 40
# rows: 66
# rows: 94
# ---- 37 ----
# rows: 37
# rows: 62
# rows: 97
# ---- 38 ----
# rows: 38
# rows: 64
# rows: 99
# ---- 39 ----
# rows: 38
# rows: 63
# rows: 97
# ---- 40 ----
# rows: 63
# rows: 64
# rows: 95
# ---- 41 ----
# rows: 55
# rows: 75
# ---- 42 ----
# rows: 66
# rows: 69
# rows: 70
# ---- 43 ----
# rows: 106
# ---- 44 ----
# rows: 21
# rows: 22
# rows: 23
# rows: 24
# rows: 28
# rows: 29
# rows: 30
# rows: 31
# rows: 93
# ---- 45 ----
# rows: 43
# rows: 110
# ---- 46 ----
# rows: 116
# ---- 47 ----
# rows: 106
# ---- 48 ----
# rows: 100
# ---- 49 ----
# rows: 98
# ---- 50 ----
# rows: 72
# ---- 51 ----
#  NO END ey
# ---- 52 ----
# rows: 86
# ---- 53 ----
# rows: 88
# ---- 54 ----
# rows: 98
# ---- 55 ----
# rows: 38
# rows: 57
# rows: 90
# ---- 56 ----
# rows: 67
# rows: 99
# ---- 57 ----
# rows: 66
# rows: 97
# ---- 58 ----
# rows: 47
# rows: 74
# ---- 59 ----
# rows: 46
# rows: 110
# ---- 60 ----
# rows: 40
# rows: 58
# rows: 79
# ---- 61 ----
# rows: 62
# rows: 88
# ---- 62 ----
# rows: 53
# rows: 85
# ---- 63 ----
# rows: 84
# ---- 64 ----
# rows: 31
# rows: 76
# ---- 65 ----
# rows: 103
# ---- 66 ----
# rows: 80
# ---- 67 ----
# rows: 101
# ---- 68 ----
# rows: 98
# ---- 69 ----
# rows: 102
# ---- 70 ----
# rows: 105
# ---- 71 ----
# rows: 101
# ---- 72 ----
# rows: 103
# ---- 73 ----
# rows: 99
# ---- 74 ----
# rows: 100
# ---- 75 ----
# rows: 70
# ---- 76 ----
# rows: 99
# ---- 77 ----
# rows: 57
# rows: 99
# ---- 78 ----
# rows: 108
# ---- 79 ----
# rows: 118
# ---- 80 ----
# rows: 44
# rows: 70
# ---- 81 ----
# rows: 41
# rows: 64
# rows: 105
# ---- 82 ----
# rows: 65
# rows: 100
# ---- 83 ----
# rows: 65
# rows: 66
# rows: 101
# ---- 84 ----
# rows: 70
# ---- 85 ----
# rows: 36
# rows: 57
# rows: 90
# ---- 86 ----
# rows: 38
# rows: 90
# ---- 87 ----
# rows: 36
# rows: 90
# ---- 88 ----
# rows: 37
# rows: 58
# rows: 88
# ---- 89 ----
# rows: 37
# rows: 58
# rows: 87
# ---- 90 ----
# rows: 53
# rows: 74
# ---- 91 ----
# rows: 54
# rows: 75
# ---- 92 ----
# rows: 52
# rows: 77
# ---- 93 ----
# rows: 42
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 71
# ---- 94 ----
# rows: 45
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 95 ----
# rows: 61
# rows: 99
# ---- 96 ----
# rows: 94
# ---- 97 ----
# rows: 87
# ---- 98 ----
# rows: 94
# ---- 99 ----
# rows: 91
# Done Trimming utang 100 files
# ----------------- Word wala-----------------
# ---- 0 ----
# rows: 74
# ---- 1 ----
# rows: 64
# rows: 66
# rows: 68
# rows: 69
# rows: 70
# ---- 2 ----
# rows: 73
# ---- 3 ----
# rows: 70
# ---- 4 ----
# rows: 84
# ---- 5 ----
# rows: 84
# ---- 6 ----
# rows: 85
# ---- 7 ----
# rows: 83
# ---- 8 ----
# rows: 81
# ---- 9 ----
# rows: 91
# ---- 10 ----
# rows: 75
# ---- 11 ----
# rows: 70
# ---- 12 ----
# rows: 80
# ---- 13 ----
# rows: 89
# ---- 14 ----
# rows: 96
# ---- 15 ----
# rows: 82
# ---- 16 ----
# rows: 86
# ---- 17 ----
# rows: 81
# ---- 18 ----
# rows: 80
# ---- 19 ----
# rows: 80
# ---- 20 ----
# rows: 67
# rows: 71
# ---- 21 ----
# rows: 76
# ---- 22 ----
# rows: 78
# ---- 23 ----
# rows: 78
# ---- 24 ----
# rows: 82
# ---- 25 ----
# rows: 70
# ---- 26 ----
# rows: 85
# ---- 27 ----
# rows: 79
# ---- 28 ----
# rows: 79
# ---- 29 ----
# rows: 85
# ---- 30 ----
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 31 ----
# rows: 86
# ---- 32 ----
# rows: 85
# ---- 33 ----
# rows: 76
# ---- 34 ----
# rows: 90
# ---- 35 ----
# rows: 77
# ---- 36 ----
# rows: 83
# ---- 37 ----
# rows: 73
# ---- 38 ----
# rows: 79
# ---- 39 ----
# rows: 83
# ---- 40 ----
# rows: 76
# ---- 41 ----
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 42 ----
# rows: 63
# rows: 64
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 43 ----
# rows: 72
# ---- 44 ----
# rows: 74
# ---- 45 ----
# rows: 75
# ---- 46 ----
# rows: 84
# ---- 47 ----
# rows: 79
# ---- 48 ----
# rows: 79
# ---- 49 ----
# rows: 88
# ---- 50 ----
# rows: 112
# ---- 51 ----
# rows: 112
# ---- 52 ----
# rows: 100
# ---- 53 ----
# rows: 102
# ---- 54 ----
# rows: 105
# ---- 55 ----
# rows: 84
# ---- 56 ----
# rows: 75
# ---- 57 ----
# rows: 71
# ---- 58 ----
# rows: 91
# ---- 59 ----
# rows: 88
# ---- 60 ----
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 61 ----
# rows: 83
# ---- 62 ----
# rows: 89
# ---- 63 ----
# rows: 87
# ---- 64 ----
# rows: 85
# ---- 65 ----
# rows: 77
# ---- 66 ----
# rows: 81
# ---- 67 ----
# rows: 73
# ---- 68 ----
# rows: 84
# ---- 69 ----
# rows: 85
# ---- 70 ----
# rows: 76
# ---- 71 ----
# rows: 82
# ---- 72 ----
# rows: 81
# ---- 73 ----
# rows: 80
# ---- 74 ----
# rows: 83
# ---- 75 ----
# rows: 72
# ---- 76 ----
# rows: 81
# ---- 77 ----
# rows: 75
# ---- 78 ----
# rows: 91
# ---- 79 ----
# rows: 83
# ---- 80 ----
# rows: 85
# ---- 81 ----
# rows: 90
# ---- 82 ----
# rows: 93
# ---- 83 ----
# rows: 96
# ---- 84 ----
# rows: 102
# ---- 85 ----
# rows: 90
# ---- 86 ----
# rows: 96
# ---- 87 ----
# rows: 92
# ---- 88 ----
# rows: 86
# ---- 89 ----
# rows: 88
# ---- 90 ----
# rows: 61
# rows: 62
# rows: 63
# rows: 64
# rows: 65
# rows: 66
# rows: 76
# ---- 91 ----
# rows: 72
# ---- 92 ----
# rows: 69
# rows: 70
# ---- 93 ----
# rows: 65
# rows: 66
# rows: 67
# rows: 68
# rows: 69
# rows: 70
# ---- 94 ----
# rows: 74
# ---- 95 ----
# rows: 92
# ---- 96 ----
# rows: 98
# ---- 97 ----
# rows: 95
# ---- 98 ----
# rows: 96
# ---- 99 ----
# rows: 88
# Done Trimming wala 100 files

# %%
import os

directory = "trimmed_data_updated2a/"
if not os.path.exists(directory):
    os.makedirs(directory)
    
for className in classNames:
    className = className.split("\\")[1]
    
    if not os.path.exists(directory +className):
        os.makedirs(directory  +className)
    
    ctr = 0
    for df in listOfTrimmedDataFramesPerClass[className]['emg']:
        fileName = directory + className + "/emg" + str(ctr)
        df['right'].to_csv(fileName + "-Right2a.csv", encoding='utf-8', index=False)
        df['left'].to_csv(fileName + "-Left2a.csv", encoding='utf-8', index=False)
        ctr+=1
    
    ctr = 0
    for df in listOfTrimmedDataFramesPerClass[className]['acc']:
        fileName = directory + className + "/acc" + str(ctr)
        df['right'].to_csv(fileName + "-Right2a.csv", encoding='utf-8', index=False)
        df['left'].to_csv(fileName + "-Left2a.csv", encoding='utf-8', index=False)
        ctr+=1

    ctr = 0
    for df in listOfTrimmedDataFramesPerClass[className]['gyro']:
        fileName = directory + className + "/gyro" + str(ctr)
        df['right'].to_csv(fileName + "-Right2a.csv", encoding='utf-8', index=False)
        df['left'].to_csv(fileName + "-Left2a.csv", encoding='utf-8', index=False)
        ctr+=1
    
    print("Done saving trimmed files of " + className)

print("DONE")
# Out:
# Done saving trimmed files of binebenta
# Done saving trimmed files of extra
# Done saving trimmed files of gulay
# Done saving trimmed files of gusto
# Done saving trimmed files of itlog
# Done saving trimmed files of juice
# Done saving trimmed files of kape
# Done saving trimmed files of kilo
# Done saving trimmed files of mahal
# Done saving trimmed files of malaki
# Done saving trimmed files of maliit
# Done saving trimmed files of mayroon
# Done saving trimmed files of nagbubukas
# Done saving trimmed files of nagsasara
# Done saving trimmed files of oras
# Done saving trimmed files of pabili
# Done saving trimmed files of poloshirt
# Done saving trimmed files of puwede
# Done saving trimmed files of saging
# Done saving trimmed files of sari-sari store
# Done saving trimmed files of shorts
# Done saving trimmed files of size
# Done saving trimmed files of spaghetti
# Done saving trimmed files of supot
# Done saving trimmed files of t-shirt
# Done saving trimmed files of tawad
# Done saving trimmed files of tinapay
# Done saving trimmed files of utang
# Done saving trimmed files of wala
# DONE

# %%
# emgDataFrames = {}
# emgDataFrames['right'] = []
# emgDataFrames['left'] = []
    
# accDataFrames = {}
# accDataFrames['right'] = []
# accDataFrames['left'] = []

# gyroDataFrames = {}
# gyroDataFrames['right'] = []
# gyroDataFrames['left'] = []

# dataFrameDictionary = {}
# className = c
# emgleftctr = 0
# emgrightctr = 0
# accleftctr = 0
# accrightctr = 0
# gyroleftctr = 0
# gyrorightctr = 0

# className = "binebenta"
# d = listOfDataPerClass[0]

# for fileName in d:
#     fileLocation = path + className + "/" + fileName + ""
            
#     df = pd.read_csv(fileLocation)
            
#     if "emg" in fileName:   
#         if "-0-" in fileName:
#             emgDataFrames['right'].append(df)
#             emgleftctr+=1
#         else:
#             emgDataFrames['left'].append(df)
#             emgrightctr+=1
#     elif ("accelerometer") in fileName:
#         if "-0-" in fileName:
#             accDataFrames['right'].append(df)
#             accleftctr+=1
#         else:
#             accDataFrames['left'].append(df)
#             accrightctr+=1
#     elif ("gyro") in fileName:
#         if "-0-" in fileName:
#             gyroDataFrames['right'].append(df)
#             gyroleftctr+=1
#         else:
#             gyroDataFrames['left'].append(df)
#             gyrorightctr+=1
    
# dataFrameDictionary["emg"] = emgDataFrames
# dataFrameDictionary["acc"] = accDataFrames
# dataFrameDictionary["gyro"] = gyroDataFrames

# listOfDataFramesPerClass[className] = dataFrameDictionary
# print("Total of " + str(emgleftctr) + " left arm emg files and " + str(emgrightctr) + " right arm emg files.")
# print("Total of " + str(accleftctr) + " left arm acc files and " + str(accrightctr) + " right arm acc files.")
# print("Total of " + str(gyroleftctr) + " left arm gyro files and " + str(gyrorightctr) + " right arm gyro files.")
