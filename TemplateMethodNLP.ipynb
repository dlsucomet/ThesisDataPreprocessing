# %%
class Word:
    
    def __init__(self, type, word, entity="NA"):
        self.type = type
        self.word = word
        self.entity = entity
        
template1 = []
template1.append("adjective")
template1.append("verb")
template2 = []
template2.append("verb")
template2.append("noun")
template3 = []
template3.append("adjective")
template3.append("noun")
template3.append("noun")
template4 = []
template4.append("adjective")
template4.append("adjective")
template4.append("noun")
template5 = []
template5.append("verb")
template5.append("adjective")
template5.append("noun")
template5.append("noun")
template6 = []
template6.append("preposition")
template6.append("noun")
template6.append("verb")
template6.append("noun")
template7 = []
template7.append("adjective")
template7.append("noun")
template8 = []
template8.append("adjective")
template9 = []
template9.append("preposition")
template9.append("verb")
template9.append("adverb")

library = []
word0 = Word("verb","pabili")
word1 = Word("verb","nagbubukas")
word2 = Word("noun","ate","person")
word3 = Word("noun","isda","food")
word4 = Word("noun", "itlog","food")
word5 = Word("noun", "kuya","person")
word6 = Word("noun", "baboy","food")
word7 = Word("noun", "tshirt","clothes")
word8 = Word("adjective", "blue")
word9 = Word("adjective", "wala")
word10 = Word("adjective", "dalawa")
word11 = Word("adjective", "tatlo")
word12 = Word("verb", "nagsasara")
word13 = Word("noun", "shorts","clothes")
word14 = Word("adjective", "red")
word15 = Word("adjective", "mahal")
word16 = Word("verb", "tawad")
word17 = Word("adjective", "small")
word18 = Word("adjective", "medium")
word19 = Word("adjective", "large")
word20 = Word("noun", "sarisaristore","location")
word21 = Word("noun", "mantika","food")
word22 = Word("noun", "juice","food")
word23 = Word("noun", "size")
word24 = Word("adjective", "mayroon")
word25 = Word("noun", "kayo","person")
word26 = Word("adjective", "black")
word27 = Word("preposition", "ano")
word28 = Word("noun", "niyo","person")
word29 = Word("noun", "kape","food")
word30 = Word("adjective", "magkano")
word31 = Word("verb", "bibili")
word32 = Word("noun", "oras","adjective")
word33 = Word("adverb", "dito")
word34 = Word("noun", "pagkain","food")
word35 = Word("noun", "tubig","food")
word36 = Word("noun", "kulay")
word37 = Word("adjective", "isa")
word38 = Word("verb", "gusto")
word39 = Word("noun", "tinapay","food")
word40 = Word("noun", "manok","food")
word41 = Word("noun", "poloshirt","clothes")
word42 = Word("adjective", "extra")
word43 = Word("noun", "kilo", "adjective")
word44 = Word("verb", "salamat")
word45 = Word("verb", "binebenta")
word46 = Word("verb", "pwede")
word47 = Word("noun", "ko","person")
word48 = Word("verb", "utang")
word49 = Word("noun", "gulay","food")
word50 = Word("noun", "softdrinks","food")
word51 = Word("adjective", "sorry")
word52 = Word("exclamation", "hello")
word53 = Word("adjective", "malaki")
word54 = Word("noun", "supot","item")
word55 = Word("noun", "saging","food")
word56 = Word("noun", "kanin","food")
word57 = Word("noun", "ito","item")
word58 = Word("noun", "spaghetti","food")
word59 = Word("noun", "nito","item")

library.append(word0)
library.append(word1)
library.append(word2)
library.append(word3)
library.append(word4)
library.append(word5)
library.append(word6)
library.append(word7)
library.append(word8)
library.append(word9)
library.append(word10)
library.append(word11)
library.append(word12)
library.append(word13)
library.append(word14)
library.append(word15)
library.append(word16)
library.append(word17)
library.append(word18)
library.append(word19)
library.append(word20)
library.append(word21)
library.append(word22)
library.append(word23)
library.append(word24)
library.append(word25)
library.append(word26)
library.append(word27)
library.append(word28)
library.append(word29)
library.append(word30)
library.append(word31)
library.append(word32)
library.append(word33)
library.append(word34)
library.append(word35)
library.append(word36)
library.append(word37)
library.append(word38)
library.append(word39)
library.append(word40)
library.append(word41)
library.append(word42)
library.append(word43)
library.append(word44)
library.append(word45)
library.append(word46)
library.append(word47)
library.append(word48)
library.append(word49)
library.append(word50)
library.append(word51)
library.append(word52)
library.append(word53)
library.append(word54)
library.append(word55)
library.append(word56)
library.append(word57)
library.append(word58)
library.append(word59)

inputs = []
types = []
entity = []
uinput = ""
end = 1

while(end):
    #Read user inputs
    print("Please enter one word at a time, enter 0 to finalize inputs.\n")
    while(uinput != "0"):
        uinput = input()
        if(uinput != "0"):
            inputs.append(uinput)
            
    #Check type for each input
    for i in range(len(inputs)):
        for j in range(len(library)):
            if(inputs[i] == library[j].word):
                types.append(library[j].type)
                entity.append(library[j].entity)
    
    #Remove default entity
    entity[:] = [x for x in entity if x != "NA"]
    
    #Match to templates
    if(len(entity) > 0)
        if 'location' in entity:
            print(inputs[0]+"ng "+inputs[1]+" "+inputs[2]+" yung "+ inputs[3] + "\n")
        elif 'adjective' in entity:
            print(inputs[0]+" "+inputs[1]+"ng "+inputs[2]+" ng " + inputs[3] + "\n")
    elif(len(types) == 1):
        if(types == template8):
            print("ang " + inputs[0] + " naman\n")
    elif(len(types) == 2):
        if(types == template1):
            print(inputs[0]+" na po bang "+inputs[1]+"\n")
        elif(types == template2):
            print(inputs[0]+" po ng "+inputs[1]+"\n")
        elif(types == template7):
            print(inputs[0]+" po "+inputs[1])
    elif(len(types) == 3):
        if(types == template3):
            print(inputs[0]+" ba "+inputs[1]+"ng "+inputs[2]+"\n")
        elif(types == template4):
            if(inputs[2] == "nito"):
                print(inputs[0]+" po ba "+inputs[1]+" "+inputs[2]+"\n")
            else:
                print(inputs[0]+"g "+inputs[1]+" po ba na "+inputs[2]+"\n")
        elif(types == template9):
            print(inputs[0]+" "+inputs[1]+" niyo "+inputs[2]+"\n")
    elif(len(types) == 4):
        if(types == template5):
            print(inputs[0]+" "+inputs[1]+"ng "+inputs[2]+" ng " + inputs[3] + "\n")
        elif(types == template6):
            print(inputs[0]+"ng "+inputs[1]+" "+inputs[2]+" yung "+ inputs[3] + "\n")
    else:
        print("No template matches your input!")
    
    inputs.clear()
    uinput = ""
    types.clear()
    entity.clear()
    
    end = int(input("Enter 1 to input a new set of words, 0 to end the program: \n"))
# Out:
# Please enter one word at a time, enter 0 to finalize inputs.
#
# pabili
# kape
# 0
# ['NA', 'food']
# ['food']
# pabili po ng kape
#
# Enter 1 to input a new set of words, 0 to end the program:
# 0
